# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Web Scraping con Python

# %% [markdown]
# <div class="alert alert-block alert-danger"> <h1>Librerias a Utilizar en el Curso

# %%
#pip install pixiedust
#jupyter labextension install @jupyterlab/debugger
conda install xeus-python -c conda-forge
# Out:
#   File "<ipython-input-32-0baf641571a6>", line 3
#     conda install xeus-python -c conda-forge
#           ^
# SyntaxError: invalid syntax

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import pixiedust
# Out:
# Pixiedust database opened successfully
# Table VERSION_TRACKER created successfully
# Table METRICS_TRACKER created successfully
#
# Share anonymous install statistics? (opt-out instructions)
#
# PixieDust will record metadata on its environment the next time the package is installed or updated. The data is anonymized and aggregated to help plan for future releases, and records only the following values:
#
# {
#    "data_sent": currentDate,
#    "runtime": "python",
#    "application_version": currentPixiedustVersion,
#    "space_id": nonIdentifyingUniqueId,
#    "config": {
#        "repository_id": "https://github.com/ibm-watson-data-lab/pixiedust",
#        "target_runtimes": ["Data Science Experience"],
#        "event_id": "web",
#        "event_organizer": "dev-journeys"
#    }
# }
# You can opt out by calling pixiedust.optOut() in a new cell.
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Tutorial

# %%
url = "https://boston.craigslist.org/d/software-qa-dba-etc/search/sof"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data = response.text

# %%
data
# Out:
# '\ufeff<!DOCTYPE html>\n<html class="no-js"><head>\n    <title>boston software/qa/dba/etc  jobs - craigslist</title>\n    <script type="application/ld+json" id="ld_breadcrumb_data" >\n    {"@context":"https://schema.org","itemListElement":[{"item":{"name":"boston.craigslist.org","@id":"https://boston.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"jobs","@id":"https://boston.craigslist.org/d/jobs/search/jjj"},"position":2,"@type":"ListItem"},{"item":{"name":"software","@id":"https://boston.craigslist.org/d/software-qa-dba-etc/search/sof"},"position":3,"@type":"ListItem"}],"@type":"BreadcrumbList"}\n</script>\n\n\n    <meta name="description" content="">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n        <link rel="canonical" href="https://boston.craigslist.org/d/software-qa-dba-etc/search/sof">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org
# ...

# %%
soup = BeautifulSoup(data,'html.parser')

# %%
soup
# Out:
# ﻿<!DOCTYPE html>
#
# <html class="no-js"><head>
# <title>boston software/qa/dba/etc  jobs - craigslist</title>
# <script id="ld_breadcrumb_data" type="application/ld+json">
#     {"@context":"https://schema.org","itemListElement":[{"item":{"name":"boston.craigslist.org","@id":"https://boston.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"jobs","@id":"https://boston.craigslist.org/d/jobs/search/jjj"},"position":2,"@type":"ListItem"},{"item":{"name":"software","@id":"https://boston.craigslist.org/d/software-qa-dba-etc/search/sof"},"position":3,"@type":"ListItem"}],"@type":"BreadcrumbList"}
# </script>
# <meta content="" name="description"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible">
# <link href="https://boston.craigslist.org/d/software-qa-dba-etc/search/sof" rel="canonical"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# ...

# %%
tags = soup.find_all('a')

# %%
tags
# Out:
# [<a class="appstorebtn" href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">
#          Android
#      </a>,
#  <a class="appstorebtn" href="https://apps.apple.com/us/app/craigslist/id1336642410">
#          iOS
#      </a>,
#  <a class="header-logo" href="/" name="logoLink">CL</a>,
#  <a href="/">boston</a>,
#  <a href="https://post.craigslist.org/c/bos">post</a>,
#  <a href="https://accounts.craigslist.org/login/home">account</a>,
#  <a class="favlink" href="#"><span aria-hidden="true" class="icon icon-star fav"></span><span class="fav-number">0</span><span class="fav-label"> favorites</span></a>,
#  <a class="to-banish-page-link" href="#">
#  <span aria-hidden="true" class="icon icon-trash red"></span>
#  <span class="banished_count">0</span>
#  <span class="discards-label"> hidden</span>
#  </a>,
#  <a class="header-logo" href="/">CL</a>,
# ...

# %%
for tag in tags:
    print(tag.get('href'))
# Out:
# https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile
# https://apps.apple.com/us/app/craigslist/id1336642410
# /
# /
# https://post.craigslist.org/c/bos
# https://accounts.craigslist.org/login/home
# #
# #
# /
# https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fboston%2Ecraigslist%2Eorg%2Fd%2Fsoftware%2Dqa%2Ddba%2Detc%2Fsearch%2Fsof
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof?sort=date&
#
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof
#
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7306130076.html
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7306130076.html
# #
# https://boston.craigslist.org/gbs/sof/d/newton-highlands-xamarine-software/7306093632.html
# https://boston.craigslist.org/gbs/sof/d/newton-highlands-xamarine-software/7306093632.html
# #
# ...

# %%
jobs = soup.find_all('div',{"class":"result-info"})

# %%
jobs
# Out:
# [<div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-13 10:29" title="Tue 13 Apr 10:29:23 AM">Apr 13</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7306130076" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7306130076.html" id="postid_7306130076">Software Engineer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Remote)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
# ...

# %%
npo_jobs = {}
job_no = 0
while True:
    for job in jobs:
        title = job.find("a",{"class":"result-title hdrlnk"}).text
        location_tag = job.find("span",{"class":"result-hood"})
        location = location_tag.text[2:-1] if location_tag else "N/A"
        date = job.find("time",{"class":"result-date"}).text
        link = job.find("a",{"class":"result-title hdrlnk"}).get("href")
        job_response = requests.get(link)
        job_data = job_response.text
        job_soup = BeautifulSoup(job_data,'html.parser')
        job_description = job_soup.find('section',{'id':'postingbody'}).text
        job_atributtes_tag = job_soup.find('p',{'class':'attrgroup'})
        job_atributtes = job_atributtes_tag.text if job_atributtes_tag else 'N/A'
        
        job_no+=1
        npo_jobs[job_no]=[title,location,date,link,job_atributtes,job_description]
        
        print("Job Title: ",title, "\nLocation: ",location,"\nDate:",date,"\nLink: ",link,"\n", job_atributtes,"\nJob Description:",job_description,"\n-----")
    url_tag = soup.find('a',{'title':'next page'})
    if url_tag.get('href'):
        url = 'https://boston.craigslist.org' + url_tag.get('href')
        print(url)
    else:
        break
print('Total Jobs: ', job_no)
npo_jobs_df = pd.DataFrame.from_dict(npo_jobs,orient='index',columns=['Job Title','Location','Date','Link','Job Attributes','Job Description'])
# Out:
# --Return--
# None
# > <ipython-input-33-f7af10cdf94e>(1)<module>()
# ----> 1 import pdb; pdb.set_trace()
#       2 npo_jobs = {}
#       3 job_no = 0
#       4 while True:
#       5     for job in jobs:
#
# ipdb> c
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-f7af10cdf94e> in <module>
#       3 job_no = 0
#       4 while True:
# ----> 5     for job in jobs:
#       6         title = job.find("a",{"class":"result-title hdrlnk"}).text
#       7         location_tag = job.find("span",{"class":"result-hood"})
#
# NameError: name 'jobs' is not defined

# %%
npo_jobs_df.head()
# Out:
#                             Job Title          Location    Date  \
# 1                   Software Engineer            Remote  Apr 13
# 2         Xamarine Software Developer  Newton Highlands  Apr 13
# 3  Data Scientist & Software Engineer               N/A  Apr  9
# 4                   Software Engineer            Remote  Apr  8
# 5                   Software Engineer            Remote  Apr  6
#
#                                                 Link  \
# 1  https://boston.craigslist.org/gbs/sof/d/andove...
# 2  https://boston.craigslist.org/gbs/sof/d/newton...
# 3  https://boston.craigslist.org/bmw/sof/d/boxbor...
# 4  https://boston.craigslist.org/gbs/sof/d/andove...
# 5  https://boston.craigslist.org/gbs/sof/d/andove...
#
#                                       Job Attributes  \
# 1  \ncompensation: To Be Discussed\n\nemployment ...
# 2  \ncompensation: based on candidate's experienc...
# 3  \ncompensation: TBD\n\nemployment type: full-t...
# ...

# %%
npo_jobs_df.to_csv('npo_jobs.csv',sep='|')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Tarea

# %%
url = "https://www.programmableweb.com/category/all/apis"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data = response.text

# %%
data
# Out:
# '<!DOCTYPE html><html xmlns="https://www.w3.org/1999/xhtml" lang="en" dir="ltr" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#"><head profile="http://www.w3.org/1999/xhtml/vocab"><meta name="viewport" content="width=device-width, initial-scale=1.0"> <!--[if IE]><![endif]--><link rel="preload" href="https://fonts.gstatic.com/s/opensans/v16/mem6YaGs126MiZpBA-UFUK0Zdcg.ttf" as="font" type="font/ttf" crossorigin="anonymous" /><link rel="preload" href="https://fonts.gstatic.com/s/opensans/v16/memnYaGs126MiZpBA-UFUKXGUdhrIqY.ttf" as="font" type="font/ttf" crossorigin="anonymous" /><link rel="preload" href="https://fonts.gstatic.com/s/opensans/v16/memnYaGs126MiZpBA-UFUKWiUNhrIqY.ttf" as="font" type="font/ttf" crossorigin="anonymous" /><link rel="preload" href="https://fonts.gstatic.com/s/opensans/v16/mem8YaGs126MiZpBA-UFVZ0e.ttf" as="font" type="font/ttf" crossorigin="anonymous" /><link rel="preload" href="https://fonts.gstatic.com/s/opensans/v16/mem5YaGs126MiZpBA-UNirkOUuhs.ttf" as
# ...

# %%
soup = BeautifulSoup(data,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
apis_table = soup.find('tbody')

# %%
apis_table
# Out:
# <tbody><tr class="odd views-row-first"><td class="views-field views-field-pw-version-title"> <a href="/api/google-maps">Google Maps API</a><br/></td><td class="views-field views-field-search-api-excerpt views-field-field-api-description hidden-xs visible-md visible-sm col-md-8"> [This API is no longer available. Google Maps' services have been split into multiple APIs, including the Static Maps API, Street View Image API, Directions APIs, Distance Matrix API, Elevation API,...</td><td class="views-field views-field-field-article-primary-category"> <a href="/category/mapping">Mapping</a></td><td class="views-field views-field-flag-follow-api-count"> 3,850</td><td class="views-field views-field-pw-version-links"> <a href="/api/google-maps-rest-api">REST</a></td></tr><tr class="even"><td class="views-field views-field-pw-version-title"> <a href="/api/twitter">Twitter API</a><br/></td><td class="views-field views-field-search-api-excerpt views-field-field-api-description hidden-xs visibl
# ...

# %%
def request_soup(url):
    response = requests.get(url)
    data = response.text
    return BeautifulSoup(data,'html.parser')

# %%
#Activando Debuger
#%%pixie_debugger

url="https://www.programmableweb.com/category/all/apis"
npo_apis = {}
apis_no = 0
while True:
    soup = request_soup(url)
    apis_table = soup.find('tbody')
    for tr in apis_table.select('tr'):
        name_tag = tr.find("td",{"class":"views-field views-field-pw-version-title"})
        name = name_tag.text if name_tag else "N/A"
        description = tr.find("td",{"class":"views-field views-field-search-api-excerpt views-field-field-api-description hidden-xs visible-md visible-sm col-md-8"}).text
        category = tr.find("td",{"class":"views-field views-field-field-article-primary-category"}).text
        link = 'https://www.programmableweb.com' + tr.find("td",{"class":"views-field views-field-pw-version-title"}).a.get("href")

        apis_no+=1
        npo_apis[apis_no]=[name,description,category,link]

        print("Api Name: ",name, "\nDescription: ",description,"\nCategory:",category,"\nLink: ",link,"\n-----")
    url_tag = soup.find('a',{'title':'Go to next page'})
    if url_tag.get('href') and apis_no <= 5:
        url = 'https://www.programmableweb.com' + url_tag.get('href')
        print(url)
        #break
    else:
        break
    
print('Total Apis: ', apis_no)

#DataFrame
npo_apis_df = pd.DataFrame.from_dict(npo_apis,orient='index',columns=['Api Name','Description','Category','Link'])
#CSV
npo_apis_df.to_csv('npo_apis.csv',sep='|')
# Out:
# --Return--
# None
# > <ipython-input-38-bc386b7333df>(3)<module>()
#       1 #Activando Debuger
#       2 #%%pixie_debugger
# ----> 3 import pdb; pdb.set_trace()
#       4
#       5 url="https://www.programmableweb.com/category/all/apis"
#
# ipdb> l
#       1 #Activando Debuger
#       2 #%%pixie_debugger
# ----> 3 import pdb; pdb.set_trace()
#       4
#       5 url="https://www.programmableweb.com/category/all/apis"
#       6 npo_apis = {}
#       7 apis_no = 0
#       8 while True:
#       9     soup = request_soup(url)
#      10     apis_table = soup.find('tbody')
#      11     for tr in apis_table.select('tr'):

# %%
# %debug #Informacion de Debug https://clouds.eos.ubc.ca/~phil/courses/atsc301/coursebuild/html/debugging_intro.html
# Out:
# > c:\users\jrperez\anaconda3\lib\bdb.py(113)dispatch_line()
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# ipdb> up
# > c:\users\jrperez\anaconda3\lib\bdb.py(88)trace_dispatch()
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ipdb> up
# > <ipython-input-22-b3771832967c>(4)pixie_run()
#       2     import pdb
#       3     pdb.set_trace()
# ----> 4     url="https://www.programmableweb.com/category/all/apis"
#       5     npo_apis = {}
#       6     apis_no = 0
#
# ipdb> down
# > c:\users\jrperez\anaconda3\lib\bdb.py(88)trace_dispatch()
#      86             return # None
#      87         if event == 'line':
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
npo_apis_df.head()
# Out:
#                           Api Name  \
# 1                  Google Maps API
# 2                      Twitter API
# 3                 Shopping.com API
# 4   Google Analytics Managment API
# 5           Yahoo Local Search API
#
#                                          Description    Category  \
# 1   [This API is no longer available. Google Maps...     Mapping
# 2   [This API is no longer available. It has been...      Social
# 3   [This API has been acquired by eBay and now e...   eCommerce
# 4   Use the Google Analytics Management API to le...   Analytics
# 5   The Yahoo! Local Search APIs give users acces...      Search
#
#                                                 Link
# 1    https://www.programmableweb.com/api/google-maps
# 2        https://www.programmableweb.com/api/twitter
# 3    https://www.programmableweb.com/api/shoppingcom
# 4  https://www.programmableweb.com/api/google-ana...
# 5  https://www.programmableweb.com/api/yahoo-loca...

# %%
url
# Out:
# 'https://www.programmableweb.com/category/all/apis?page=1'
