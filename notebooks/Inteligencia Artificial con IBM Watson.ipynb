# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Introducción de Watson

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# # Url utilizadas
# https://reqbin.com/curl Ejecutar el curl
#
# https://jsonbeautifier.org Visuaizar mejor el Jason
#
# https://www.postman.com Hacer peticiones para la servicio Discovery
#
# https://www.twilio.com Proporciona una plataforma para la comunicación a través de mensajería IP (chat), video, voz, SMS y MMS
#
# https://convertio.co/es/  Convertidor de formatos de archivos
#
# https://aif360.mybluemix.net Nos ayudas a mitigar los sesgos.
#
# https://aix360.mybluemix.net  Ayudar a comprender cómo los modelos de aprendizaje automático predicen.

# %% [markdown]
# **Que es Watson?** : es la inteligencia artificial creado por IBM y expuesto por servicios.
#
# Tipos de Watson:
#
# - Watson Totalmente entrenado: eje. Whatson Personality Insights
# - Watson Parcialmente personalizado: eje. Watson Natural Languaje Understanding
# - Watson sin entrenamiento. con el fin de implementar el caso de uso especifico del negocio.
#
#
# ![Watson.JPG](../Watson.JPG)
#
# ![Watson_FormasDeConsumo.JPG](../Watson_FormasDeConsumo.JPG)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Arquitectura Rest

# %% [markdown]
# Tener conocimiento sobre la arquitectura REST es relevante para el resto del curso. Principalmente porque es la forma en la que consumiremos los servicios de Watson de IBM, pero sobre todo porque es el estándar existente en la comunicación en aplicaciones web
#
# - Empecemos, ¿Qué es REST?
#
# REST (Representational State Transfer) es un estilo de arquitectura para aplicaciones con comunicación/conexión a la red, la utilizamos para poder comunicarnos entre máquinas utilizando HTTP
#
# - ¿Qué es HTTP?
#
# Hyper Text Transfer Protocol es un protocolo que utiliza la World Wide Web que define la forma en la que los mensajes se deben de estructurar y mandar, así como sus respuestas.
#
# Las aplicaciones que utilizan REST usan peticiones HTTP para crear, alterar, leer y borrar datos. En resumen REST utiliza HTTP para operaciones CRUD (Create, Read, Update, Delete).
#
# Al usar métodos HTTP usamos varios verbos para la interacción, algunos de los más importantes son:
#
# - GET : Comúnmente cuando solo queremos obtener algo. Ej. cargar una página web
# - POST: Cuando queremos proporcionar información y obtener información a cambio
# - PUT: Cuando queremos modificar
# - DELETE: Cuando queremos borrar
#
# **Dentro de este curso estaremos utilizando la terminal cURL. cURL es una herramienta de línea de comando que nos permite transferir datos utilizando diferentes protocolos. A través de cURL es que haremos nuestras peticiones HTTP para consumir los servicios de Watson expuestos por IBM.**

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# #  Uso de Watson Personality Insights via CURL

# %% [markdown]
# El servicio IBM Watson™ Personality Insights obtiene información sobre las características de personalidad de las redes sociales, los datos empresariales, u otras comunicaciones digitales.
#
# URL Documentacion
#
#
# ![Watson_PersonalityInsights.JPG](../Watson_PersonalityInsights.JPG)
#
# ![Watson_BifFive.JPG](../Watson_BifFive.JPG)
#
# URl Documentacion https://cloud.ibm.com/docs/personality-insights?topic=personality-insights-models
#
#
# ![Watson_NecesidadesValores.JPG](../Watson_NecesidadesValores.JPG)
#
# URL Documentacion https://cloud.ibm.com/docs/personality-insights?topic=personality-insights-needs
#
# ![Watson_PreferenciasConsumo.JPG](../Watson_PreferenciasConsumo.JPG)
#
# ![Watson_CasosUso.JPG](../Watson_CasosUso.JPG)
#
# ![Watson_InterpretacionResultados.JPG](../Watson_InterpretacionResultados.JPG)
#
# ![Watson_OtrasConsidetaciones.JPG](../Watson_OtrasConsidetaciones.JPG)

# %% [markdown]
# Los archivos para la ejecucion estan en:
#
# D:\Cursos\InteligenciaArtificial\dataset\watson
#
# - curl.txt : Contiene las sentencia para consumir el servicio Personality Insights, previo a esto se debio crear el servicio para obrener las credenciales (Clave de la APy y URL)
# - curl_resultado.txt : resultado de obtenido despues de ejecutar la sentencia.
# - profile.txt: Insumo para la sentencia
#
# Para una mejor la visualizacion del contenido se debe copiar el resultado fila 11 del archivo curl_resultado.txt y pegarlo en la pagina https://jsonbeautifier.org/

# %%
# Import personality Insights SDK
from watson_developer_cloud import PersonalityInsightsV3


# Import Json
import json

url = 'https://api.us-south.personality-insights.watson.cloud.ibm.com/instances/ac602ecd-ec04-4a08-8769-344075001dec'
apikey = 'xQL5UhF7ajhPb2W-ptf5e9aBGXS1D9af_ovPz_PLo6X6'

service = PersonalityInsightsV3(
    url=url, iam_apikey=apikey, version="2017-10-13")

text = """
Vice President Johnson, Mr. Speaker, Mr. Chief Justice, President Eisenhower,
Vice President Nixon, President Truman, Reverend Clergy, fellow citizens:

We observe today not a victory of party but a celebration of freedom --
symbolizing an end as well as a beginning -- signifying renewal as well as
change. For I have sworn before you and Almighty God the same solemn oath our
forbears prescribed nearly a century and three-quarters ago.

The world is very different now. For man holds in his mortal hands the power
to abolish all forms of human poverty and all forms of human life. And yet
the same revolutionary beliefs for which our forebears fought are still at
issue around the globe -- the belief that the rights of man come not from the
generosity of the state but from the hand of God.

We dare not forget today that we are the heirs of that first revolution. Let
the word go forth from this time and place, to friend and foe alike, that the
torch has been passed to a new generation of Americans -- born in this century,
tempered by war, disciplined by a hard and bitter peace, proud of our ancient
heritage -- and unwilling to witness or permit the slow undoing of those human
rights to which this nation has always been committed, and to which we are
committed today at home and around the world.

Let every nation know, whether it wishes us well or ill, that we shall pay
any price, bear any burden, meet any hardship, support any friend, oppose
any foe to assure the survival and the success of liberty.

This much we pledge -- and more.
"""
profile = service.profile(text, content_type='text/plain',
                          content_language="es").get_result()
len(profile['warnings'])
print(json.dumps(profile, indent=2))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c75591a83acb> in <module>
#       1 # Import personality Insights SDK
# ----> 2 from watson_developer_cloud import PersonalityInsightsV3
#       3
#       4
#       5 # Import Json
#
# ModuleNotFoundError: No module named 'watson_developer_cloud'

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# # Uso de Watson Personality Insights via SDK

# %% [markdown]
# IBM Cloud
# Para Usuarios de Windows
#
# Descargar e instalar primero
# - 1 .Instalar Nodejs y IBM Cloud CLI
# instaladores de Nodejs y IBM Cloud CLI :
#
# https://nodejs.org/es/
# https://github.com/IBM-Cloud/ibm-cloud-cli-release/releases/
#
# - 2 . Bajamos el Proyecto del repositorio y lo editamos
#     -https://github.com/ibmdevelopermx/PersonalityInsights
#     -Colocar las credenciales de servicio de IBM Cloud en el proyecto : (“apikey”: “xxxxxxxxxxxxxxxxxxxxxx”)
#     -configuramos el puerto que va a arrancar el proyecto WEB : const port = 8880;
#
# - 3 Abrir CMD e ir hasta la carpeta de del proyecto (para ejecución local)
#     - ejecutamos : npm install
#     - iniciamos el servicio : npm start
#     - abrimos la pagina local en el puerto configurado
#
# - 4 Abrir CMD e ir hasta la carpeta de del proyecto (para ejecución de pagina en IBM Cloud)
#     - ejecutamos : ibmcloud cf install
#     - ejecutamos : ibmcloud login
#     - colocamos las credenciales de IBM Cloud
#     - Seleccionamos la region
#     - respondemos las preguntas de enviar estadistas a IBM y de actualización de version
#     - ejecutamos : ibmcloud target --cf
#     - ejecutamos : ibmcloud cf push

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# # Watson Natural Language Classifier

# %% [markdown]
# El servicio Natural Language Classifier utiliza técnicas avanzadas de procesamiento del lenguaje natural y de aprendizaje de máquina para asignar categorías personalizadas a texto de entrada.
#
# **Recordar : No se permiten ñ ni acentos**
#
# ![Watson_FormasDeConsumo.JPG](../Watson_NaturalLanguageClassifier.png)
# ![Watson_FormasDeConsumo.JPG](../Watson_NaturalLanguageClassifier_Uso.png)
# ![Watson_FormasDeConsumo.JPG](../Watson_NaturalLanguageClassifier_Lenguajes.png)
# ![Watson_FormasDeConsumo.JPG](../Watson_NaturalLanguageClassifier_CasosDeUso.png)
# ![Watson_FormasDeConsumo.JPG](../Watson_NaturalLanguageClassifier_Consideraciones.png)

# %% [markdown]
# Ejercicios esta en el archvivo
# D:\Cursos\InteligenciaArtificial\dataset\IBM watson\curl_NatutalLenguageClassifier.txt

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# # Watson Natural Language Understanding - Analisis Sentimiento-

# %% [markdown]
# Utilice Natural Language Understanding (NLU) para analizar texto y extraer metadatos de contenido como por ejemplo conceptos, entidades, palabras clave, categorías, sentimiento, emoción, relaciones y roles semánticos.
#
# ![Watson_NaturalLanguageUnderstanding.png](attachment:Watson_NaturalLanguageUnderstanding.png)
# ![Watson_NaturalLanguageUnderstanding_Categorias.png](attachment:Watson_NaturalLanguageUnderstanding_Categorias.png)
#
# Para detallar las Entidades , Caracteristicas ver los siguientes enlaces:
#
# https://cloud.ibm.com/docs/natural-language-understanding?topic=natural-language-understanding-entity-types-version-1
#
# https://cloud.ibm.com/docs/natural-language-understanding?topic=natural-language-understanding-categories-hierarchy
#
# ![Watson_NaturalLanguageUnderstanding_Conceptos.png](attachment:Watson_NaturalLanguageUnderstanding_Conceptos.png)
# ![Watson_NaturalLanguageUnderstanding_Emocion.png](attachment:Watson_NaturalLanguageUnderstanding_Emocion.png)
#
# ![Watson_NaturalLanguageUnderstanding_Entidades.png](attachment:Watson_NaturalLanguageUnderstanding_Entidades.png)
# ![Watson_NaturalLanguageUnderstanding_PalabrasClave.png](attachment:Watson_NaturalLanguageUnderstanding_PalabrasClave.png)
# ![Watson_NaturalLanguageUnderstanding_Metadata.png](attachment:Watson_NaturalLanguageUnderstanding_Metadata.png)
# ![Watson_NaturalLanguageUnderstanding_Relaciones.png](attachment:Watson_NaturalLanguageUnderstanding_Relaciones.png)
# ![Watson_NaturalLanguageUnderstanding_RolesSemanticos.png](attachment:Watson_NaturalLanguageUnderstanding_RolesSemanticos.png)
# ![Watson_NaturalLanguageUnderstanding_Sentimiento.png](attachment:Watson_NaturalLanguageUnderstanding_Sentimiento.png)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Discovery

# %% [markdown]
# Discovery añade un motor de búsqueda cognitiva y análisis de contenido a las aplicaciones para identificar patrones, tendencias y conocimientos útiles que permitan una mejor toma de decisiones.
#
# ![Watson_Discovery.PNG](attachment:Watson_Discovery.PNG)
# ![Watson_Discovery1.PNG](attachment:Watson_Discovery1.PNG)
# ![Watson_Discovery_Pasos.PNG](attachment:Watson_Discovery_Pasos.PNG)
# ![Watson_Discovery_Assistant.PNG](attachment:Watson_Discovery_Assistant.PNG)
# ![Watson_Discovery_News.PNG](attachment:Watson_Discovery_News.PNG)
# ![Watson_Discovery_News1.PNG](attachment:Watson_Discovery_News1.PNG)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Introducción a Watson Knowledge Studio

# %% [markdown]
# Knowledge Studio permite enseñar a Watson el lenguaje de su dominio con modelos de aprendizaje automático personalizados que identifican entidades y relaciones exclusivas de su sector en texto no estructurado.
#
# ![Watson_KnowlegseStudio.PNG](attachment:Watson_KnowlegseStudio.PNG)
# ![Watson_KnowlegseStudio_Roles.PNG](attachment:Watson_KnowlegseStudio_Roles.PNG)
# ![Watson_KnowlegseStudio_Modelos.PNG](attachment:Watson_KnowlegseStudio_Modelos.PNG)
# ![Watson_KnowlegseStudio_TypeSystem.PNG](attachment:Watson_KnowlegseStudio_TypeSystem.PNG)
# ![Watson_KnowlegseStudio_MencionesEntidadesRelaciones.PNG](attachment:Watson_KnowlegseStudio_MencionesEntidadesRelaciones.PNG)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Entrenamiento de Watson Knowledge Studio

# %% [markdown]
# Los ejercicios estan en D:\Cursos\InteligenciaArtificial\dataset\IBM watson\Knowledge-studio

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Introducción a Watson Assistant

# %% [markdown]
# **Watson Assistant** permite crear interfaces de conversación en cualquier aplicación, dispositivo o canal.
# ![Watson_Assistant.PNG](attachment:Watson_Assistant.PNG)
# ![Watson_Assistant_Elementos.PNG](attachment:Watson_Assistant_Elementos.PNG)
#
# Siempre se recorre de manera secuencial preguntando si existe una intencion ó entidad ó una combinacion de ambas.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Implementación de Watson Assistant

# %% [markdown]
# Recuerda que para manejar operaciones y logicamente dentro de assistant usamos:<? ?>
#
# Webhooks: Nos permite consumir servicios de externos

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Funciones en Javascript

# %% [markdown]
# Debemos tener el dominio mínimo de lo que es una función para el proyecto final así como también para la clase functions. También es útil para la vida, en verdad debes saber que es una función si te vas a dedicar a ser un programador profesional.
#
# En Javascript todas las funciones son un objeto Function, estos objetos siempre tienen una respuesta que ejecutamos dentro de la función con la sentencia return. Por ejemplo, yo podría tener una función que solo me devolviera el mismo valor que le ingreso, se vería así:
#
# function main(params) {
# 	return {params}
# }
#
# Los parámetros que usamos en la llamada de la función son los argumentos de dicha función y los pasamos por valor. Una vez ingresados podemos hacer diferentes tipos de operaciones y transformaciones con estos parámetros. Por ejemplo:
#
# function main(params) {
#     return params+params;
# }
#
# En este caso simplemente estructuré los parámetros en un objeto, en donde la llave es doc y el valor son los mismos parámetros, es necesaria esa estructura para poder ingresar estos datos en Cloudant, una base de datos NoSQL.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Watson Speech to Text

# %% [markdown]
# El servicio Speech to Text convierte la voz humana en palabras escritas. Se puede utilizar en cualquier lugar donde se necesite llenar el hueco entre la palabra hablada y la forma escrita, incluido el control de voz de los sistemas incorporados, la transcripción de reuniones y teleconferencias y el dictado de correo electrónico y notas.
#
# ![SpeechToText.PNG](attachment:SpeechToText.PNG)
# ![SpeechToText_Interacciones.PNG](attachment:SpeechToText_Interacciones.PNG)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Watson Text to Speech

# %% [markdown]
# El servicio Text to Speech procesa texto y lenguaje natural para generar salida de audio sintetizada completa con la entonación y cadencia adecuadas.
#
# ![TextToSpeech.PNG](attachment:TextToSpeech.PNG)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Watson Voice Agent

# %% [markdown]
# Voice Agent with Watson mejora las operaciones del Call Center utilizando los servicios Watson e integrándolos en la red telefónica. Su agente de voz puede escuchar y responder a los clientes utilizando lenguaje natural. Soporta mensajes de texto SMS.
#
# Twilio es una plataforma de desarrollo que permite a los desarrolladores construir aplicaciones de comunicación en la nube y sistemas web. Las API de comunicaciones de Twilio permiten a las empresas proporcionar la experiencia de comunicación adecuada para sus clientes dentro de la web y las aplicaciones móviles. Al usar las API de Twilio, los desarrolladores pueden agregar rápidamente esta funcionalidad a una aplicación, como mensajes de voz, videollamadas, mensajes de texto y más.

# %% [markdown]
# ![VoiceAgent.PNG](attachment:VoiceAgent.PNG)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Introducción a Machine Learning y Watson Studio

# %% [markdown]
# ![Watson_MachingLearnig.JPG](attachment:Watson_MachingLearnig.JPG)
#
# IA no es lo mismos que ML, el primero es el campo general y ML es una sundivision que que se encarga de que las maquinas emulen la inteligencia humana , que aprendan como aprendemos nosotros.
#
# **Maching Learnig**
# - Aprendizaje Supervisado: Se dice que es supervisado porque existe una intervencion humana para entrenar la maquina.
#     - Regresion : Cualquien tipo de prediccion que tenga que ver con numeros , por ejemplo cuanto voy vender el siguiente mes,
#     - Clasificacion: Divide
#
# ![Watson_MachingLearnig_AS.JPG](attachment:Watson_MachingLearnig_AS.JPG)
#
# - Aprendizaje No Supervisado:
#     - Clusterizacion: Agrupacion, se utiliza mucho en las sugerencias que da Netflix al momento de elegir una pelicula.
#
# ![Watson_MachingLearnig_ANS.JPG](attachment:Watson_MachingLearnig_ANS.JPG)

# %% [markdown]
# **Watson Studio** democratiza el aprendizaje automático y el aprendizaje profundo para acelerar la infusión de la IA en su negocio para impulsar la innovación. Watson Studio proporciona un conjunto de herramientas y un entorno de colaboración para científicos de datos, desarrolladores y expertos en dominios.
#
# **Cloud Object Storage** es un servicio de almacenamiento en la nube altamente escalable, diseñado para una durabilidad, resiliencia y seguridad de primer nivel. Almacene, gestione y acceda a sus datos a través de nuestro portal de autoservicio y de las API RESTful. Conecte aplicaciones directamente con Cloud Object Storage y utilice otro servicio de IBM Cloud con sus datos.
#
# **Watson Machine Learning** (Desplegar los modelos entrenados como un servicio): Es una oferta de Bluemix de servicio completo que consigue que sea más fácil el trabajo en equipo entre desarrolladores y expertos en datos para integrar prestaciones predictivas con sus aplicaciones. El servicio Machine Learning es un conjunto de API REST a las que puede llamar desde cualquier lenguaje de programación para desarrollar aplicaciones que toman decisiones más inteligentes, resuelven problemas difíciles y mejoran los resultados de los usuarios.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Entrenamiento de modelo en Watson Studio Clasificacion

# %% [markdown]
# https://developer.ibm.com/series/learning-path-watson-studio/ Documentacion
#
# **Watson Modeler flows**: Permite entrenar el modelo por programacion por bloques
#
# "Proporciona un entorno interactivo para construir rápidamente pipeliones de aprendizaje automático de flujos de datos desde la ingestión hasta la transformación y la construcción y evaluación de modelos, sin necesidad de código."
#
# Super importante ese concepto de Sesgo ético de las predicciones. Para tenerlo muy en cuenta. IBM proporciona una herramienta para monitorear los sesgos de  los datos llamada Watson Open Scale.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Entrenamiento de clusterización en Watson Studio

# %% [markdown]
# **AI Fairness 360** es un kit de herramientas de código abierto extensible puede ayudarlo a examinar, informar y mitigar la discriminación y el sesgo en los modelos de aprendizaje automático a lo largo del ciclo de vida de la aplicación AI. Con más de 70 métricas de equidad y 10 algoritmos de mitigación de sesgos de última generación desarrollados por la comunidad investigadora, está diseñado para traducir la investigación algorítmica del laboratorio en la práctica real de dominios tan amplios como finanzas, gestión de capital humano, salud y educación.
#
# **AI Explainability 360** kit de herramientas extensible de código abierto puede ayudarlo a comprender cómo los modelos de aprendizaje automático predicen etiquetas por varios medios a lo largo del ciclo de vida de la aplicación de inteligencia artificial.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Reconocimiento Visual

# %% [markdown]
# Visual Recognition analiza imágenes de escenas, objeto,y otros contenidos. Seleccione un modelo predefinido o cree su propio clasificador personalizado. Desarrolle aplicaciones inteligentes que analizan el contenido visual de imágenes o fotogramas para comprender lo que sucede en una escena.
#
# ![VisualRecognition.PNG](attachment:VisualRecognition.PNG)
# ![VisualRecognition_Modelos.PNG](attachment:VisualRecognition_Modelos.PNG)
# ![VisualRecognition_ModeloPersonalizado.PNG](attachment:VisualRecognition_ModeloPersonalizado.PNG)
# ![VisualRecognition_Limitaciones.PNG](attachment:VisualRecognition_Limitaciones.PNG)
# ![VisualRecognition_LimitacionesConsumo.PNG](attachment:VisualRecognition_LimitacionesConsumo.PNG)
# ![VisualRecognition_BuenasPracticas.PNG](attachment:VisualRecognition_BuenasPracticas.PNG)
# ![VisualRecognition_BuenasPracticas2.PNG](attachment:VisualRecognition_BuenasPracticas2.PNG)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Functions + Cloudant

# %% [markdown]
# La diferencia entre una funcion y un servicio es:
# - La funcion no siempre esta desplegada, un servicio si
# - La funcion solo se consume cuando es llamada
# - La funcion puede a su ver llamar mas funciones y cada una puede estar en un lenguaje diferente
#
# **Cloud Functions** es una Plataforma de función como servicio (FaaS) basada en Apache OpenWhisk. Ejecute el código de aplicación sin servidores, escálelo de forma automática y no pague nada cuando no se utilice.
#
# **Cloudant** es una Base de Datos NoSQL que ofrece acceso a una capa de datos JSON completamente gestionadas que siempre están activos. Este servicio es compatible con CouchDB y se puede acceder al mismo a través de una interfaz HTTP fácil de utilizar para modelos de aplicaciones móviles web.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Exposición de funciones a través de una API
