# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Ingeniería de Datos con Python

# %% [markdown]
# En este curso vamos a explorar cuál es el proceso que se sigue en la ingeniería de datos para obtenerlos y datasets del mundo real de diferentes fuentes y lugares. Casi siempre estos datos vienen en un formato o estructura que no esta lista para el análisis adecuado.
#
# La ingeniería de datos se preocupan principalmente por implementar los pipelines que permiten automatizar la obtención de datos y su posterior limpieza para que otros profesionales de los datos(científicos de datos o expertos en machine learning) puedan realizar su labor. Son la primera parte de la cadena.
#
# Podrás entender el día a día de un ingeniero de datos y cómo colabora con el resto del equipo

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Repositorio
#
# Del curso en el cual encontrarás todo el proyecto dividido en secciones tal como se fue desarrollando:
# https://github.com/platzi/platziData/commits/master

# %% [markdown]
# <div class="alert alert-block alert-danger"> <h1>Librerias a Utilizar en el Curso

# %%
from datetime import datetime
from IPython.display import Image
import requests
import bs4
import pandas as pd
import os
from IPython.display import display
from urllib.parse import urlparse #proporciona funciones para manipular URLs y sus componentes, para descomponerlas o construirlas
import hashlib #Genera un hash para tener un numero unico
import re #Para trabajar con expresiones regulare
import nltk #Tokenizar,separar palabras dentro del título y nos permitirá contar la frecuencia de cuántas palabras existen 
from nltk.corpus import stopwords #Palabras que no añaden ningun tipo de informacion ejm el ,la , los...
import numpy as np
# %matplotlib inline #Mostrar graficos en linea

#nltk.download('punkt')
#nltk.download('stopwords') Se debn descargar una sola vez
# Out:
# UsageError: unrecognized arguments: #Mostrar graficos en linea

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Qué es la Ciencia e Ingeniería de Datos

# %% [markdown]
# La Ciencia de Datos es la disciplina que se encarga de extraer conocimiento de los datos disponible. Casi siempre cuando te realizas una pregunta sobre datos estas fuentes se encuentran escondidas, ocultas o de difícil acceso. A nuestro alrededor hay datos en tu computadora, mesa, reloj, etc. Por ejemplo, una mesa tiene datos: longitudes, marcas, año de fabricación, etc.
#
# Los datos están por todas partes.
#
# La Ciencia de datos es multidisciplinaria. A diferencia de muchos otros ámbitos profesionales dentro del mundo de la tecnología cuando hablamos de un científico de datos es una persona que sabe de matemáticas, ingeniería de software y sabe de negocios.Si únicamente se tiene una de esas disciplinas, difícilmente se podrá trabajar de manera efectiva.
#
# Se apoya en:
#
# • Computer science: Las computadoras son la mejor herramienta para procesar datos. Se apoya de algoritmos, estructura de datos, visualizaciones que nos puede dar la computadora, conectar varias computadoras en paralelo en la nube, programación.
#
# • Estadística (Math): se realizan regresiones, inferencias, identificación de variables y relación de variables.
#
# • Conocimiento del dominio: Conocimiento sobre el negocio donde trabajamos. Hacer las preguntas correctas para interpretar los resultados correctamente.
#
# Se auxilia de:
#
# • Bases de datos: SQL (MySQL y Postgress) y NoSQL(Cassandra, Spark, etc).
#
# • Análisis de texto y procesamiento de lenguaje natural.
#
# • Análisis número de datos y minado de datos.
#
# • Análisis de redes: Nodos y sus conexiones. Teoría de grafos
#
# • Visualización de datos: Permite entender, contar historia sobre los datos y analizarlos rápidamente.
#
# • Machine Learning e Inteligencia Artificial: Predecir y determinar el futuro.
#
# • Análisis de señales digitales: Análisis de datos en tiempo real.
#
# • Análisis de datos en la nube (Big Data): Data center que podemos utilizar eficientemente para procesar grandes cantidades de datos

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Roles

# %% [markdown]
# Existen por lo menos tres diferentes roles para tener un pipeline completo de ciencia de datos. Este curso trata sobre el primer rol:
#
# **Data engineer**: Se encarga de obtener los datos, Limpiarlos y estructurarlos para posterior análisis, crear pipelines de análisis automatizado, utilización de herramientas en la nube, análisis descriptivo de los datos.
#
# **Data scientist**: Una vez tiene los datos se encarga de generar el análisis matemático de ellos, encontrar las relaciones entre las variables, las correlaciones, las causas y por último genera los modelos predictivos y prescriptivos.
#
# **Machine Learning engineer**: Se encarga de llevar las predicciones a escala, de subirlos a la nube y allí generar muchas predicciones. Se encarga de mantener la calidad del modelo.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Configuración del ambiente

# %% [markdown]
# Anaconda es una instalación de Python que ya trae preinstalado todos los paquetes necesarios para tu labor en la Ciencia de Datos, tiene más de 1400 paquetes. Nos permite configurar ambientes virtuales para poder utilizar diferentes versiones de nuestros paquetes.
#
# - conda --version para conocer la versión y saber que lo tenemos instalado
# - conda --help nos da todos los comandos que podemos usar.
# - conda list nos lista todos los paquetes que Anaconda instaló.
#
# Una buena práctica es generar un ambiente virtual por cada proyecto, los ambientes virtuales nos permiten generar varios proyectos con diferentes versiones de la librería sin generarnos errores de compatibilidad. Tradicionalmente en Python se utiliza virtualenv
#
# - conda create --name [nombre-del-proyecto] [librerías-a-usar]
# - conda create --name platzi_data beautifulsoup4 requests numpy pandas matplotlib yaml
#
# - Para activar source activate platzi_data
# - Para salir source deactivate
# - conda env list nos muestra los ambientes virtuales que tenemos
# - conda remove --name [nombre-del-proyecto] --alleliminar nuestro entorno virtual con todos nuestros paquetes
#
# Librerias utilizadas:
#
# - beautifulsoup4 = parsear y manipular HTML
# - requests = generar solicitudes a la web
# - numpy = análisis numéricos de nuestros datos
# - pandas = analizar, modificar, transformar datos y generar análisis descriptivos sobre los mismos
# - matplotlib = generar visualizaciones de nuestros datos
# - yaml =archivo similar a Json, permite generar algunas configuraciones

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Jupyter Notebooks

# %% [markdown]
# Algo interesante que tenemos con Anaconda es que nos trae Jupyter Notebooks.
#
# Jupyter Notebooks es un entorno de programación en el cual podemos mezclar ejecución de código en vivo, visualizaciones y añadir markdown.
#
# jupyter notebook para inicializar nuestro servidor de jupyter
#
# Jupyter Notebook tiene diferentes tipos de celdas en las cuales podemos escribir código o markdown. Si queremos ejecutar nuestro código hacemos ctrl + enter y si queremos ejecutar y añadir una nueva celda shift + enter.
#
# Jupyter Notebook tiene dos modalidades, la modalidad de edición y navegación.

# %% [markdown]
# En resumen:
# Se inicializa el servidor de Jupiter Notebook en la consola de anaconda así: jupyter notebook.
#
# Luego en el ambiente de jupyter se aplican los siguientes comandos:
# - Enter para: modo edición
# - Para Ejecutar: (1. una linea: control + enter) (2. Ejecuta la Linea y añade otra: shift + enter)
# - ESC: dentro de una celda entrar al modo de navegación. (el borde izquierdo de la celda se resalta en azul)
# - K: mover hacia arriba
# - J: mover hacia abajo
# - B: Agregar nueva celda
# - M Convertir en MarkDown
# - P: Acceder a la línea de comando
# - DD: Eliminar Celda
#
# **Algunas funciones de jupyter: **permite explorar codigo de manera rápida. Incluir visualizaciones de Matplotlib. Agregar imagenes. acceder a la web, entre otras opciones que permite.
#
# ![JupyterNotebook_atajosdeteclado.webp](attachment:JupyterNotebook_atajosdeteclado.webp)

# %% [markdown]
#  <div class="alert alert-block alert-success">
#
# # Profundizando en tipos de datos

# %% [markdown]
# Los datos vienen en muchas formas y estas formas las podemos clasificar de diferentes maneras, permitiéndonos poder aplicar técnicas distintas a cada uno de los tipos de datos.

# %% [markdown]
# ###  Primitivos
#
# int , str , bool, float, hex, oct, datetime, objetos especiales(clases).
# Tenemos clasificaciones ulteriores como los datos estructurados, semi estructurados y no estructurados.

# %%
from datetime import datetime

integer_type = 42
floar_type = 3.14159
bool_type = False
hex_type = 0xff
print('El número hex_type 0xff es igual a: {} en decimal\n'.format(hex_type))
oct_type = 0o23
print('El número oct_type 0o23 es igual a: {} en decimal\n'.format(oct_type))
today =  datetime.now()
print('Hoy es: {}'.format(today))
str_type = 'Jhon'
# Out:
# El número hex_type 0xff es igual a: 255 en decimal
#
# El número oct_type 0o23 es igual a: 19 en decimal
#
# Hoy es: 2021-03-30 10:34:05.635226

# %% [markdown]
# ### Estructurados
#
# Los estructurados son los más fáciles de acceder a su información.
#
#     Bases de datos
#     Data warehouses

# %%
from IPython.display import Image

Image('D:\Cursos\InteligenciaArtificial\MySQL-table.png')

# %% [markdown]
# ### Semi estructurados

# %% [markdown]
# Los semi estructurados son donde podemos usar las APIs.
#
#     Json APIs
#     Datos tabulares(csv, excel)
#     HTML

# %%
Image('D:\Cursos\InteligenciaArtificial\HTML-markup-ex1.png')

# %% [markdown]
# ### No estructurados

# %% [markdown]
# Los no estructurados son la mayoría de los datos que te vas a encontrar en tu desarrollo profesional.
#
#     Texto libre
#     Curriculum vitaes
#     Imagenes, audios, social media
#     Datos cientificos

# %% [markdown]
# zen de python
#
# Beautiful is better than ugly.
#
# Explicit is better than implicit.
#
# Simple is better than complex.
#
# Complex is better than complicated.
#
# Flat is better than nested.
#
# Sparse is better than dense.
#
# Readability counts.
#
# Special cases aren’t special enough to break the rules.
#
# Although practicality beats purity.
#
# Errors should never pass silently.
#
# Unless explicitly silenced.
#
# In the face of ambiguity, refuse the temptation to guess.
#
# There should be one-- and preferably only one --obvious way to do it.
#
# Although that way may not be obvious at first unless you’re Dutch.
#
# Now is better than never.
#
# Although never is often better than right now.
#
# If the implementation is hard to explain, it’s a bad idea.
#
# If the implementation is easy to explain, it may be a good idea.
#
# Namespaces are one honking great idea – let’s do more of those!

# %% [markdown]
#  <div class="alert alert-block alert-success">
#
# # Fuentes de datos

# %% [markdown]
# - Web
#
# Es una mina enorme con datos financieros, de startups, del clima, precipitación fluvial, astronómicos, de negocios, etc.
#
# https://datasetsearch.research.google.com/
# https://www.datos.gov.co/
# https://www.kaggle.com/
#
# - APIs
#
# Endpoints que viven en la web y nos devuelven JSON. Por ejemplo, la API de twitter, google, facebook.
#
# - User Analytics
#
# Son el comportamiento del usuario dentro de nuestra aplicaciones, algo similar a los que nos ofrece Google Analytics.
#
# - IoT
#
# Se ha vuelto una mina espectacular en los últimos años. Como automóviles.

# %% [markdown]
#  <div class="alert alert-block alert-success">
#
# # ETL

# %% [markdown]
# ETL = Extract Transform Load
#
# - **Extract**: Es el proceso de lectura de datos de diversas fuentes
#
# Base de datos
# CRM
# Archivos CSV
# Datasets públicos
#
# - **Transform**: En este momento cuando nosotros tenemos que transformar los datos, tenemos que identificar datos faltantes o datos erróneos o una edad negativa. En esta etapa donde tenemos que identificar todos los problemas y solucionarlos.
#
# Limpieza
# Estructurado
# Enriquecimiento.
#
# - **Load**: Una vez transformados debemos insertarlos en el data warehouse
#
# Depende del tipo de solución que se haya escogido
#
# ![Etl.JPG](attachment:Etl.JPG)

# %% [markdown]
#  <div class="alert alert-block alert-success">
#
# # Introducción a las tecnologías web

# %% [markdown]
# Las tecnologías web en principio podemos pensarlas como el internet, pero el internet es mucho más grande, es la red de redes, la forma en la que millones de computadores se conectan entre ellas para transferirse información.
#
# El internet también se compone de otros pedazos como telefonía(voip), mail(pop3, imap), compartir archivos(ftp). El internet es una red que une varias redes públicas, privadas, académicas, de negocios, de gobiernos, etc.
#
# La **web** específicamente es un espacio de información en el cual varios documentos(y otros recursos web) se pueden acceder a través de URLs y vínculos(links). La comunicación se da a través del protocolo **HTTP**.
#
# Elementos básicos de la web:
#
# - HTML: nos da la estructura de la información. Es un lenguaje para anotar pedazos de información para que el navegador o otros tipos de programa puedan interpretar que tipo de información se encuentra ahí.
# - CSS: nos permite darle colores, arreglar el texto y añadir diferentes elementos de presentación.
# - Javascript: nos permite añadir interactividad y cómputo a nuestra web.
# - JSON: Simplemente es una forma de transmitir datos entre servidores y clientes. Es la forma estándar en las que en la web y las aplicaciones se comunican con los servidores backend.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Realizar solicitudes HTTP con Python

# %% [markdown]
# Para poder experimentar con la web necesitamos un método programático para solicitar URLs y obtener HTML
#
# **Requests**: Nos permite generar solicitudes a la web dentro de Python y utilizar los diferentes verbos HTTP, normalmente utilizaremos el método GET porque vamos a traer datos. PEro existen otros como,:
#
#
# - GET
# Se emplea para leer una representación de un resource. En caso de respuesta positiva (200 OK), GET devuelve la representación en un formato concreto: HTML, XML, JSON o imágenes, JavaScript, CSS, etc. En caso de respuesta negativa devuelve 404 (not found) o 400 (bad request)
#
# - POST
# Aunque se puedan enviar datos a través del método GET, en muchos casos se utiliza POST por las limitaciones de GET. En caso de respuesta positiva devuelve 201 (created)
#
# - PUT
# Utilizado normalmente para actualizar contenidos, pero también pueden crearlos. Tampoco muestra ninguna información en la URL. En caso de éxito devuelve 201 (created, en caso de que la acción haya creado un elemento) o 204 (no response, si el servidor no devuelve ningún contenido). A diferencia de POST es idempotente, si se crea o edita un resource con PUT y se hace el mismo request otra vez, el resource todavía está ahí y mantiene el mismo estado que en la primera llamada
#
# - DELETE
# Simplemente elimina un resource identificado en la URI. Si se elimina correctamente devuelve 200 junto con un body response, o 204 sin body. DELETE, al igual que PUT y GET, también es idempotente
#
# Ejemplo:
#
# ***requests.get('url') para hacer una solicitud a la web y nos devolverá un objeto response***
#
# Todas las solicitudes HTTP tienen metadatos para que los diferentes sistemas y computadoras puedan entender de qué va la solicitud.

# %%
import requests

response = requests.get('https://www.platzi.com')

# %%
#response? #Informacion del objeto
#response?? #Documentacion de la implementacion del objeto
print(dir(response)) # NOs informa de todos los metodos que tiene el objeto

# %% [markdown]
# **Códigos de estado**
#
# Lo primero que podemos hacer es verificar el código de estado. Los códigos HTTP van de “1XX” a “5XX”. Los códigos de estado frecuentes que probablemente haya visto son “200”, “404” y “500”.
#
# A continuación, le ofrecemos una descripción general rápida del significado de cada código de estado:
#
# - 1XX: información
# - 2XX: éxito
# - 3XX: redireccionamiento
# - 4XX: error del cliente (usted cometió un error)
# - 5XX: error del servidor (se cometió un error en este)
#
# En general, al realizar sus propias solicitudes lo que busca son códigos de estado del orden del 200.
#
# Requests reconoce que los códigos de estado 4XX y 5XX son errores. Por lo tanto, si se muestran estos códigos de estado, el objeto de respuesta de la solicitud se evalúa como False.

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.headers) #Encabezado de la respuesta
# Out:
# {'Date': 'Tue, 30 Mar 2021 15:37:17 GMT', 'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d6e4b6c9fcce2572cc0003fdf130366b71617118637; expires=Thu, 29-Apr-21 15:37:17 GMT; path=/; domain=.platzi.com; HttpOnly; SameSite=Lax; Secure', 'CF-Ray': '63826b1edb42041c-MIA', 'Access-Control-Allow-Origin': '*', 'Age': '20547', 'Cache-Control': 'no-store', 'Expires': 'Wed, 30 Mar 2022 15:37:17 GMT', 'Strict-Transport-Security': 'max-age=2592000; includeSubDomains; preload', 'Vary': 'Accept-Encoding', 'CF-Cache-Status': 'HIT', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Headers': 'X-Requested-With,content-type,X-CSRFToken', 'Access-Control-Allow-Methods': 'GET, POST', 'cf-request-id': '09256147520000041c042bf000000001', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'X-Content-Type-Options': 'nosniff', 'X-DNS-Prefetch-Control': 'off', 'X-Download-Options
# ...

# %%
print(response.request.headers) #Encabezado de la salida
# Out:
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '__cf_bm=045cb7d77ce8157f2b956798e9236e21cdc977dc-1617118637-1800-AQs8veIsfbte2J5Nj+vpNNqWAcrNE3jQrjzv78mL3B1sfB/cj713TbjK3VB1+5dnGezDMzTF0/fhRtClzwsNJjP7gyUxXbuAlnlFNqjoKrFm'}

# %%
print(response.headers['Date'])
# Out:
# Tue, 30 Mar 2021 15:37:17 GMT

# %%
response.request.method #Metodo que utilizamos
# Out:
# 'GET'

# %%
response.request.url
# Out:
# 'https://platzi.com/'

# %%
for i in response.headers:
    print(i + ": " + response.headers[i])
# Out:
# Date: Tue, 30 Mar 2021 15:37:17 GMT
# Content-Type: text/html
# Transfer-Encoding: chunked
# Connection: keep-alive
# Set-Cookie: __cfduid=d6e4b6c9fcce2572cc0003fdf130366b71617118637; expires=Thu, 29-Apr-21 15:37:17 GMT; path=/; domain=.platzi.com; HttpOnly; SameSite=Lax; Secure
# CF-Ray: 63826b1edb42041c-MIA
# Access-Control-Allow-Origin: *
# Age: 20547
# Cache-Control: no-store
# Expires: Wed, 30 Mar 2022 15:37:17 GMT
# Strict-Transport-Security: max-age=2592000; includeSubDomains; preload
# Vary: Accept-Encoding
# CF-Cache-Status: HIT
# Access-Control-Allow-Credentials: true
# Access-Control-Allow-Headers: X-Requested-With,content-type,X-CSRFToken
# Access-Control-Allow-Methods: GET, POST
# cf-request-id: 09256147520000041c042bf000000001
# Expect-CT: max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"
# X-Content-Type-Options: nosniff
# X-DNS-Prefetch-Control: off
# X-Download-Options: noopen
# X-Frame-Options: SAMEORIGIN
# ...

# %%
print(response.text)
# Out:
#     <!doctype html>
#       <html lang=es-CO>
#         <head>
#           <meta charset="UTF-8">
#
#           <meta name="viewport" content="width=device-width, initial-scale=1" />
#           <title>🚀Platzi: ‎Cursos Online Profesionales de Tecnología</title>
#           <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-svg-core@1.2.28/styles.css">
#           <link rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/home.ab9064d99216ee788332.css" type="text/css" />
#           <link rel="shortcut icon" href="//static.platzi.com/media/favicons/platzi_favicon.png" />
#           <link rel="icon" sizes="192x192" href="//static.platzi.com/media/favicons/platzi_favicon.png">
#           <link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="" />
#
# ...

# %%
response.encoding
# Out:
# 'ISO-8859-1'

# %%
#Cambiar el encoding del response
#response.encoding = 'ISO-8859-1'
response.encoding = 'utf-8'

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # ¿Cómo trabajar con un documento HTML?

# %% [markdown]
# En el caso de Python la librería estándar para manipular los documentos HTML se llama **BeautifulSoup**.
#
# **BeautifulSoup** nos ayuda a organizar gramaticalmente(parsear) el documento HTML para que tengamos una estructura con la cual podamos manejar y extraer información. BeautifulSoup convierte el string de HTML en un árbol de nodos para poder manipularlo.
#
# Para manipularlo podemos usar los selectores CSS con soup.select()

# %%
import bs4
response = requests.get('https://www.platzi.com')
response.encoding = 'utf-8'
soup = bs4.BeautifulSoup(response.text,'html.parser')
print(soup.title.text) #Seleccion el Titulo de la pagina
# Out:
# Platzi: ‎Cursos Online Profesionales de Tecnología

# %%
print(soup.select('meta[name = description]')[0]['content'])
# Out:
# Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!

# %%
courses_links = soup.select('.HomeCategories-anchor')
print(courses_links)
print('Numero de Cursos: {}'.format(len(courses_links)))

#courses = [course['href'] for course in courses_links]
courses = []
for course in courser_links:
    courses.append(course['href'])


for course in courses:
    print(course)
    
for i in range(len(courses_links)):
    print(i+1,courses_links[i].h2.text,':',courses_links[i]['href'])
# Out:
# [<a class="HomeCategories-anchor" href="/categorias/desarrollo/"><div class="HomeCategories-item HomeCategories-desarrollo"><div class="HomeCategories-badge" style="background-color:#33b13a"><img alt="Desarrollo e ingeniería" loading="lazy" src="https://static.platzi.com/mf-landings/image/ico-desarrollo-fa207491a4cb7b6be3e3ab41b1fecced.png"/></div><div class="HomeCategories-category"><h2>Desarrollo e ingeniería</h2><span>423<!-- --> <!-- -->cursos</span></div></div></a>, <a class="HomeCategories-anchor" href="/categorias/diseno/"><div class="HomeCategories-item HomeCategories-diseno"><div class="HomeCategories-badge" style="background-color:#6b407e"><img alt="Diseño y UX" loading="lazy" src="https://static.platzi.com/mf-landings/image/ico-diseno-1aeccde1b13a43e07474c34d0f261c66.png"/></div><div class="HomeCategories-category"><h2>Diseño y UX</h2><span>84<!-- --> <!-- -->cursos</span></div></div></a>, <a class="HomeCategories-anchor" href="/categorias/marketing/"><div class="HomeCateg
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Analizando un sitio web para encontrar las directivas a utilizar al hacer un web scrapping

# %% [markdown]
# Para poder desarrollar scrapers debemos entender los datos semi estructurados dados por el HTML para determinar qué tipo de selectores CSS necesitamos para sacar información.

# %%
url ='https://www.elcolombiano.com/antioquia/fin-al-estado-de-cuidado-total-en-medellin-comercio-podra-abrir-los-fines-de-semana-PO13480258'
#url ='https://www.futbolred.com/futbol-colombiano/liga-aguila/america-sergi-escobar-asistente-espanol-de-juan-cruz-real-colombia-hoy-122386'
#response_elcolombiano = requests.get('https://www.elcolombiano.com/')
response_elcolombiano = requests.get(url)
response_elcolombiano.encoding = 'utf-8'
soup = bs4.BeautifulSoup(response_elcolombiano.text,'html.parser')

print(soup.title.text) #Seleccion el Titulo de la pagina
# Out:
# Qué sigue luego de los cierres estrictos los fines de semana

# %%
print(soup)
# Out:
#  <!DOCTYPE html>
#  <html class="ltr" dir="ltr" lang="es-ES"> <head> <meta content="text/html; charset=utf-8" http-equiv="content-type"/> <title>Qué sigue luego de los cierres estrictos los fines de semana</title> <link href="https://www.elcolombiano.com/base-portlet/webrsrc/ctxvar/7bacdb4bae8c4a41855e25ae67d07716.jpeg" rel="shortcut icon"/> <style amp-custom=""> .mln_uppercase_mln
# 		{
# 			text-transform:uppercase
# 		}
#
# 		.mln_small-caps_mln
# 		{
# 			font-variant:small-caps
# 		}
# ...

# %%
#links_noticias = soup.select('.noticia-segundaria')
links_noticias = soup.select('.noticia p')
print(links_noticias)
# Out:
# [<p>Los 10 alcaldes del área metropolitana acordaron el pasado fin de semana terminar la estrategia 4-3 que desde hace más de un mes venía operando los fines de semana y que consistía en cuatro días de apertura para el comercio y la industria, por tres días de cierre. </p>, <p>La decisión, explicó Braulio Espinosa, alcalde de Envigado, fue unánime y obedeció a dos factores: que “el pico” de contagios se aplanó y se convirtió en una meseta, y que los cierres estaban dejando grandes impactos económicos. </p>, <p>“Hay que... </p>]

# %%
len(links_noticias)
parrafos=''
for parrafo in links_noticias:
    parrafos += parrafo.text
print(parrafos)
# Out:
# Los 10 alcaldes del área metropolitana acordaron el pasado fin de semana terminar la estrategia 4-3 que desde hace más de un mes venía operando los fines de semana y que consistía en cuatro días de apertura para el comercio y la industria, por tres días de cierre. La decisión, explicó Braulio Espinosa, alcalde de Envigado, fue unánime y obedeció a dos factores: que “el pico” de contagios se aplanó y se convirtió en una meseta, y que los cierres estaban dejando grandes impactos económicos. “Hay que...

# %%
# Ingrseando un nivel mas abajo
links_noticias2 = soup.select('.noticia-segundaria div')
print(links_noticias2)
# Out:
# [<div class="left"> <a href="/colombia/uribe-una-carrera-publica-a-traves-de-cuatro-decadas-EC13444514"> <div frame="Segundo_Nivel" style="position: relative; width: 100%; padding-top: 68.97%; background-color: #000000"> <img alt="Álvaro Uribe Vélez ha salido victorioso en siete elecciones; cuatro para el Senado, una para la Gobernación de Antioquia y dos para la Presidencia de la República. FOTO Colprensa" height="100" itercontenttypein="TeaserImage" itercontenttypeout="Image" iterimgid="36184020" src="//www.elcolombiano.com/documents/10157/0/145x107/0c0/145d100/none/11101/DYKT/image_content_36184020_20200811173622.jpg" srcset="//www.elcolombiano.com/documents/10157/0/145x107/0c0/145d100/none/11101/DYKT/image_content_36184020_20200811173622.jpg 145w" style="bottom: 0; left: 0; top: 0; right: 0;
# height: auto; width: auto;
# max-height: 100%; max-width: 100%;
# ...

# %%
links = [noticias.a for noticias in links_noticias]
for link in links:
    print(link)
# Out:
# <a href="/negocios/economia/petroleo-retorna-de-a-poco-a-la-normalidad-LA13469460"> <div frame="Segundo_Nivel" style="position: relative; width: 100%; padding-top: 68.97%; background-color: #000000"> <img alt="El petróleo empieza a reportar normalidad. FOTO: COLPRENSA" height="100" itercontenttypein="TeaserImage" itercontenttypeout="Image" iterimgid="36215774" src="//www.elcolombiano.com/documents/10157/0/159x100/7c0/145d100/none/11101/GTKF/image_content_36215774_20200816113826.jpg" srcset="//www.elcolombiano.com/documents/10157/0/159x100/7c0/145d100/none/11101/GTKF/image_content_36215774_20200816113826.jpg 145w" style="bottom: 0; left: 0; top: 0; right: 0;
# height: auto; width: auto;
# max-height: 100%; max-width: 100%;
# display: block; position: absolute; margin: auto;" title="El petróleo empieza a reportar normalidad. FOTO: COLPRENSA" width="145"/> </div> </a>
# ...

# %%
for count, noticia in enumerate(links_noticias):
    print('{}. Titulo: {} '.format(count+1,noticia.text),'Link: ', noticia.a['href'],' Contenido:',noticia.img['title'])
# Out:
# 1. Titulo:            Colombia | 12:00 AM
#                    Uribe, una carrera pública a través de cuatro décadas       Link:  /colombia/uribe-una-carrera-publica-a-traves-de-cuatro-decadas-EC13444514  Contenido: Álvaro Uribe Vélez ha salido victorioso en siete elecciones; cuatro para el Senado, una para la Gobernación de Antioquia y dos para la Presidencia de la República. FOTO Colprensa
# 2. Titulo:             Colombia | 12:00 AM
#                    Abrirán los cielos de seis municipios        Link:  /colombia/estos-son-los-seis-aeropuertos-que-comenzaran-a-operar-NC13446308  Contenido: El José María Cordová es uno de los aeropuertos que iniciarán operaciones. FOTO: Camilo Suárez
# 3. Titulo:            Negocios | 12:00 AM
#                    Nueva normalidad para la declaración de renta       Link:  /negocios/nueva-normalidad-para-la-declaracion-de-renta-OC13445847  Contenido: FOTO: Colprensa.
# 4. Titulo:            Colombia | 12:00 AM
# ...

# %%
for count, noticia in enumerate(links_noticias):
    print('{}. Titulo: {} '.format(count+1,noticia.text),'Link: ', noticia.a['href'],' Contenido:',noticia.img['title'])
# Out:
# 1. Titulo:            Colombia | 12:00 AM
#                    Uribe, una carrera pública a través de cuatro décadas       Link:  /colombia/uribe-una-carrera-publica-a-traves-de-cuatro-decadas-EC13444514  Contenido: Álvaro Uribe Vélez ha salido victorioso en siete elecciones; cuatro para el Senado, una para la Gobernación de Antioquia y dos para la Presidencia de la República. FOTO Colprensa
# 2. Titulo:             Colombia | 12:00 AM
#                    Abrirán los cielos de seis municipios        Link:  /colombia/estos-son-los-seis-aeropuertos-que-comenzaran-a-operar-NC13446308  Contenido: El José María Cordová es uno de los aeropuertos que iniciarán operaciones. FOTO: Camilo Suárez
# 3. Titulo:            Negocios | 12:00 AM
#                    Nueva normalidad para la declaración de renta       Link:  /negocios/nueva-normalidad-para-la-declaracion-de-renta-OC13445847  Contenido: FOTO: Colprensa.
# 4. Titulo:            Colombia | 12:00 AM
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Solicitudes a la web: Requests

# %% [markdown]
# Un buen Data engineer utiliza los conceptos de la ingeniería de software para poder desarrollar sus programa. En nuestro caso para poder desarrollar nos apoyaremos de un patrón.
#
# **Page Object Patter**: Es un patrón que consiste en esconder los queries especificos que se utilizan para manipular un documento HTML detrás de un objeto que representa la página web.
#
# Si estos queries se añaden directamente al código principal, el código se vuelve frágil y va a depender mucho de la modificación que hagan a la web otras personas y arreglarlo se vuelve muy complicado.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Implementando nuestro web scrapper: Configuración

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Ejercicio completo esta en la siguiente ruta : <code>***D:\Cursos\Python\Python\Scraping\WebScraping_Data_Ing***</code>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Introducción a Pandas

# %% [markdown]
# Pandas nos otorga diversas facilidades para el ““domados de datos””. Nos otorga dos estructuras de datos:
#
# - Series: Es un array unidimensional que representa una columna.
# - DataFrame: Es un conjunto de series que forman una tabla. Se pueden acceder a través de indices como una etiqueta(label) o pueden ser posicionales es decir 0 o índice 100. También pueden ser rangos o slices
#
# Estas estructuras de datos no son contenedores de datos, son estructuras intermedias.
# - En Pandas las utilizamos para transformar y enriquecer nuestros datos,
#     - manipularlos,
#     - manejar los faltantes,
#     - realizar operaciones aritméticas y booleanos,
#     - combinar diferentes dataframes en uno solo para obtener una nueva tabla.
#     - leeer datos de archivos y escrbir a disco

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Estructura de datos: Series

# %% [markdown]
# Series es un vector unidimensional, para poder acceder a esta lista podemos usar posiciones o **labels**, siendo este último el preferido para manipular las series. Una diferencia importante sobre las listas de Python es que los datos son homogéneos, es decir solo podemos tener **un tipo de dato** por cada Serie.
#
# Las Series se pueden crear a partir de cualquier secuencia(listas, tuplas, arrays de numpy y diccionarios).
# - Ejemplo: series = ps.Series([1,2,3])
#
# En Python tenemos la filosofía del Duck Typing, si se ve como un pato y hace cuac, a ese animal le llamamos pato, si una serie se comporta una lista, se accede como una lista en principio deberíamos llamarla lista, pero esto no es así.
#
# Una mejor aproximación para inicializar Series es utilizar diccionarios.
# - Ejemplo: pd.Series({'a':1,'b':2,'c':3})

# %%
series_test = pd.Series([100,200,300])
series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({1999:48,
                           2000:65,
                           2001:89})
series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %%
series_test3 = pd.Series([11,13,17,19],
                index = ['a','b','c','d'])
series_test3
# Out:
# a    11
# b    13
# c    17
# d    19
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Estructura de datos: DataFrames

# %% [markdown]
# - DataFrames son simplemente una tabla donde las filas y las columnas tienen etiquetas.
# - Se puede construir de diferentes formas pero siempre debemos considerar que la estructura que necesitamos construir para inicializarla tiene que ser bidimensional (una matriz) y puede ser una lista de listas, lista de tuplas, un diccionario de Python u otro DataFrame.
# - Si solo tenemos una dimensión a eso **no** le llamamos DataFrame, le llamamos Serie.
# - Cuando utilizamos un diccionario las llaves se convierten en las llaves de la columna.
# - Cuando utilizamos una lista podemos utilizar el parametro opcional columns

# %%
frame_test = pd.DataFrame({1999:[74,39,39],
                          2000: [34,32,32],
                          2001: [39,23,23]})
frame_test
# Out:
#    1999  2000  2001
# 0    74    34    39
# 1    39    32    23
# 2    39    32    23

# %%
 frame_test2 = pd.DataFrame([[74,39,39],
                           [34,32,32],
                           [39,23,23]],
                           columns = [1999,2000,2001])
frame_test2
# Out:
#    1999  2000  2001
# 0    74    39    39
# 1    34    32    32
# 2    39    23    23

# %%
 frame_test3 = pd.DataFrame([[74,39,39],
                           [34,32,32],
                           [39,23,23]],
                           columns = [1999,2000,2001],
                          index = ['a','b','c'])
frame_test3
# Out:
#    1999  2000  2001
# a    74    39    39
# b    34    32    32
# c    39    23    23

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Índices y selección

# %% [markdown]
# Existen muchas formas de manipular los DataFrames y de seleccionar los elementos que queremos transformar.
#
# - Dictionary like:
#
#     - df[`col1`] # Regresa un DataSeries
#     - df[['col1', 'col3']] # Regresa un DataFrame
#
#
# - Numpy like:
# iloc = index location
#     - df.iloc[:] # Fila
#     - df.iloc[:,:] # Fila,  columna
#
#
# - Label based:
# loc = location
#     - df.loc[:] # Fila
#     - df.loc[:,:] # Fila,  columna
#
# Existe una gran diferencia en la forma en la que utilizamos estos slices porque varia de la forma tradicional de Python. loc va a incluir el final del que necesitamos.

# %% [markdown]
# ### Read data

# %%
mainpath = "/Cursos/Python/Python/Scraping/WebScraping_Data_Ing"
filename = "elcolombiano_2020_08_20_articles.csv"
#fullpath = mainpath + "/" + filename
fullpath = os.path.join(mainpath,filename)

el_colombiano = pd.read_csv(fullpath, encoding='utf-8')
display(type(el_colombiano))
display(el_colombiano)
# Out:
# pandas.core.frame.DataFrame
#                                                  body  \
# 0   La inscripción de la candidatura a vicepreside...
# 1   El extremo colombiano Yony González se convirt...
# 2   Este miércoles, según versiones preliminares, ...
# 3   Si se revisa el mapa del continente, la mayorí...
# 4   El ministro de Hacienda, Alberto Carrasquilla,...
# ..                                                ...
# 26  Emilio Lozoya, exdirector de Petróleos Mexican...
# 27  Pasaron 24 semanas, 166 días y se aplicaron 2,...
# 28   La senadora negra Kamala Harris aceptó el mié...
# 29  El Servicio Geológico Colombiano confirmó este...
# 30  La Federación Nacional de Comerciantes (Fenalc...
#
#                                                 title  \
# 0    Desde Bélgica, Correa busca ser vicepresident...
# 1            Yony González llega al Galaxy de la MLS
# 2    Exalcalde de Convención habría sido secuestrado
# 3    Los expresidentes que le apuestan a seguir en...
# ...

# %%
mainpath = "/Cursos/Python/Python/Scraping/WebScraping_Data_Ing"
filename = "eluniversal_2019_06_07_articles.csv"
#fullpath = mainpath + "/" + filename
fullpath = os.path.join(mainpath,filename)

el_universal = pd.read_csv(fullpath, encoding='utf-8')
display(type(el_universal))
display(el_universal)
# Out:
# pandas.core.frame.DataFrame
#                                                   body  \
# 0    \nLa procuradora Ernestina Godoy confirmó que ...
# 1                                                  NaN
# 2                                                  NaN
# 3    \n\nTras el triunfo de Barbosa y la derrota de...
# 4    \n\nLa noticia de que las niñas y niños de la ...
# ..                                                 ...
# 194  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 195  \nTexto: Aída Castro SánchezDiseño web: Miguel...
# 196  \nTingüindín, Michoacán.- Diego Vidal Manzo, s...
# 197                                                NaN
# 198                                                NaN
#
#                                                  title  \
# 0    Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                  NaN
# 2                                                  NaN
# ...

# %%
pd.options.display.max_rows = 10 #define el maximo de registros a mostrar
display(el_colombiano.head())
display(el_colombiano.tail())
# Out:
#                                                 body  \
# 0  La inscripción de la candidatura a vicepreside...
# 1  El extremo colombiano Yony González se convirt...
# 2  Este miércoles, según versiones preliminares, ...
# 3  Si se revisa el mapa del continente, la mayorí...
# 4  El ministro de Hacienda, Alberto Carrasquilla,...
#
#                                                title  \
# 0   Desde Bélgica, Correa busca ser vicepresident...
# 1           Yony González llega al Galaxy de la MLS
# 2   Exalcalde de Convención habría sido secuestrado
# 3   Los expresidentes que le apuestan a seguir en...
# 4   Nivel de deuda se acerca a límites de difícil...
#
#                                                  url
# 0  http://elcolombiano.com/internacional/america-...
# 1  http://elcolombiano.com/deportes/futbol/yony-g...
# 2  http://elcolombiano.com/colombia/exalcalde-de-...
# 3  http://elcolombiano.com/internacional/america-...
# 4  http://elcolombiano.com/negocios/economia/deud...
# ...

# %% [markdown]
# ### Index and Selection

# %%
#Estilo diccionario
display(el_colombiano['title'])
display(el_universal['title'])
# Out:
# 0      Desde Bélgica, Correa busca ser vicepresident...
# 1              Yony González llega al Galaxy de la MLS
# 2      Exalcalde de Convención habría sido secuestrado
# 3      Los expresidentes que le apuestan a seguir en...
# 4      Nivel de deuda se acerca a límites de difícil...
#                             ...
# 26     Esto dice la denuncia contra Peña Nieto por p...
# 27     ¿Con 502.000 contagios, ahora cuál será la ta...
# 28     Kamala Harris acepta candidatura a Vicepresid...
# 29     Temblor de magnitud 5,0 se sintió en varias c...
# 30     Comerciantes reportaron menores ventas en julio
# Name: title, Length: 31, dtype: object
# 0      Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                    NaN
# 2                                                    NaN
# 3      Puebla: un tropiezo electoral no es una derrot...
# 4                              Entre faldas y pantalones
#                              ...
# ...

# %%
el_colombiano[['title','url']]
# Out:
#                                                 title  \
# 0    Desde Bélgica, Correa busca ser vicepresident...
# 1            Yony González llega al Galaxy de la MLS
# 2    Exalcalde de Convención habría sido secuestrado
# 3    Los expresidentes que le apuestan a seguir en...
# 4    Nivel de deuda se acerca a límites de difícil...
# ..                                                ...
# 26   Esto dice la denuncia contra Peña Nieto por p...
# 27   ¿Con 502.000 contagios, ahora cuál será la ta...
# 28   Kamala Harris acepta candidatura a Vicepresid...
# 29   Temblor de magnitud 5,0 se sintió en varias c...
# 30   Comerciantes reportaron menores ventas en julio
#
#                                                   url
# 0   http://elcolombiano.com/internacional/america-...
# 1   http://elcolombiano.com/deportes/futbol/yony-g...
# 2   http://elcolombiano.com/colombia/exalcalde-de-...
# 3   http://elcolombiano.com/internacional/america-...
# ...

# %%
# Estilo Numpy
el_colombiano.iloc[10:15]
# Out:
#                                                  body  \
# 10  El anuncio de la gerencia de EPM de entablar u...
# 11  La plataforma de alojamiento en hogares Airbnb...
# 12  La NBA anunció que no hubo ningún positivo por...
# 13  Sobre una barca se van repartiendo libros por ...
# 14  La Dirección de Impuestos y Aduanas Nacionales...
#
#                                                 title  \
# 10       Foro | Los desafíos de la gobernanza en EPM
# 11                  Airbnb, más cerca de Wall Street
# 12   NBA, sin positivos por covid-19 en los playoffs
# 13   Con homenajes a las letras chocoanas, arrancó...
# 14   Dian aprehendió 1,74 millones de cajetillas d...
#
#                                                   url
# 10  http://elcolombiano.com/antioquia/foro-los-des...
# 11  http://elcolombiano.com/negocios/empresas/airb...
# 12  http://elcolombiano.com/deportes/otros-deporte...
# 13  http://elcolombiano.com/cultura/literatura/fle...
# ...

# %%
el_colombiano.iloc[10]['title']
# Out:
# ' Foro | Los desafíos de la gobernanza en EPM '

# %%
 el_colombiano.iloc[:5,0]
# Out:
# 0    La inscripción de la candidatura a vicepreside...
# 1    El extremo colombiano Yony González se convirt...
# 2    Este miércoles, según versiones preliminares, ...
# 3    Si se revisa el mapa del continente, la mayorí...
# 4    El ministro de Hacienda, Alberto Carrasquilla,...
# Name: body, dtype: object

# %%
el_colombiano.loc[:,'body':'title']
# Out:
#                                                  body  \
# 0   La inscripción de la candidatura a vicepreside...
# 1   El extremo colombiano Yony González se convirt...
# 2   Este miércoles, según versiones preliminares, ...
# 3   Si se revisa el mapa del continente, la mayorí...
# 4   El ministro de Hacienda, Alberto Carrasquilla,...
# ..                                                ...
# 26  Emilio Lozoya, exdirector de Petróleos Mexican...
# 27  Pasaron 24 semanas, 166 días y se aplicaron 2,...
# 28   La senadora negra Kamala Harris aceptó el mié...
# 29  El Servicio Geológico Colombiano confirmó este...
# 30  La Federación Nacional de Comerciantes (Fenalc...
#
#                                                 title
# 0    Desde Bélgica, Correa busca ser vicepresident...
# 1            Yony González llega al Galaxy de la MLS
# 2    Exalcalde de Convención habría sido secuestrado
# 3    Los expresidentes que le apuestan a seguir en...
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Data wrangling con Pandas

# %% [markdown]
# Data wrangling es una de las actividades más importantes de todos los profesionales de datos. Simplemente es limpiar, transformar y enriquecer el dataset para objetivos posteriores.
#
# Pandas es una de las herramientas más poderosas para realizar este ***“domado”*** de datos. Recordemos que Pandas trae muchas de sus abstracciones del lenguaje R, pero nos otorga lo mejor de ambos mundos, por eso es tan popular.
#
# Nos permite:
#
# - generar transformaciones con gran facilidad.
# - trabajar rápidamente con datasets grandes
# - detectar y reemplazar faltantes
# - agrupar y resumir nuestros datos
# - visualizar nuestros resultados.

# %%
# 1. Añadir newspaper_uid al DataFrame

el_universal['newspaper_uid'] = 'eluniversal'

el_universal
# Out:
#                                                   body  \
# 0    \nLa procuradora Ernestina Godoy confirmó que ...
# 1                                                  NaN
# 2                                                  NaN
# 3    \n\nTras el triunfo de Barbosa y la derrota de...
# 4    \n\nLa noticia de que las niñas y niños de la ...
# ..                                                 ...
# 194  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 195  \nTexto: Aída Castro SánchezDiseño web: Miguel...
# 196  \nTingüindín, Michoacán.- Diego Vidal Manzo, s...
# 197                                                NaN
# 198                                                NaN
#
#                                                  title  \
# 0    Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                  NaN
# 2                                                  NaN
# 3    Puebla: un tropiezo electoral no es una derrot...
# ...

# %%
#2. obtener el host

#from urllib.parse import urlparse

el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)

# Funcion pd.apply() aplica la funcion que esta dentro del parentesis a cada una de las filas de la columna, o serie, 
# especificada. lambda (rgumentos : resultado)es la syntaxis para una funcion de un solo renglon.

display(el_universal)
display(el_universal['host'].value_counts()) #Valores que se repiten y sus frecuencias
# Out:
#                                                   body  \
# 0    \nLa procuradora Ernestina Godoy confirmó que ...
# 1                                                  NaN
# 2                                                  NaN
# 3    \n\nTras el triunfo de Barbosa y la derrota de...
# 4    \n\nLa noticia de que las niñas y niños de la ...
# ..                                                 ...
# 194  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 195  \nTexto: Aída Castro SánchezDiseño web: Miguel...
# 196  \nTingüindín, Michoacán.- Diego Vidal Manzo, s...
# 197                                                NaN
# 198                                                NaN
#
#                                                  title  \
# 0    Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                  NaN
# 2                                                  NaN
# 3    Puebla: un tropiezo electoral no es una derrot...
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Creación de la receta: preparando la automatización

# %% [markdown]
# El codigo esta en D:\Cursos\Python\Python\Scraping\WebScraping_Data_Ing\newspaper_receipe.py

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# #  Cómo trabajar con datos faltantes?

# %% [markdown]
# Los datos faltantes representan un verdadero problema sobre todo cuando estamos realizando agregaciones. Imagina que tenemos datos faltantes y los llenamos con 0, pero eso haría que la distribución de datos se modificaría radicalmente. Podemos eliminar los registros, pero la fuerza de nuestras conclusiones se debilita.
#
# Pandas nos otorga varias funcionalidades para identificarlas y para trabajar con ellas. Existe el concepto que se llama NaN, cuando existe un dato faltante simplemente se rellena con un *NaN* y en ese momento podemos preguntar cuáles son los datos faltantes con ***.isna()***.
#
# - Eliminar Registro
#     - **notna()** : para preguntar dónde hay datos completos.
#     - **dropna()** : para eliminar el registro.
#
# - Para reemplazar:
#     - **fillna()** :donde le damos un dato centinela
#     - **ffill()** : donde utiliza el último valor.

# %%
#3. Rellenar datos faltantes

missing_titles_mask = el_universal['title'].isna()
missing_titles_mask
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 194    False
# 195    False
# 196    False
# 197     True
# 198    False
# Name: title, Length: 199, dtype: bool

# %%
missing_titles = (el_universal[missing_titles_mask]['url']
                    .str.extract(r'(?P<missing_titles>[^/]+)$')
                    .applymap(str)
                    .applymap(lambda title: title.split('-'))
                    .applymap(lambda title_word_list: ' '.join(title_word_list))
                  .applymap(lambda title: title.capitalize())
)
missing_titles
# Out:
#                                         missing_titles
# 1                                                  Box
# 2    En verdad padecio sifilis schubert el gran com...
# 6    Ladron se dispara durante asalto pizzeria en m...
# 9    Las bacterias que viven en tu celular y otros ...
# 10                                             2jmdixt
# ..                                                 ...
# 182  10 famosos que lucen irreconocibles con unos k...
# 188                                      Suscripciones
# 191                                            1twqkcr
# 192             6 ejercicios para tonificar los brazos
# 197                                          Seguridad
#
# [65 rows x 1 columns]

# %%
missing_titles2 = (el_universal[missing_titles_mask]['url']
                     .str.extract(r'(?P<missing_titles>[^/]+)$')
                    .applymap(str)
                     .applymap(lambda title: title.replace('-',' '))
                    .applymap(lambda title: title.capitalize())
    )
missing_titles2
# Out:
#                                         missing_titles
# 1                                                  Box
# 2    En verdad padecio sifilis schubert el gran com...
# 6    Ladron se dispara durante asalto pizzeria en m...
# 9    Las bacterias que viven en tu celular y otros ...
# 10                                             2jmdixt
# ..                                                 ...
# 182  10 famosos que lucen irreconocibles con unos k...
# 188                                      Suscripciones
# 191                                            1twqkcr
# 192             6 ejercicios para tonificar los brazos
# 197                                          Seguridad
#
# [65 rows x 1 columns]

# %%
el_universal.loc[missing_titles_mask,'title'] = missing_titles.loc[:,'missing_titles']
el_universal
# Out:
#                                                   body  \
# 0    \nLa procuradora Ernestina Godoy confirmó que ...
# 1                                                  NaN
# 2                                                  NaN
# 3    \n\nTras el triunfo de Barbosa y la derrota de...
# 4    \n\nLa noticia de que las niñas y niños de la ...
# ..                                                 ...
# 194  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 195  \nTexto: Aída Castro SánchezDiseño web: Miguel...
# 196  \nTingüindín, Michoacán.- Diego Vidal Manzo, s...
# 197                                                NaN
# 198                                                NaN
#
#                                                  title  \
# 0    Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                  Box
# 2    En verdad padecio sifilis schubert el gran com...
# 3    Puebla: un tropiezo electoral no es una derrot...
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# #  Operaciones con Series y DataFrames

# %% [markdown]
# Se complementa el codigo en Python D:\Cursos\Python\Python\Scraping\WebScraping_Data_Ing\newspaper_receipe.py

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Limpiando detalles adicionales

# %%
# 4. Añadir uid a las filas


uids = (el_universal
        .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
        # md5 da un identificador unico de 128 bytes que lo vamos a representar en hexadecimal, cofificado en utf-8 gracias a la función .encode(). 
        .apply(lambda hash_object: hash_object.hexdigest())
        # El hash object obtenido anteriormente lo conventimos en un numero hexadecimal
        )
el_universal['uid'] = uids #reeplaza el index numerico definifo por defecto por uno definido a priori
el_universal.set_index('uid', inplace=True) #inplace nos modifica el df actual y no crea otro

el_universal
# Out:
#                                                                                body  \
# uid
# 6c7bf68194a8a5998597239b29be7e41  \nLa procuradora Ernestina Godoy confirmó que ...
# cb18691c58018e4163d72b0ed8bbcf38                                                NaN
# cf5bc6c8b4056dc4120a47d67699919e                                                NaN
# 35e6ddcb6722ef46c2f60a04d4e33229  \n\nTras el triunfo de Barbosa y la derrota de...
# 217d524b953cf2f3dabfe160622cc128  \n\nLa noticia de que las niñas y niños de la ...
# ...                                                                             ...
# 3486e1b91f94db6ad09d8d3dbef782e2  \nCDMX.- Cerca de las 18:30 horas, un hombre d...
# 0b3554fa7bcb1999372a959a34bcab22  \nTexto: Aída Castro SánchezDiseño web: Miguel...
# fef05cb73c5ba11f41aa58190726ca5a  \nTingüindín, Michoacán.- Diego Vidal Manzo, s...
# ab3f9d29135096228449397395057c36                                                NaN
# ...

# %%
#.5 Eliminar caracter especial \n o \r

# %%
stripped_body = (el_universal
                 .dropna()
                 .apply(lambda row: row['body'], axis=1)
                 #Selecciona cada una de las filas de la columna body
                 .apply(str)
                 #Convierte cada fila en un string
                 .apply(lambda body: list(body))
                 #El contenido de cada fila la separa por una lista de letras
                 .apply(lambda letters: list(map(lambda letter: letter.replace('\n',''),letters)))
                 #Reemplaza \n por espacions en blanco
                 .apply(lambda letters_list: ''.join(letters_list))
                 #Une de nuevo la lista de letras en un string
    
)
stripped_body
# Out:
# uid
# 6c7bf68194a8a5998597239b29be7e41    La procuradora Ernestina Godoy confirmó que el...
# 35e6ddcb6722ef46c2f60a04d4e33229    Tras el triunfo de Barbosa y la derrota de Cár...
# 217d524b953cf2f3dabfe160622cc128    La noticia de que las niñas y niños de la Ciud...
# 4143ab2442056b5528505c397328005d    [email protected]Hace más de siglo y medio, el...
# ea90d86c2113e6364b955ce4d1a86f78    CUERNAVACA.– Tres hombres fueron detenidos, un...
#                                                           ...
# ede25de0c732442cd78c6cb15327beec    Los brazos son una de las zonas que más pueden...
# fefe2a7902716da5e068e6a55171d7a0    Felipe Orocuta, boxeador mexicano, está siendo...
# 3486e1b91f94db6ad09d8d3dbef782e2    CDMX.- Cerca de las 18:30 horas, un hombre de ...
# 0b3554fa7bcb1999372a959a34bcab22    Texto: Aída Castro SánchezDiseño web: Miguel Á...
# fef05cb73c5ba11f41aa58190726ca5a    Tingüindín, Michoacán.- Diego Vidal Manzo, sub...
# Length: 141, dtype: object

# %%
# import re 
stripped_body2 = (el_universal['body']
                     .dropna()
                    .apply(str)
                     .apply(lambda body: re.sub(r'(\n|\r)+','',body))
                 
    
)
stripped_body2
# Out:
# uid
# 6c7bf68194a8a5998597239b29be7e41    La procuradora Ernestina Godoy confirmó que el...
# 35e6ddcb6722ef46c2f60a04d4e33229    Tras el triunfo de Barbosa y la derrota de Cár...
# 217d524b953cf2f3dabfe160622cc128    La noticia de que las niñas y niños de la Ciud...
# 4143ab2442056b5528505c397328005d    [email protected]Hace más de siglo y medio, el...
# ea90d86c2113e6364b955ce4d1a86f78    CUERNAVACA.– Tres hombres fueron detenidos, un...
#                                                           ...
# ede25de0c732442cd78c6cb15327beec    Los brazos son una de las zonas que más pueden...
# fefe2a7902716da5e068e6a55171d7a0    Felipe Orocuta, boxeador mexicano, está siendo...
# 3486e1b91f94db6ad09d8d3dbef782e2    CDMX.- Cerca de las 18:30 horas, un hombre de ...
# 0b3554fa7bcb1999372a959a34bcab22    Texto: Aída Castro SánchezDiseño web: Miguel Á...
# fef05cb73c5ba11f41aa58190726ca5a    Tingüindín, Michoacán.- Diego Vidal Manzo, sub...
# Name: body, Length: 141, dtype: object

# %%
stripped_body3 = (el_universal['body']
                 .dropna()
                  .apply(str)
                 .apply(lambda body: body.replace('\n',''))
                 
    
)
stripped_body3
# Out:
# uid
# 6c7bf68194a8a5998597239b29be7e41    La procuradora Ernestina Godoy confirmó que el...
# 35e6ddcb6722ef46c2f60a04d4e33229    Tras el triunfo de Barbosa y la derrota de Cár...
# 217d524b953cf2f3dabfe160622cc128    La noticia de que las niñas y niños de la Ciud...
# 4143ab2442056b5528505c397328005d    [email protected]Hace más de siglo y medio, el...
# ea90d86c2113e6364b955ce4d1a86f78    CUERNAVACA.– Tres hombres fueron detenidos, un...
#                                                           ...
# ede25de0c732442cd78c6cb15327beec    Los brazos son una de las zonas que más pueden...
# fefe2a7902716da5e068e6a55171d7a0    Felipe Orocuta, boxeador mexicano, está siendo...
# 3486e1b91f94db6ad09d8d3dbef782e2    CDMX.- Cerca de las 18:30 horas, un hombre de ...
# 0b3554fa7bcb1999372a959a34bcab22    Texto: Aída Castro SánchezDiseño web: Miguel Á...
# fef05cb73c5ba11f41aa58190726ca5a    Tingüindín, Michoacán.- Diego Vidal Manzo, sub...
# Name: body, Length: 141, dtype: object

# %%
el_universal['body'] = stripped_body
el_universal
# Out:
#                                                                                body  \
# uid
# 6c7bf68194a8a5998597239b29be7e41  La procuradora Ernestina Godoy confirmó que el...
# cb18691c58018e4163d72b0ed8bbcf38                                                NaN
# cf5bc6c8b4056dc4120a47d67699919e                                                NaN
# 35e6ddcb6722ef46c2f60a04d4e33229  Tras el triunfo de Barbosa y la derrota de Cár...
# 217d524b953cf2f3dabfe160622cc128  La noticia de que las niñas y niños de la Ciud...
# ...                                                                             ...
# 3486e1b91f94db6ad09d8d3dbef782e2  CDMX.- Cerca de las 18:30 horas, un hombre de ...
# 0b3554fa7bcb1999372a959a34bcab22  Texto: Aída Castro SánchezDiseño web: Miguel Á...
# fef05cb73c5ba11f41aa58190726ca5a  Tingüindín, Michoacán.- Diego Vidal Manzo, sub...
# ab3f9d29135096228449397395057c36                                                NaN
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Limpiando detalles en nuestro proyecto

# %% [markdown]
# Se complementa el codigo en Python D:\Cursos\Python\Python\Scraping\WebScraping_Data_Ing\newspaper_receipe.py

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Enriquecimiento de los datos

# %% [markdown]
# Podemos enriquecer nuestra tabla con información adicional, un poco de información numérica para realizar análisis posterior.
#
# Usaremos nltk es una librería dentro del stack de Ciencia de Datos de Python que nos va a permitir tokenizar, separar palabras dentro del título y nos permitirá contar la frecuencia de cuántas palabras existen en nuestro título y body

# %%
#6 tokenizar el titulo y el body
# import nltk
# from nltk.corpus import stopwords

#nltk.download('punkt')
#nltk.download('stopwords')

stop_words = set(stopwords.words('spanish'))

def tokenize_columns(df, column_name):
    return (df
            .dropna()
            #.apply(str)
            .apply(lambda row: nltk.word_tokenize(row[column_name]), axis = 1)
            .apply(lambda tokens: list(filter(lambda token: token.isalpha(),tokens)))
            .apply(lambda list_tokens: list(map(lambda token: token.lower(),list_tokens)))
            .apply(lambda words_list: list(filter(lambda word: word not in stop_words, words_list)))
            .apply(lambda valid_word_list: len(valid_word_list))
            
        )

el_universal['n_tokens_title'] = tokenize_columns(el_universal,'title')
el_universal['n_tokens_body'] = tokenize_columns(el_universal,'body')


el_universal.dropna()
# Out:
#                                                                                body  \
# uid
# 6c7bf68194a8a5998597239b29be7e41  La procuradora Ernestina Godoy confirmó que el...
# 35e6ddcb6722ef46c2f60a04d4e33229  Tras el triunfo de Barbosa y la derrota de Cár...
# 217d524b953cf2f3dabfe160622cc128  La noticia de que las niñas y niños de la Ciud...
# 4143ab2442056b5528505c397328005d  [email protected]Hace más de siglo y medio, el...
# ea90d86c2113e6364b955ce4d1a86f78  CUERNAVACA.– Tres hombres fueron detenidos, un...
# ...                                                                             ...
# ede25de0c732442cd78c6cb15327beec  Los brazos son una de las zonas que más pueden...
# fefe2a7902716da5e068e6a55171d7a0  Felipe Orocuta, boxeador mexicano, está siendo...
# 3486e1b91f94db6ad09d8d3dbef782e2  CDMX.- Cerca de las 18:30 horas, un hombre de ...
# 0b3554fa7bcb1999372a959a34bcab22  Texto: Aída Castro SánchezDiseño web: Miguel Á...
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# #  Valores duplicados en Jupyter

# %% [markdown]
# Estos valores duplicados es importantes identificarlos y removerlos de nuestro datasets para que esos valores no generen un peso no justificado dentro del análisis a realizar dentro de nuestro Pipelines.
#
# Pandas nos otorga la función drop_duplicates para eliminar estos valores duplicados

# %%
#7 Eliminar duplicados

el_universal['title'].value_counts()
# Out:
# Concacaf pide al Tri priorizar la Copa Oro       2
# Trump frena aranceles con pacto migratorio       2
# La ex reina que ligó a crack de Chivas           2
# Cinco siglos del idioma español en México        2
# Vicente Fernández suma nueva enemiga             2
#                                                 ..
# Mauricio Meschoulam                              1
# 2em2dil                                          1
# Microplasticos la nueva dieta del ser humano     1
# Los daños que las lluvias producen a tu auto     1
# 8 alimentos que te provocan gases                1
# Name: title, Length: 192, dtype: int64

# %%
el_universal[el_universal['title']=='Mitin “por la dignidad” se convierte en celebración']
# Out:
#                                                                                body  \
# uid
# d1c306d3311e161ac3d49a83fcf11267                                                NaN
# f8ade06569bbf1199fae9a567bea3397  [email protected]Tijuana, BC.— El presidente A...
#
#                                                                               title  \
# uid
# d1c306d3311e161ac3d49a83fcf11267  Mitin “por la dignidad” se convierte en celebr...
# f8ade06569bbf1199fae9a567bea3397  Mitin “por la dignidad” se convierte en celebr...
#
#                                                                                 url  \
# uid
# d1c306d3311e161ac3d49a83fcf11267               http://www.eluniversal.com.mx/nacion
# f8ade06569bbf1199fae9a567bea3397  http://www.eluniversal.com.mx/nacion/politica/...
#
#                                  newspaper_uid                    host  \
# uid
# d1c306d3311e161ac3d49a83fcf11267   eluniversal  www.eluniversal.com.mx
# ...

# %%
#subset =Columna a buscar
#keep= Que registro desea conservar
#inplace= True = sobreecribe el df, False= se crea uno nuevo con los cambios
el_universal.drop_duplicates(subset=['title'], keep='first', inplace=True)

# %%
el_universal
# Out:
#                                                                                body  \
# uid
# 6c7bf68194a8a5998597239b29be7e41  La procuradora Ernestina Godoy confirmó que el...
# cb18691c58018e4163d72b0ed8bbcf38                                                NaN
# cf5bc6c8b4056dc4120a47d67699919e                                                NaN
# 35e6ddcb6722ef46c2f60a04d4e33229  Tras el triunfo de Barbosa y la derrota de Cár...
# 217d524b953cf2f3dabfe160622cc128  La noticia de que las niñas y niños de la Ciud...
# ...                                                                             ...
# fefe2a7902716da5e068e6a55171d7a0  Felipe Orocuta, boxeador mexicano, está siendo...
# 3486e1b91f94db6ad09d8d3dbef782e2  CDMX.- Cerca de las 18:30 horas, un hombre de ...
# 0b3554fa7bcb1999372a959a34bcab22  Texto: Aída Castro SánchezDiseño web: Miguel Á...
# fef05cb73c5ba11f41aa58190726ca5a  Tingüindín, Michoacán.- Diego Vidal Manzo, sub...
# ...

# %%
#el_universal['body'] = el_universal['body'].replace('nan', np.nan)
#el_universal

# %%
el_universal.dropna()
# Out:
#                                                                                body  \
# uid
# 6c7bf68194a8a5998597239b29be7e41  La procuradora Ernestina Godoy confirmó que el...
# 35e6ddcb6722ef46c2f60a04d4e33229  Tras el triunfo de Barbosa y la derrota de Cár...
# 217d524b953cf2f3dabfe160622cc128  La noticia de que las niñas y niños de la Ciud...
# 4143ab2442056b5528505c397328005d  [email protected]Hace más de siglo y medio, el...
# ea90d86c2113e6364b955ce4d1a86f78  CUERNAVACA.– Tres hombres fueron detenidos, un...
# ...                                                                             ...
# ede25de0c732442cd78c6cb15327beec  Los brazos son una de las zonas que más pueden...
# fefe2a7902716da5e068e6a55171d7a0  Felipe Orocuta, boxeador mexicano, está siendo...
# 3486e1b91f94db6ad09d8d3dbef782e2  CDMX.- Cerca de las 18:30 horas, un hombre de ...
# 0b3554fa7bcb1999372a959a34bcab22  Texto: Aída Castro SánchezDiseño web: Miguel Á...
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Visualización de datos

# %%
mainpath = "/Cursos/Python/Python/Scraping/WebScraping_Data_Ing"
filename_ElUniversal = "clean_eluniversal_2019_06_07_articles.csv"
filename_ElColombiano = "clean_elcolombiano_2020_08_20_articles.csv"

#fullpath = mainpath + "/" + filename
fullpath_Eluniversal = os.path.join(mainpath,filename_ElUniversal)
fullpath_ElColombiano = os.path.join(mainpath,filename_ElColombiano)

clean_eluniversal = pd.read_csv(fullpath_Eluniversal, encoding='utf-8')
clean_elcolombiano = pd.read_csv(fullpath_ElColombiano, encoding='utf-8')

# %%
#describe nos proporciona informacion estadistica de nuestros datos

display(clean_eluniversal.describe())
display(clean_elcolombiano.describe())
# Out:
#        n_tokens_body  n_tokens_title
# count     137.000000      137.000000
# mean      280.167883        5.423358
# std       276.113163        1.643716
# min         9.000000        1.000000
# 25%       119.000000        4.000000
# 50%       198.000000        5.000000
# 75%       302.000000        6.000000
# max      2105.000000       10.000000
#        n_tokens_body  n_tokens_title
# count      31.000000       31.000000
# mean      151.677419        5.096774
# std       498.296524        1.325515
# min        36.000000        3.000000
# 25%        38.500000        4.000000
# 50%        41.000000        5.000000
# 75%        43.500000        6.000000
# max      2747.000000        8.000000

# %%
clean_eluniversal[clean_eluniversal['n_tokens_title'] == 1]
# Out:
#                                   uid  \
# 129  3e542ff3beadc7730bbe798190f3cf39
#
#                                                   body          title  \
# 129   Toggle navigation  SuscripcionesEl Universal ...  Suscripciones
#
#                                                    url newspaper_uid  \
# 129  https://www.clubeluniversal.mx/content/suscrip...   eluniversal
#
#                        host  n_tokens_body  n_tokens_title
# 129  www.clubeluniversal.mx            9.0             1.0

# %%
clean_eluniversal['n_tokens_title'].plot(style='k.') #K color negro "." significa que la grafica sea de punto
clean_elcolombiano['n_tokens_title'].plot(style='r.')

# %%
clean_eluniversal['n_tokens_body'].plot(style='k.') #K color negro "." significa que la grafica sea de punto
clean_elcolombiano['n_tokens_body'].plot(style='r.')

# %%
all_newspapers = pd.concat([clean_elcolombiano,clean_eluniversal])
grouped = all_newspapers.groupby('newspaper_uid')
grouped.hist()
# Out:
# newspaper_uid
# elcolombiano    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# eluniversal     [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
grouped['n_tokens_body'].agg(['min','mean','max'])
# Out:
#                 min        mean     max
# newspaper_uid
# elcolombiano   36.0  151.677419  2747.0
# eluniversal     9.0  280.167883  2105.0

# %%
grouped.plot()
# Out:
# newspaper_uid
# elcolombiano    AxesSubplot(0.125,0.125;0.775x0.755)
# eluniversal     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Introducción a los sistemas de datos

# %% [markdown]
# Los sistemas de datos vienen en muchos sabores y colores, SQL, NoSQL, especializados en procesamiento en bloque, chorro y streaming. Este tipo de sistema nos permite realizar queries sofisticadas y compartir nuestro trabajo con otros miembros del equipo.
#
# - Procesamiento de bloque: Estamos hablando de datos históricos, qué sucedió ayer, en el trimestre pasado, cuáles fueron las ventas del año anterior o de los últimos cinco años. Nos permite realizar el procesamiento de manera eficiente.
#
# - Procesamiento en chorro: Significa que estamos procesando los datos conforme van llegando, las transformaciones se realizan en tiempo real, Este tipo de sistema nos sirven para cuando queremos realizar decisiones en donde la importancia del tiempo es fundamental.
#
# El criterio principal a tener en cuenta: El tiempo que tienes. Si bien los sistemas open source son gratis, para poderlos implementar necesitas tener conocimientos de cloud, debes poder saber trabajar y mantener máquinas.
#
# **SQL vs NoSQL**
#
# - La discusión más relevante en el mundo de las aplicaciones web y móvil, donde dependiendo de la aplicación, la decisión puede ser fundamental para el crecimiento de la app.
# - La verdad es que para los profesionales de los datos, especialmente los profesionales de los datos. Es necesario saber ambos.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Cargando datos a SQLite

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Automatización del Pipline

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # ¿Por qué usar la nube?

# %% [markdown]
# La nube nos da un poder de cómputo casi inimaginable, nos permite procesar terabytes de datos en segundos. La nube se puede usar en dos grandes ocasiones. Cuando los datos ya no caben en tu computadora loca o cuando el tiempo de procesamiento esta siendo muy extenso, es en ese momento donde deberías usar la nube.
#
# Si estas en un entorno de producción, si estas trabajando en una empresa y los datos de esa empresa ya viven en la nube, lo lógico es realizar el trabajo en la nube. Automatizar los scripts en ese mismo ambiente.
#
# Diversas nubes ya ofrecen paquetes completos para el ciclo de datos, como Google Cloud:
#
# - Dataflow
# - Pub/Sub
# - Cloud Storage
# - Datalab
# - BigQuery
# - Dataproc
# - Firestore
