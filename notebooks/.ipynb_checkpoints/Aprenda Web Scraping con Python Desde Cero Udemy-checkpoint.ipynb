# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Web Scraping con Python

# %% [markdown]
# <div class="alert alert-block alert-danger"> <h1>Librerias a Utilizar en el Curso

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Tutorial

# %%
url = "https://boston.craigslist.org/d/software-qa-dba-etc/search/sof"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data = response.text

# %%
data
# Out:
# '\ufeff<!DOCTYPE html>\n<html class="no-js"><head>\n    <title>boston software/qa/dba/etc  jobs - craigslist</title>\n    <script type="application/ld+json" id="ld_breadcrumb_data" >\n    {"@context":"https://schema.org","itemListElement":[{"item":{"name":"boston.craigslist.org","@id":"https://boston.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"jobs","@id":"https://boston.craigslist.org/d/jobs/search/jjj"},"position":2,"@type":"ListItem"},{"item":{"name":"software","@id":"https://boston.craigslist.org/d/software-qa-dba-etc/search/sof"},"position":3,"@type":"ListItem"}],"@type":"BreadcrumbList"}\n</script>\n\n\n    <meta name="description" content="">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n        <link rel="canonical" href="https://boston.craigslist.org/d/software-qa-dba-etc/search/sof">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=ebf48c6109c06a8e6dbee442f06f0084">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/search.css?v=fd4f01ec1e3db22cf5a5494aba60e24c">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2">\n<!--[if IE]>\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=6bcbe5817e70c9a7f673ff72ba3e56e5">\n<![endif]-->\n\n    \n        <script type="text/javascript"><!--\nvar areaCountry = "US";\nvar areaID = "4";\nvar areaRegion = "MA";\nvar catAbb = "sof";\nvar countOfTotalText = "image {count} of {total}";\nvar currencySymbol = "&#x0024;";\nvar defaultView = "list";\nvar expiredFavIDs = null;\nvar imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};\nvar lessInfoText = "less info";\nvar maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";\nvar maxResults = 3000;\nvar noImageText = "no image";\nvar pID = null;\nvar postalLat = null;\nvar postalLon = null;\nvar purveyorCategories = null;\nvar searchDistance = null;\nvar sectionAbb = "jjj";\nvar sectionBase = "jjj";\nvar showInfoText = "show info";\nvar showMapTabs = 1;\nvar showingBanished = 0;\nvar showingFavorites = 0;\nvar starHint = "save this post in your favorites list";\nvar subarea = null;\nvar zoomToPosting = null;\n--></script>\n    \n</head>\n<body class="search has-map">\n    <script type="text/javascript"><!--\n    function C(k){return(document.cookie.match(\'(^|; )\'+k+\'=([^;]*)\')||0)[2]}\n    var pagetype, pagemode;\n    (function(){\n        var h = document.documentElement;\n        h.className = h.className.replace(\'no-js\', \'js\');\n        var b = document.body;\n        var bodyClassList = b.className.split(/\\s+/);;\n        pagetype = bodyClassList[0]; // dangerous assumption\n        var fmt = C(\'cl_fmt\');\n        if ( fmt === \'regular\' || fmt === \'mobile\' ) {\n            pagemode = fmt;\n        } else if (screen.width <= 480) {\n            pagemode = \'mobile\';\n        } else {\n            pagemode = \'regular\';\n  ...

# %%
soup = BeautifulSoup(data,'html.parser')

# %%
soup
# Out:
# ﻿<!DOCTYPE html>
#
# <html class="no-js"><head>
# <title>boston software/qa/dba/etc  jobs - craigslist</title>
# <script id="ld_breadcrumb_data" type="application/ld+json">
#     {"@context":"https://schema.org","itemListElement":[{"item":{"name":"boston.craigslist.org","@id":"https://boston.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"jobs","@id":"https://boston.craigslist.org/d/jobs/search/jjj"},"position":2,"@type":"ListItem"},{"item":{"name":"software","@id":"https://boston.craigslist.org/d/software-qa-dba-etc/search/sof"},"position":3,"@type":"ListItem"}],"@type":"BreadcrumbList"}
# </script>
# <meta content="" name="description"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible">
# <link href="https://boston.craigslist.org/d/software-qa-dba-etc/search/sof" rel="canonical"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <link href="//www.craigslist.org/styles/cl.css?v=ebf48c6109c06a8e6dbee442f06f0084" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/search.css?v=fd4f01ec1e3db22cf5a5494aba60e24c" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2" media="all" rel="stylesheet" type="text/css"/>
# <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=6bcbe5817e70c9a7f673ff72ba3e56e5">
# <![endif]-->
# <script type="text/javascript"><!--
# var areaCountry = "US";
# var areaID = "4";
# var areaRegion = "MA";
# var catAbb = "sof";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "list";
# var expiredFavIDs = null;
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 3000;
# var noImageText = "no image";
# var pID = null;
# var postalLat = null;
# var postalLon = null;
# var purveyorCategories = null;
# var searchDistance = null;
# var sectionAbb = "jjj";
# var sectionBase = "jjj";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = null;
# var zoomToPosting = null;
# --></script>
# </meta></head>
# <body class="search has-map">
# <script type="text/javascript"><!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# --></script>
# <section class="page-container" id="page-top">
# <div class="bglogo"></div>
# <div class="tryapp">
#     try the craigslist app »
#     <a class="appstorebtn" href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">
#         Android
#     </a>
# <a class="appstorebtn" href="https://apps.apple.com/us/app/craigslist/id1336642410">
#         iOS
#     </a>
# </div>
# <header class="global-header wide">
# <a class="header-logo" href="/" name="logoLink">CL</a>
# <nav class="breadcrumbs-container">
# <form action="/search/sof" class="breadcrumbs-form" data-action="/search/###/sof" id="breadcrumbform" method="get">
# <ul class="breadcrumbs">
# <li class="crumb area">
# <span class="no-js">
# <a href="/">boston</a>
# </span>
# <select class="js-only" id="areaAbb" name="areaAbb">
# <option value="boston">boston</option>
# <option value="albany">albany, NY</option>
# <option value="capecod">cape cod</option>
# <option value="catskills">catskills</option>
# <option value="cnj">central NJ</option>
# <option value="newlondon">eastern CT</option>
# <option value="glensfalls">glens falls</option>
# <option value="hartford">hartford</option>
# <option value="hudsonvalley">hudson valley</option>
# <option value="jerseyshore">jersey shore</option>
# <option value="longisland">long island</option>
# <option value="maine">maine</option>
# <option value="nh">new hampshire</option>
# <option value="newhaven">new haven</option>
# <option value="newyork">new york</option>
# <option value="newjersey">north jersey</option>
# <option value="nwct">northwest CT</option>
# <option value="oneonta">oneonta</option>
# <option value="plattsburgh">plattsburgh</option>
# <option value="poconos">poconos</option>
# <option value="providence">rhode island</option>
# <option value="southcoast">south coast</option>
# <option value="utica">utica</option>
# <option value="vermont">vermont</option>
# <option value="westernmass">western mass</option>
# <option value="worcester">worcester</option>
# </select>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb subarea">
# <select id="subArea" name="subArea">
# <option selected="" value="">all boston</option>
# <option value="gbs">boston/camb/brook</option>
# <option value="bmw">metro west</option>
# <option value="nos">north shore</option>
# <option value="nwb">northwest/merrimack</option>
# <option value="sob">south shore</option>
# </select>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb section">
# <select id="catAbb" name="catAbb">
# <option value="ccc">community</option>
# <option value="eee">events</option>
# <option value="sss">for sale</option>
# <option value="ggg">gigs</option>
# <option value="hhh">housing</option>
# <option selected="" value="jjj">jobs</option>
# <option value="rrr">resumes</option>
# <option value="bbb">services</option>
# </select>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb category">
# <select class="js-only" id="subcatAbb">
# <option value="jjj">all</option>
# <option value="ofc">admin/office</option>
# <option value="bus">business</option>
# <option value="csr">customer service</option>
# <option value="edu">education</option>
# <option value="egr">engineering</option>
# <option value="etc">etcetera</option>
# <option value="acc">finance</option>
# <option value="fbh">food/bev/hosp</option>
# <option value="lab">general labor</option>
# <option value="gov">government</option>
# <option value="hea">healthcare</option>
# <option value="hum">human resource</option>
# <option value="lgl">legal</option>
# <option value="mnu">manufacturing</option>
# <option value="mar">marketing</option>
# <option value="med">media</option>
# <option value="npo">nonprofit</option>
# <option value="rej">real estate</option>
# <option value="ret">retail/wholesale</option>
# <option value="sls">sales</option>
# <option value="spa">salon/spa/fitness</option>
# <option value="sci">science</option>
# <option value="sec">security</option>
# <option value="trd">skilled trades</option>
# <option selected="" value="sof">software</option>
# <option value="sad">systems/networking</option>
# <option value="tch">tech support</option>
# <option value="trp">transport</option>
# <option value="tfr">tv video radio</option>
# <option value="web">web design</option>
# <option value="wri">writing</option>
# </select><span class="no-js">software</span>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb no-js">
# <input type="submit" value="go"/>
# </li>
# </ul>
# </form>
# </nav>
# <div class="userlinks">
# <ul class="user-actions">
# <li class="user post">
# <a href="https://post.craigslist.org/c/bos">post</a>
# </li>
# <li class="user account">
# <a href="https://accounts.craigslist.org/login/home">account</a>
# </li>
# </ul>
# <ul class="user-favs-discards">
# <li class="user">
# <div class="favorites">
# <a class="favlink" href="#"><span aria-hidden="true" class="icon icon-star fav"></span><span class="fav-number">0</span><span class="fav-label"> favorites</span></a>
# </div>
# </li>
# <li class="user discards">
# <form action="/favorites" class="unfavform js-only" method="GET">
# <div class="to-banish-page">
# <input class="unfaves" name="fl" type="hidden"/>
# <input name="uf" type="hidden" value="1"/>
# <a class="to-banish-page-link" href="#">
# <span aria-hidden="true" class="icon icon-trash red"></span>
# <span class="banished_count">0</span>
# <span class="discards-label"> hidden</span>
# </a>
# </div>
# </form>
# </li>
# </ul>
# </div>
# </header>
# <header class="global-header narrow">
# <a class="header-logo" href="/">CL</a>
# <nav class="breadcrumbs-container">
# <h1 class="breadcrumbs">
#
# boston            &gt;
#
# software/qa/dba/etc</h1>
# </nav>
# <span class="linklike show-wide-header">...</span>
# </header>
# <form action="/d/software-qa-dba-etc/search/sof" class="search-form" id="searchform">
# <div class="querybox">
# <div class="form-tab js-only"><span class="search-open" title="hide search">«</span><span class="search-closed" title="show search">»</span></div>
# <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search software/qa/dba/etc" type="text" value=""/>
# <button class="searchbtn" type="submit">
# <span aria-hidden="true" class="icon icon-search"></span>
# <span class="screen-reader-text">press to search craigslist</span>
# </button>
# <div class="savealert">
# <a class="saveme" data-action="save" href="https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fboston%2Ecraigslist%2Eorg%2Fd%2Fsoftware%2Dqa%2Ddba%2Detc%2Fsearch%2Fsof" title="save this search">save search</a>
# </div>
# </div>
# <div class="search-options-container">
# <h1 class="cattitle">
# <a class="reset" href="/d/software-qa-dba-etc/search/sof" title="clear all search parameters">software/qa/dba/etc</a>
# </h1>
# <div class="search-options-header linklike">
# <div aria-hidden="true" class="icon icon-toggle-gear"></div>
#         options<span class="options-close">close</span>
# </div>
# <input id="excats" name="excats" type="hidden"/>
# <div class="search-options">
# <div class="searchgroup categories">
# </div>
# <input name="userid" type="hidden" value="">
# <div class="searchgroup" id="basic-bools">
# <ul>
# <li>
# <label class="srchType">
# <input class="" name="srchType" type="checkbox" value="T"/>
#            search titles only
#        </label>
# </li>
# <li>
# <label class="hasPic">
# <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#            has image
#        </label>
# </li>
# <li>
# <label class="postedToday">
# <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#            posted today
#        </label>
# </li>
# <li>
# <label class="bundleDuplicates">
# <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#            bundle duplicates
#        </label>
# </li>
# <li>
# <label class="searchNearby">
# <input class="autosubmit" name="searchNearby" type="checkbox" value="1"/>
#            include nearby areas
#        </label>
# </li>
# </ul>
# <ul class="js-only nearbyAreas">
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_10" name="nearbyArea" type="checkbox" value="59">
#                             albany, NY <small>(alb)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_4">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_26" name="nearbyArea" type="checkbox" value="248">
#                             binghamton, NY <small>(bgm)</small>
# </input></label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_3" name="nearbyArea" type="checkbox" value="239">
#                             cape cod / islands <small>(cap)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_14" name="nearbyArea" type="checkbox" value="451">
#                             catskills <small>(cat)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_4">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_24" name="nearbyArea" type="checkbox" value="349">
#                             central NJ <small>(cnj)</small>
# </input></label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_4" name="nearbyArea" type="checkbox" value="281">
#                             eastern CT <small>(nlo)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_6">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_36" name="nearbyArea" type="checkbox" value="453">
#                             elmira-corning <small>(elm)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_5">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_35" name="nearbyArea" type="checkbox" value="685">
#                             finger lakes, NY <small>(fgl)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_11" name="nearbyArea" type="checkbox" value="686">
#                             glens falls, NY <small>(gfl)</small>
# </input></label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_5" name="nearbyArea" type="checkbox" value="44"/>
#                             hartford, CT <small>(htf)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_12" name="nearbyArea" type="checkbox" value="249"/>
#                             hudson valley, NY <small>(hud)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_5">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_32" name="nearbyArea" type="checkbox" value="201"/>
#                             ithaca, NY <small>(ith)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_21" name="nearbyArea" type="checkbox" value="561"/>
#                             jersey shore <small>(jys)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_4">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_28" name="nearbyArea" type="checkbox" value="167"/>
#                             lehigh valley <small>(alt)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_13" name="nearbyArea" type="checkbox" value="250"/>
#                             long island, NY <small>(isp)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_16" name="nearbyArea" type="checkbox" value="169"/>
#                             maine <small>(mne)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_6" name="nearbyArea" type="checkbox" value="198"/>
#                             new hampshire <small>(nhm)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_9" name="nearbyArea" type="checkbox" value="168"/>
#                             new haven, CT <small>(hvn)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_18" name="nearbyArea" type="checkbox" value="3"/>
#                             new york city <small>(nyc)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_17" name="nearbyArea" type="checkbox" value="170"/>
#                             north jersey <small>(njy)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_8" name="nearbyArea" type="checkbox" value="354"/>
#                             northwest CT <small>(nct)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_20" name="nearbyArea" type="checkbox" value="684"/>
#                             oneonta, NY <small>(onh)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_5">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_31" name="nearbyArea" type="checkbox" value="17"/>
#                             philadelphia <small>(phi)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_19" name="nearbyArea" type="checkbox" value="338"/>
#                             plattsburgh-adirondacks <small>(plb)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_23" name="nearbyArea" type="checkbox" value="356"/>
#                             poconos <small>(poc)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_4">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_27" name="nearbyArea" type="checkbox" value="683"/>
#                             potsdam-canton-massena <small>(ptd)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_5">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_34" name="nearbyArea" type="checkbox" value="278"/>
#                             reading, PA <small>(rea)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_1" name="nearbyArea" type="checkbox" value="38"/>
#                             rhode island <small>(prv)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_4">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_25" name="nearbyArea" type="checkbox" value="276"/>
#                             scranton / wilkes-barre <small>(avp)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_2" name="nearbyArea" type="checkbox" value="378"/>
#                             south coast, MA <small>(sma)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_5">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_33" name="nearbyArea" type="checkbox" value="286"/>
#                             south jersey <small>(snj)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_4">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_29" name="nearbyArea" type="checkbox" value="130"/>
#                             syracuse, NY <small>(syr)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_22" name="nearbyArea" type="checkbox" value="247"/>
#                             utica-rome-oneida <small>(uti)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_15" name="nearbyArea" type="checkbox" value="93"/>
#                             vermont <small>(brl)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_5">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_30" name="nearbyArea" type="checkbox" value="337"/>
#                             watertown, NY <small>(wtn)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_7" name="nearbyArea" type="checkbox" value="173"/>
#                             western massachusetts <small>(wma)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_0" name="nearbyArea" type="checkbox" value="240"/>
#                             worcester / central MA <small>(wor)</small>
# </label>
# </li>
# <li>
# <span class="nextNearbyZone linklike" data-zone="1">
#                             + show <span id="nearbyNumber">37</span> more...
#                         </span>
# </li>
# </ul>
# </div>
# <div class="searchgroup">
# <span class="searchfieldlabel">miles from zip</span>
# <input class="flatinput searchInput search_distance" inputmode="numeric" maxlength="5" name="search_distance" placeholder="miles" size="5" value=""/>
# <input class="flatinput searchInput postal" name="postal" placeholder="from zip" size="7" type="text" value=""/>
# <span class="icon icon-locate"></span>
# </div>
# <div class="searchgroup search-group-checkbox">
# <label class="is_internship">
# <input class="autosubmit" name="is_internship" type="checkbox" value="1">
#     internship
# </input></label><br/>
# <label class="is_nonprofit">
# <input class="autosubmit" name="is_nonprofit" type="checkbox" value="1"/>
#     non-profit
# </label><br/>
# <label class="is_telecommuting">
# <input class="autosubmit" name="is_telecommuting" type="checkbox" value="1"/>
#     telecommute
# </label><br/>
# </div>
# <div class="searchgroup search-group-multi_checkbox">
# <div class="search-attribute" data-attr="employment_type">
# <div class="title linklike">
# <span class="plus">▸</span><span class="minus">▾</span> employment type
#     </div>
# <ul class="list">
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="employment_type_1" name="employment_type" type="checkbox" value="1"/>
#                     full-time
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="employment_type_2" name="employment_type" type="checkbox" value="2"/>
#                     part-time
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="employment_type_3" name="employment_type" type="checkbox" value="3"/>
#                     contract
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="employment_type_4" name="employment_type" type="checkbox" value="4"/>
#                     employee's choice
#                 </label>
# </li>
# </ul>
# </div>
# </div>
# <div class="searchgroup resetsearch">
# <a class="reset linklike" href="/d/software-qa-dba-etc/search/sof" title="clear all search parameters">reset</a>
# <button class="searchlink linklike" type="submit">update search</button>
# </div>
# </input></div>
# </div>
# <div class="search-legend">
# <div class="search-view js-only">
# <div aria-expanded="false" aria-label="view options" class="dropdown dropdown-icons dropdown-arrows dropdown-view" role="toolbar">
# <ul class="dropdown-list">
# <li class="dropdown-item mode sel">
# <button data-selection="list" id="listview" title="show results in a list">
# <span class="view-list icon"></span>list
#                 </button>
# <span class="toggle-arrow"></span>
# </li>
# <li class="dropdown-item mode">
# <button data-selection="pic" id="picview" title="show results in a list with thumbnail pictures">
# <span class="view-thumb icon"></span>thumb
#                 </button>
# <span class="toggle-arrow"></span>
# </li>
# <li class="dropdown-item mode">
# <button data-selection="grid" id="gridview" title="show results side-by-side with larger pictures">
# <span class="view-gallery icon"></span>gallery
#                 </button>
# <span class="toggle-arrow"></span>
# </li>
# <li class="dropdown-item mode">
# <button data-selection="map" id="mapview" title="show results on a map">
# <span class="view-map icon"></span>map
#                     </button>
# <span class="toggle-arrow"></span>
# </li>
# </ul>
# </div>
# </div>
# <div class="search-sort">
# <div aria-expanded="false" aria-label="sort options" class="dropdown dropdown-sort" data-default-sort="date" role="toolbar">
# <ul class="dropdown-list">
# <li aria-selected="true" class="dropdown-item mode sel">
# <a data-selection="date" href="/d/software-qa-dba-etc/search/sof?sort=date&amp;" title="show newest matches first">newest <span class="toggle-arrow"></span></a>
# </li>
# </ul>
# </div>
# </div>
# <div class="paginator buttongroup firstpage lastpage">
# <span class="resulttotal">
# <span class="for-map">
#         showing <span class="displaycountShow">...</span> postings
#         <span class="zoom-out-for-more" style="display: none">
#             -
#             <a href="">
#                 zoom out for all <span class="total">49</span>
# </a>
# </span>
# </span>
# </span>
# <span class="buttons">
# <a class="button first" href="/d/software-qa-dba-etc/search/sof" title="first page">&lt;&lt;</a>
# <span class="button first" title="first page">&lt;&lt;</span>
# <a class="button prev" href="/d/software-qa-dba-etc/search/sof" title="previous page">&lt; prev</a>
# <span class="button prev" title="previous page">&lt; prev</span>
# <span class="button pagenum">
# <span class="range">
# <span class="rangeFrom">1</span>
#                 -
#                 <span class="rangeTo">49</span>
# </span>
#             /
#             <span class="totalcount">49</span>
# </span>
# <a class="button next" href="" title="next page">next &gt; </a>
# <span class="button next" title="next page"> next &gt; </span>
# </span>
# </div>
# </div>
# <div class="content" id="sortable-results">
# <section class="favlistsection">
# <section class="favlistinfo">
# </section>
# <section class="banishlistinfo">
# </section>
# </section>
# <div class="open-map-view-button">
# <span>see in map view</span>
# </div>
# <div data-arealat="42.358299" data-arealon="-71.060303" id="mapcontainer">
# <div id="noresult-overlay"></div>
# <div id="noresult-text">
# <span class="message">No mappable items found</span>
# </div>
# <div class="loading" id="map">
# <div class="close-full-screen-map-mode-button">close fullscreen</div>
# </div>
# </div>
# <ul class="rows">
# <li class="result-row" data-pid="7306130076" data-repost-of="7295881009">
# <a class="result-image gallery" data-ids="3:00m0m_5LiuJjlxvHz_0qx09z" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7306130076.html">
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-13 10:29" title="Tue 13 Apr 10:29:23 AM">Apr 13</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7306130076" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7306130076.html" id="postid_7306130076">Software Engineer</a>
# </h3>
# <span class="result-meta">
# <span class="result-hood"> (Remote)</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7306093632">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/newton-highlands-xamarine-software/7306093632.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-13 09:16" title="Tue 13 Apr 09:16:19 AM">Apr 13</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7306093632" href="https://boston.craigslist.org/gbs/sof/d/newton-highlands-xamarine-software/7306093632.html" id="postid_7306093632">Xamarine Software Developer</a>
# </h3>
# <span class="result-meta">
# <span class="result-hood"> (Newton Highlands)</span>
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7304410862">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/bmw/sof/d/boxborough-data-scientist-software/7304410862.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-09 17:59" title="Fri 09 Apr 05:59:17 PM">Apr  9</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7304410862" href="https://boston.craigslist.org/bmw/sof/d/boxborough-data-scientist-software/7304410862.html" id="postid_7304410862">Data Scientist &amp; Software Engineer</a>
# </h3>
# <span class="result-meta">
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7303697158" data-repost-of="7295881009">
# <a class="result-image gallery" data-ids="3:01515_fq01DjyHQxqz_09G03e" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7303697158.html">
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-08 12:34" title="Thu 08 Apr 12:34:29 PM">Apr  8</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7303697158" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7303697158.html" id="postid_7303697158">Software Engineer</a>
# </h3>
# <span class="result-meta">
# <span class="result-hood"> (Remote)</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7302580375" data-repost-of="7295881009">
# <a class="result-image gallery" data-ids="3:01515_fq01DjyHQxqz_09G03e" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7302580375.html">
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-06 10:44" title="Tue 06 Apr 10:44:04 AM">Apr  6</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7302580375" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7302580375.html" id="postid_7302580375">Software Engineer</a>
# </h3>
# <span class="result-meta">
# <span class="result-hood"> (Remote)</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7301724610" data-repost-of="7209678061">
# <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7301724610.html">
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-04 13:51" title="Sun 04 Apr 01:51:21 PM">Apr  4</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7301724610" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7301724610.html" id="postid_7301724610">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
# </h3>
# <span class="result-meta">
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7300999570" data-repost-of="7209678061">
# <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300999570.html">
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-02 18:51" title="Fri 02 Apr 06:51:55 PM">Apr  2</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7300999570" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300999570.html" id="postid_7300999570">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
# </h3>
# <span class="result-meta">
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7300896102">
# <a class="result-image gallery" data-ids="3:00q0q_81cukKGrcYgz_0ix044,3:00J0J_bipCVo4VjoUz_0x20m2" href="https://boston.craigslist.org/gbs/sof/d/boston-python-engineer-weplayed-sports/7300896102.html">
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-02 15:39" title="Fri 02 Apr 03:39:28 PM">Apr  2</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7300896102" href="https://boston.craigslist.org/gbs/sof/d/boston-python-engineer-weplayed-sports/7300896102.html" id="postid_7300896102">Python Engineer @ WePlayed Sports</a>
# </h3>
# <span class="result-meta">
# <span class="result-hood"> (Boston (remote or on-site))</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7300534100">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/bmw/sof/d/framingham-database-tutor/7300534100.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-01 20:37" title="Thu 01 Apr 08:37:08 PM">Apr  1</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7300534100" href="https://boston.craigslist.org/bmw/sof/d/framingham-database-tutor/7300534100.html" id="postid_7300534100">database tutor</a>
# </h3>
# <span class="result-meta">
# <span class="result-hood"> (FRAMINGHAM)</span>
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7300338438">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/nos/sof/d/billerica-powerbuilder-programmer/7300338438.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-01 14:08" title="Thu 01 Apr 02:08:05 PM">Apr  1</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7300338438" href="https://boston.craigslist.org/nos/sof/d/billerica-powerbuilder-programmer/7300338438.html" id="postid_7300338438">PowerBuilder Programmer/Analyst Position</a>
# </h3>
# <span class="result-meta">
# <span class="result-hood"> (Billerica)</span>
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7300330242" data-repost-of="7209678061">
# <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300330242.html">
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-01 13:54" title="Thu 01 Apr 01:54:50 PM">Apr  1</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7300330242" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300330242.html" id="postid_7300330242">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
# </h3>
# <span class="result-meta">
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7300290359" data-repost-of="4887496409">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-underwriter/7300290359.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-01 12:51" title="Thu 01 Apr 12:51:09 PM">Apr  1</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7300290359" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-underwriter/7300290359.html" id="postid_7300290359">Mortgage Loan Underwriter</a>
# </h3>
# <span class="result-meta">
# <span class="result-hood"> (Medford, MA)</span>
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7300290139" data-repost-of="4887496409">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-closer/7300290139.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-01 12:50" title="Thu 01 Apr 12:50:53 PM">Apr  1</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7300290139" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-closer/7300290139.html" id="postid_7300290139">Mortgage Loan Closer</a>
# </h3>
# <span class="result-meta">
# <span class="result-hood"> (Medford, MA)</span>
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7300288495" data-repost-of="4887165676">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/medford-junior-items-processing-analyst/7300288495.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-01 12:48" title="Thu 01 Apr 12:48:15 PM">Apr  1</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7300288495" href="https://boston.craigslist.org/gbs/sof/d/medford-junior-items-processing-analyst/7300288495.html" id="postid_7300288495">Junior Items Processing Analyst</a>
# </h3>
# <span class="result-meta">
# <span class="result-hood"> (Medford)</span>
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7300007467" data-repost-of="6702174324">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7300007467.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-03-31 19:08" title="Wed 31 Mar 07:08:03 PM">Mar 31</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7300007467" href="https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7300007467.html" id="postid_7300007467">Data Science Fellowship</a>
# </h3>
# <span class="result-meta">
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7300007303" data-repost-of="6702174324">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7300007303.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-03-31 19:07" title="Wed 31 Mar 07:07:39 PM">Mar 31</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7300007303" href="https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7300007303.html" id="postid_7300007303">Product Management Fellowship</a>
# </h3>
# <span class="result-meta">
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7300006937" data-repost-of="6702174324">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7300006937.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-03-31 19:06" title="Wed 31 Mar 07:06:47 PM">Mar 31</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7300006937" href="https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7300006937.html" id="postid_7300006937">Software Engineering Fellowship</a>
# </h3>
# <span class="result-meta">
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7299811760">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-looking-for-senior-staff/7299811760.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-03-31 13:09" title="Wed 31 Mar 01:09:34 PM">Mar 31</time>
# <h3 class="result-heading">
# ...
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-12 13:40" title="Mon 12 Apr 01:40:03 PM">Apr 12</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7305727506" href="https://providence.craigslist.org/sof/d/mansfield-manager-or-director/7305727506.html" id="postid_7305727506">Manager or Director, Professional Services</a>
# </h3>
# <span class="result-meta">
# <span class="nearby" title="rhode island">(prv &gt; Mansfield, MA)</span>
# <span class="result-tags">
# <span class="pictag">img</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7298867620">
# <a class="result-image gallery empty" href="https://providence.craigslist.org/sof/d/warwick-full-stack-developer/7298867620.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-03-29 14:56" title="Mon 29 Mar 02:56:52 PM">Mar 29</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7298867620" href="https://providence.craigslist.org/sof/d/warwick-full-stack-developer/7298867620.html" id="postid_7298867620">Full Stack Developer</a>
# </h3>
# <span class="result-meta">
# <span class="nearby" title="rhode island">(prv &gt; REGIONAL)</span>
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7298487508" data-repost-of="7222316135">
# <a class="result-image gallery empty" href="https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298487508.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-03-28 18:52" title="Sun 28 Mar 06:52:11 PM">Mar 28</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7298487508" href="https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298487508.html" id="postid_7298487508">✭✭✭Start a Web Developer Career Today! No Experience Needed (Remote)</a>
# </h3>
# <span class="result-meta">
# <span class="nearby" title="rhode island">(prv)</span>
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7298253649" data-repost-of="7222316135">
# <a class="result-image gallery empty" href="https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298253649.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-03-28 11:34" title="Sun 28 Mar 11:34:07 AM">Mar 28</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7298253649" href="https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298253649.html" id="postid_7298253649">✭✭✭Start a Web Developer Career Today! No Experience Needed (Remote)</a>
# </h3>
# <span class="result-meta">
# <span class="nearby" title="rhode island">(prv)</span>
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7294691934" data-repost-of="7222316135">
# <a class="result-image gallery empty" href="https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7294691934.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-03-21 09:50" title="Sun 21 Mar 09:50:21 AM">Mar 21</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7294691934" href="https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7294691934.html" id="postid_7294691934">✭✭✭Start a Web Developer Career Today! No Experience Needed (Remote)</a>
# </h3>
# <span class="result-meta">
# <span class="nearby" title="rhode island">(prv)</span>
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7291841605" data-repost-of="7267494186">
# <a class="result-image gallery" data-ids="3:00j0j_ambV249uFxCz_0CI0jm" href="https://capecod.craigslist.org/sof/d/hyannis-estimator-templator/7291841605.html">
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-03-15 15:14" title="Mon 15 Mar 03:14:03 PM">Mar 15</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7291841605" href="https://capecod.craigslist.org/sof/d/hyannis-estimator-templator/7291841605.html" id="postid_7291841605">Estimator/Templator</a>
# </h3>
# <span class="result-meta">
# <span class="nearby" title="cape cod / islands">(cap &gt; hyannis)</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# <li class="result-row" data-pid="7298191991">
# <a class="result-image gallery empty" href="https://hartford.craigslist.org/sof/d/hartford-cyber-security-analysts-earn/7298191991.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-03-28 09:03" title="Sun 28 Mar 09:03:59 AM">Mar 28</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7298191991" href="https://hartford.craigslist.org/sof/d/hartford-cyber-security-analysts-earn/7298191991.html" id="postid_7298191991">Cyber Security Analysts! Earn $56,000-$117,000 per year!</a>
# </h3>
# <span class="result-meta">
# <span class="nearby" title="hartford, CT">(htf &gt; Hartford, CT)</span>
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>
# </ul>
# </div>
# <div class="search-legend bottom">
# <div class="search-view">
# <span class="buttongroup"><a class="backtotop button" href="#page-top">^ back to top</a></span>
# </div>
# <div class="search-sort">
# <span class="buttongroup"><a class="backtotop button" href="#page-top">^ back to top</a></span>
# </div>
# <div class="paginator buttongroup firstpage lastpage">
# <span class="resulttotal">
# <span class="for-map">
#         showing <span class="displaycountShow">...</span> postings
#         <span class="zoom-out-for-more" style="display: none">
#             -
#             <a href="">
#                 zoom out for all <span class="total">49</span>
# </a>
# </span>
# </span>
# </span>
# <span class="buttons">
# <a class="button first" href="/d/software-qa-dba-etc/search/sof" title="first page">&lt;&lt;</a>
# <span class="button first" title="first page">&lt;&lt;</span>
# <a class="button prev" href="/d/software-qa-dba-etc/search/sof" title="previous page">&lt; prev</a>
# <span class="button prev" title="previous page">&lt; prev</span>
# <span class="button pagenum">
# <span class="range">
# <span class="rangeFrom">1</span>
#                 -
#                 <span class="rangeTo">49</span>
# </span>
#             /
#             <span class="totalcount">49</span>
# </span>
# <a class="button next" href="" title="next page">next &gt; </a>
# <span class="button next" title="next page"> next &gt; </span>
# </span>
# </div>
# </div>
# <section class="blurbs">
# </section>
# <div id="floater">
# <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>
# <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>
# </div>
# </form>
# <div class="slidemessage">
# <span class="fave">
# <span class="star"></span>
#         favorited
#     </span>
# <span class="unfave">
# <span class="star"></span>
#         no longer favorited
#     </span>
# <span class="hide">
# <span class="trash"></span>
#         hidden
#     </span>
# <span class="unhide">
# <span class="trash"></span>
#         no longer hidden
#     </span>
# </div>
# <footer>
# <ul class="clfooter">
# <li>© 2021 <span class="desktop">craigslist</span><span class="mobile">CL</span></li>
# <li><a href="https://www.craigslist.org/about/help/">help</a></li>
# <li><a href="https://www.craigslist.org/about/scams">safety</a></li>
# <li class="desktop"><a href="https://www.craigslist.org/about/privacy.policy">privacy</a><sup class="neu">new</sup></li>
# <li class="desktop"><a href="https://forums.craigslist.org/?forumID=8">feedback</a></li>
# <li><a href="https://www.craigslist.org/about/terms.of.use">terms</a></li>
# <li><a href="https://www.craigslist.org/about/">about</a></li>
# <li class="fsel desktop linklike" data-mode="mobile">mobile</li>
# <li class="fsel mobile linklike" data-mode="regular">desktop</li>
# </ul>
# </footer>
# </section>
# <template id="gallerycarousel">
# <div class="slider-info"></div><div class="slider-back arrow">&lt;</div><div class="slider-forward arrow">&gt;</div>
# </template>
# <script>
#                 try {
#                     if (
#                         !/\/\/.+\.craigslist\.org\/about\//.test(window.location.href)
#                         &&
#                         (!window.addEventListener || JSON.parse(JSON.stringify('x')) !== 'x')
#                     ) {
#                         throw "unsupported browser";
#                     }
#                 } catch (e) {
#                     function cleanup() {
#                         document.body.innerHTML = '<div id="cl-unsupported-browser" style="margin:1em;font-size:150%;text-align:center;">We have detected you are using a browser that is missing critical features.<br><br>Please visit craigslist from a modern browser.</div>';
#                         document.body.style = "display:block";
#                     }
#
#                     try {
#                         document.body.style = "display:none";
#                     } catch (e) {
#                     }
#                     window.onload = cleanup;
#                     window.clUnsupportedBrowser = true;
#                 }
#                 </script>
# <script src="//www.craigslist.org/js/general-concat.min.js?v=2d91af30d4b934fdeac883a1d566126a" type="text/javascript"></script>
# <script id="clustertemplate" type="text/template">
#     <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{price}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
# </script>
# <script id="postingtemplate" type="text/template">
#     <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{price}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lt;</span><span class="slider-info"></span><span class="slider-forward arrow">&gt;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <div class="timecontainer"></div>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
# </script>
# <script id="popuptemplate" type="text/template">
#     <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
# </script>
# <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=66cc485807e67440f6b0d8f1fbced8ae" type="text/javascript"></script>
# <script src="//www.craigslist.org/js/search-concat.min.js?v=d5a723cf2be89b6eaae155dd9ada3c27" type="text/javascript"></script>
# <script src="//www.craigslist.org/js/postings-concat.min.js?v=dc59a76497f8ac00dc99db926c8fef7a" type="text/javascript"></script>
# </body>
# </html>

# %%
tags = soup.find_all('a')

# %%
tags
# Out:
# [<a class="appstorebtn" href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">
#          Android
#      </a>,
#  <a class="appstorebtn" href="https://apps.apple.com/us/app/craigslist/id1336642410">
#          iOS
#      </a>,
#  <a class="header-logo" href="/" name="logoLink">CL</a>,
#  <a href="/">boston</a>,
#  <a href="https://post.craigslist.org/c/bos">post</a>,
#  <a href="https://accounts.craigslist.org/login/home">account</a>,
#  <a class="favlink" href="#"><span aria-hidden="true" class="icon icon-star fav"></span><span class="fav-number">0</span><span class="fav-label"> favorites</span></a>,
#  <a class="to-banish-page-link" href="#">
#  <span aria-hidden="true" class="icon icon-trash red"></span>
#  <span class="banished_count">0</span>
#  <span class="discards-label"> hidden</span>
#  </a>,
#  <a class="header-logo" href="/">CL</a>,
#  <a class="saveme" data-action="save" href="https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fboston%2Ecraigslist%2Eorg%2Fd%2Fsoftware%2Dqa%2Ddba%2Detc%2Fsearch%2Fsof" title="save this search">save search</a>,
#  <a class="reset" href="/d/software-qa-dba-etc/search/sof" title="clear all search parameters">software/qa/dba/etc</a>,
#  <a class="reset linklike" href="/d/software-qa-dba-etc/search/sof" title="clear all search parameters">reset</a>,
#  <a data-selection="date" href="/d/software-qa-dba-etc/search/sof?sort=date&amp;" title="show newest matches first">newest <span class="toggle-arrow"></span></a>,
#  <a href="">
#                  zoom out for all <span class="total">49</span>
#  </a>,
#  <a class="button first" href="/d/software-qa-dba-etc/search/sof" title="first page">&lt;&lt;</a>,
#  <a class="button prev" href="/d/software-qa-dba-etc/search/sof" title="previous page">&lt; prev</a>,
#  <a class="button next" href="" title="next page">next &gt; </a>,
#  <a class="result-image gallery" data-ids="3:00m0m_5LiuJjlxvHz_0qx09z" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7306130076.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7306130076" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7306130076.html" id="postid_7306130076">Software Engineer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/newton-highlands-xamarine-software/7306093632.html"></a>,
#  <a class="result-title hdrlnk" data-id="7306093632" href="https://boston.craigslist.org/gbs/sof/d/newton-highlands-xamarine-software/7306093632.html" id="postid_7306093632">Xamarine Software Developer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/bmw/sof/d/boxborough-data-scientist-software/7304410862.html"></a>,
#  <a class="result-title hdrlnk" data-id="7304410862" href="https://boston.craigslist.org/bmw/sof/d/boxborough-data-scientist-software/7304410862.html" id="postid_7304410862">Data Scientist &amp; Software Engineer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:01515_fq01DjyHQxqz_09G03e" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7303697158.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7303697158" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7303697158.html" id="postid_7303697158">Software Engineer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:01515_fq01DjyHQxqz_09G03e" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7302580375.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7302580375" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7302580375.html" id="postid_7302580375">Software Engineer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7301724610.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7301724610" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7301724610.html" id="postid_7301724610">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300999570.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7300999570" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300999570.html" id="postid_7300999570">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00q0q_81cukKGrcYgz_0ix044,3:00J0J_bipCVo4VjoUz_0x20m2" href="https://boston.craigslist.org/gbs/sof/d/boston-python-engineer-weplayed-sports/7300896102.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7300896102" href="https://boston.craigslist.org/gbs/sof/d/boston-python-engineer-weplayed-sports/7300896102.html" id="postid_7300896102">Python Engineer @ WePlayed Sports</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/bmw/sof/d/framingham-database-tutor/7300534100.html"></a>,
#  <a class="result-title hdrlnk" data-id="7300534100" href="https://boston.craigslist.org/bmw/sof/d/framingham-database-tutor/7300534100.html" id="postid_7300534100">database tutor</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/nos/sof/d/billerica-powerbuilder-programmer/7300338438.html"></a>,
#  <a class="result-title hdrlnk" data-id="7300338438" href="https://boston.craigslist.org/nos/sof/d/billerica-powerbuilder-programmer/7300338438.html" id="postid_7300338438">PowerBuilder Programmer/Analyst Position</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300330242.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7300330242" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300330242.html" id="postid_7300330242">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-underwriter/7300290359.html"></a>,
#  <a class="result-title hdrlnk" data-id="7300290359" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-underwriter/7300290359.html" id="postid_7300290359">Mortgage Loan Underwriter</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-closer/7300290139.html"></a>,
#  <a class="result-title hdrlnk" data-id="7300290139" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-closer/7300290139.html" id="postid_7300290139">Mortgage Loan Closer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/medford-junior-items-processing-analyst/7300288495.html"></a>,
#  <a class="result-title hdrlnk" data-id="7300288495" href="https://boston.craigslist.org/gbs/sof/d/medford-junior-items-processing-analyst/7300288495.html" id="postid_7300288495">Junior Items Processing Analyst</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7300007467.html"></a>,
#  <a class="result-title hdrlnk" data-id="7300007467" href="https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7300007467.html" id="postid_7300007467">Data Science Fellowship</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7300007303.html"></a>,
#  <a class="result-title hdrlnk" data-id="7300007303" href="https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7300007303.html" id="postid_7300007303">Product Management Fellowship</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7300006937.html"></a>,
#  <a class="result-title hdrlnk" data-id="7300006937" href="https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7300006937.html" id="postid_7300006937">Software Engineering Fellowship</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-looking-for-senior-staff/7299811760.html"></a>,
#  <a class="result-title hdrlnk" data-id="7299811760" href="https://boston.craigslist.org/gbs/sof/d/boston-looking-for-senior-staff/7299811760.html" id="postid_7299811760">Looking For Senior/Staff Software Engineer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7299696969.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7299696969" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7299696969.html" id="postid_7299696969">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:01515_fq01DjyHQxqz_09G03e" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7299216813.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7299216813" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7299216813.html" id="postid_7299216813">Software Engineer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7299185378.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7299185378" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7299185378.html" id="postid_7299185378">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-vp-of-engineering/7299019544.html"></a>,
#  <a class="result-title hdrlnk" data-id="7299019544" href="https://boston.craigslist.org/gbs/sof/d/boston-vp-of-engineering/7299019544.html" id="postid_7299019544">VP of Engineering</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/bmw/sof/d/warwick-full-stack-developer/7298883871.html"></a>,
#  <a class="result-title hdrlnk" data-id="7298883871" href="https://boston.craigslist.org/bmw/sof/d/warwick-full-stack-developer/7298883871.html" id="postid_7298883871">FULL STACK DEVELOPER</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/newton-devops-engineer-new-position/7298826408.html"></a>,
#  <a class="result-title hdrlnk" data-id="7298826408" href="https://boston.craigslist.org/gbs/sof/d/newton-devops-engineer-new-position/7298826408.html" id="postid_7298826408">DevOps Engineer - New Position! Remote, in the office when it's safe</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/nwb/sof/d/woburn-senior-software-engineer-team/7298798871.html"></a>,
#  <a class="result-title hdrlnk" data-id="7298798871" href="https://boston.craigslist.org/nwb/sof/d/woburn-senior-software-engineer-team/7298798871.html" id="postid_7298798871">Senior Software Engineer/Team Coordinator</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7298474884.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7298474884" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7298474884.html" id="postid_7298474884">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/boston-front-backend-website-developer/7298302297.html"></a>,
#  <a class="result-title hdrlnk" data-id="7298302297" href="https://boston.craigslist.org/gbs/sof/d/boston-front-backend-website-developer/7298302297.html" id="postid_7298302297">Front / Backend Website Developer Team</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7298217510.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7298217510" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7298217510.html" id="postid_7298217510">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/brookline-cyber-security-analysts-earn/7298169719.html"></a>,
#  <a class="result-title hdrlnk" data-id="7298169719" href="https://boston.craigslist.org/gbs/sof/d/brookline-cyber-security-analysts-earn/7298169719.html" id="postid_7298169719">Cyber Security Analysts! Earn $56,000-$117,000 per year!</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7297396536.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7297396536" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7297396536.html" id="postid_7297396536">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7296925982.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7296925982" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7296925982.html" id="postid_7296925982">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:01515_fq01DjyHQxqz_09G03e" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7296729470.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7296729470" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7296729470.html" id="postid_7296729470">Software Engineer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/woburn-guitar-test-technician/7296377572.html"></a>,
#  <a class="result-title hdrlnk" data-id="7296377572" href="https://boston.craigslist.org/gbs/sof/d/woburn-guitar-test-technician/7296377572.html" id="postid_7296377572">Guitar Test Technician</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7296323620.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7296323620" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7296323620.html" id="postid_7296323620">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/cambridge-seeking-contractor-backend/7296062829.html"></a>,
#  <a class="result-title hdrlnk" data-id="7296062829" href="https://boston.craigslist.org/gbs/sof/d/cambridge-seeking-contractor-backend/7296062829.html" id="postid_7296062829">Seeking Contractor: Backend Developer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:01515_fq01DjyHQxqz_09G03e" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7295881009.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7295881009" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7295881009.html" id="postid_7295881009">Software Engineer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7295788648.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7295788648" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7295788648.html" id="postid_7295788648">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7294921377.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7294921377" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7294921377.html" id="postid_7294921377">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7294674291.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7294674291" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7294674291.html" id="postid_7294674291">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-closer/7293696773.html"></a>,
#  <a class="result-title hdrlnk" data-id="7293696773" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-closer/7293696773.html" id="postid_7293696773">Mortgage Loan Closer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-underwriter/7293696372.html"></a>,
#  <a class="result-title hdrlnk" data-id="7293696372" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-underwriter/7293696372.html" id="postid_7293696372">Mortgage Loan Underwriter</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/cambridge-engineering-manager/7293361981.html"></a>,
#  <a class="result-title hdrlnk" data-id="7293361981" href="https://boston.craigslist.org/gbs/sof/d/cambridge-engineering-manager/7293361981.html" id="postid_7293361981">Engineering Manager</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00g0g_7WM0QNiWTXhz_0g80aL,3:00F0F_4tKraUmdaJjz_0gw08g,3:00f0f_76tCtQSu1Pcz_07g08e,3:00f0f_8O1ptE2MSxiz_0he09H,3:00505_lpp8HLjlw75z_079082,3:00r0r_lKMurrDJyHvz_0kF071" href="https://boston.craigslist.org/gbs/sof/d/boston-best-in-demand-it-skills-job/7293165293.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7293165293" href="https://boston.craigslist.org/gbs/sof/d/boston-best-in-demand-it-skills-job/7293165293.html" id="postid_7293165293">Best In-Demand IT Skills &amp; Job Training Program</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/bmw/sof/d/north-chelmsford-software-developer/7293156483.html"></a>,
#  <a class="result-title hdrlnk" data-id="7293156483" href="https://boston.craigslist.org/bmw/sof/d/north-chelmsford-software-developer/7293156483.html" id="postid_7293156483">Software Developer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/nwb/sof/d/software-developer/7293155979.html"></a>,
#  <a class="result-title hdrlnk" data-id="7293155979" href="https://boston.craigslist.org/nwb/sof/d/software-developer/7293155979.html" id="postid_7293155979">Software Developer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/nwb/sof/d/software-developer/7293155440.html"></a>,
#  <a class="result-title hdrlnk" data-id="7293155440" href="https://boston.craigslist.org/nwb/sof/d/software-developer/7293155440.html" id="postid_7293155440">Software Developer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/bmw/sof/d/north-chelmsford-software-developer/7293154957.html"></a>,
#  <a class="result-title hdrlnk" data-id="7293154957" href="https://boston.craigslist.org/bmw/sof/d/north-chelmsford-software-developer/7293154957.html" id="postid_7293154957">Software Developer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://boston.craigslist.org/bmw/sof/d/marlborough-qa-document-control/7292785355.html"></a>,
#  <a class="result-title hdrlnk" data-id="7292785355" href="https://boston.craigslist.org/bmw/sof/d/marlborough-qa-document-control/7292785355.html" id="postid_7292785355">QA Document Control Associate/ QA Compliance Associate</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00j0j_izBLU6XrDnF_0pM0eg,3:00F0F_lUEVmePwdeb_0q00eE" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7292165185.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7292165185" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7292165185.html" id="postid_7292165185">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://providence.craigslist.org/sof/d/mansfield-manager-or-director/7305727506.html"></a>,
#  <a class="result-title hdrlnk" data-id="7305727506" href="https://providence.craigslist.org/sof/d/mansfield-manager-or-director/7305727506.html" id="postid_7305727506">Manager or Director, Professional Services</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://providence.craigslist.org/sof/d/warwick-full-stack-developer/7298867620.html"></a>,
#  <a class="result-title hdrlnk" data-id="7298867620" href="https://providence.craigslist.org/sof/d/warwick-full-stack-developer/7298867620.html" id="postid_7298867620">Full Stack Developer</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298487508.html"></a>,
#  <a class="result-title hdrlnk" data-id="7298487508" href="https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298487508.html" id="postid_7298487508">✭✭✭Start a Web Developer Career Today! No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298253649.html"></a>,
#  <a class="result-title hdrlnk" data-id="7298253649" href="https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298253649.html" id="postid_7298253649">✭✭✭Start a Web Developer Career Today! No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7294691934.html"></a>,
#  <a class="result-title hdrlnk" data-id="7294691934" href="https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7294691934.html" id="postid_7294691934">✭✭✭Start a Web Developer Career Today! No Experience Needed (Remote)</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery" data-ids="3:00j0j_ambV249uFxCz_0CI0jm" href="https://capecod.craigslist.org/sof/d/hyannis-estimator-templator/7291841605.html">
#  </a>,
#  <a class="result-title hdrlnk" data-id="7291841605" href="https://capecod.craigslist.org/sof/d/hyannis-estimator-templator/7291841605.html" id="postid_7291841605">Estimator/Templator</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="result-image gallery empty" href="https://hartford.craigslist.org/sof/d/hartford-cyber-security-analysts-earn/7298191991.html"></a>,
#  <a class="result-title hdrlnk" data-id="7298191991" href="https://hartford.craigslist.org/sof/d/hartford-cyber-security-analysts-earn/7298191991.html" id="postid_7298191991">Cyber Security Analysts! Earn $56,000-$117,000 per year!</a>,
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>,
#  <a class="backtotop button" href="#page-top">^ back to top</a>,
#  <a class="backtotop button" href="#page-top">^ back to top</a>,
#  <a href="">
#                  zoom out for all <span class="total">49</span>
#  </a>,
#  <a class="button first" href="/d/software-qa-dba-etc/search/sof" title="first page">&lt;&lt;</a>,
#  <a class="button prev" href="/d/software-qa-dba-etc/search/sof" title="previous page">&lt; prev</a>,
#  <a class="button next" href="" title="next page">next &gt; </a>,
#  <a href="https://www.craigslist.org/about/help/">help</a>,
#  <a href="https://www.craigslist.org/about/scams">safety</a>,
#  <a href="https://www.craigslist.org/about/privacy.policy">privacy</a>,
#  <a href="https://forums.craigslist.org/?forumID=8">feedback</a>,
#  <a href="https://www.craigslist.org/about/terms.of.use">terms</a>,
#  <a href="https://www.craigslist.org/about/">about</a>]

# %%
for tag in tags:
    print(tag.get('href'))
# Out:
# https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile
# https://apps.apple.com/us/app/craigslist/id1336642410
# /
# /
# https://post.craigslist.org/c/bos
# https://accounts.craigslist.org/login/home
# #
# #
# /
# https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fboston%2Ecraigslist%2Eorg%2Fd%2Fsoftware%2Dqa%2Ddba%2Detc%2Fsearch%2Fsof
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof?sort=date&
#
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof
#
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7306130076.html
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7306130076.html
# #
# https://boston.craigslist.org/gbs/sof/d/newton-highlands-xamarine-software/7306093632.html
# https://boston.craigslist.org/gbs/sof/d/newton-highlands-xamarine-software/7306093632.html
# #
# https://boston.craigslist.org/bmw/sof/d/boxborough-data-scientist-software/7304410862.html
# https://boston.craigslist.org/bmw/sof/d/boxborough-data-scientist-software/7304410862.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7303697158.html
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7303697158.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7302580375.html
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7302580375.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7301724610.html
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7301724610.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300999570.html
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300999570.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-python-engineer-weplayed-sports/7300896102.html
# https://boston.craigslist.org/gbs/sof/d/boston-python-engineer-weplayed-sports/7300896102.html
# #
# https://boston.craigslist.org/bmw/sof/d/framingham-database-tutor/7300534100.html
# https://boston.craigslist.org/bmw/sof/d/framingham-database-tutor/7300534100.html
# #
# https://boston.craigslist.org/nos/sof/d/billerica-powerbuilder-programmer/7300338438.html
# https://boston.craigslist.org/nos/sof/d/billerica-powerbuilder-programmer/7300338438.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300330242.html
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300330242.html
# #
# https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-underwriter/7300290359.html
# https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-underwriter/7300290359.html
# #
# https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-closer/7300290139.html
# https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-closer/7300290139.html
# #
# https://boston.craigslist.org/gbs/sof/d/medford-junior-items-processing-analyst/7300288495.html
# https://boston.craigslist.org/gbs/sof/d/medford-junior-items-processing-analyst/7300288495.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7300007467.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7300007467.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7300007303.html
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7300007303.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7300006937.html
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7300006937.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-looking-for-senior-staff/7299811760.html
# https://boston.craigslist.org/gbs/sof/d/boston-looking-for-senior-staff/7299811760.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7299696969.html
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7299696969.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7299216813.html
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7299216813.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7299185378.html
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7299185378.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-vp-of-engineering/7299019544.html
# https://boston.craigslist.org/gbs/sof/d/boston-vp-of-engineering/7299019544.html
# #
# https://boston.craigslist.org/bmw/sof/d/warwick-full-stack-developer/7298883871.html
# https://boston.craigslist.org/bmw/sof/d/warwick-full-stack-developer/7298883871.html
# #
# https://boston.craigslist.org/gbs/sof/d/newton-devops-engineer-new-position/7298826408.html
# https://boston.craigslist.org/gbs/sof/d/newton-devops-engineer-new-position/7298826408.html
# #
# https://boston.craigslist.org/nwb/sof/d/woburn-senior-software-engineer-team/7298798871.html
# https://boston.craigslist.org/nwb/sof/d/woburn-senior-software-engineer-team/7298798871.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7298474884.html
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7298474884.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-front-backend-website-developer/7298302297.html
# https://boston.craigslist.org/gbs/sof/d/boston-front-backend-website-developer/7298302297.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7298217510.html
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7298217510.html
# #
# https://boston.craigslist.org/gbs/sof/d/brookline-cyber-security-analysts-earn/7298169719.html
# https://boston.craigslist.org/gbs/sof/d/brookline-cyber-security-analysts-earn/7298169719.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7297396536.html
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7297396536.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7296925982.html
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7296925982.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7296729470.html
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7296729470.html
# #
# https://boston.craigslist.org/gbs/sof/d/woburn-guitar-test-technician/7296377572.html
# https://boston.craigslist.org/gbs/sof/d/woburn-guitar-test-technician/7296377572.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7296323620.html
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7296323620.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-seeking-contractor-backend/7296062829.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-seeking-contractor-backend/7296062829.html
# #
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7295881009.html
# https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7295881009.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7295788648.html
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7295788648.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7294921377.html
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7294921377.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7294674291.html
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7294674291.html
# #
# https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-closer/7293696773.html
# https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-closer/7293696773.html
# #
# https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-underwriter/7293696372.html
# https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-underwriter/7293696372.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-engineering-manager/7293361981.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-engineering-manager/7293361981.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-best-in-demand-it-skills-job/7293165293.html
# https://boston.craigslist.org/gbs/sof/d/boston-best-in-demand-it-skills-job/7293165293.html
# #
# https://boston.craigslist.org/bmw/sof/d/north-chelmsford-software-developer/7293156483.html
# https://boston.craigslist.org/bmw/sof/d/north-chelmsford-software-developer/7293156483.html
# #
# https://boston.craigslist.org/nwb/sof/d/software-developer/7293155979.html
# https://boston.craigslist.org/nwb/sof/d/software-developer/7293155979.html
# #
# https://boston.craigslist.org/nwb/sof/d/software-developer/7293155440.html
# https://boston.craigslist.org/nwb/sof/d/software-developer/7293155440.html
# #
# https://boston.craigslist.org/bmw/sof/d/north-chelmsford-software-developer/7293154957.html
# https://boston.craigslist.org/bmw/sof/d/north-chelmsford-software-developer/7293154957.html
# #
# https://boston.craigslist.org/bmw/sof/d/marlborough-qa-document-control/7292785355.html
# https://boston.craigslist.org/bmw/sof/d/marlborough-qa-document-control/7292785355.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7292165185.html
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7292165185.html
# #
# https://providence.craigslist.org/sof/d/mansfield-manager-or-director/7305727506.html
# https://providence.craigslist.org/sof/d/mansfield-manager-or-director/7305727506.html
# #
# https://providence.craigslist.org/sof/d/warwick-full-stack-developer/7298867620.html
# https://providence.craigslist.org/sof/d/warwick-full-stack-developer/7298867620.html
# #
# https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298487508.html
# https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298487508.html
# #
# https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298253649.html
# https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298253649.html
# #
# https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7294691934.html
# https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7294691934.html
# #
# https://capecod.craigslist.org/sof/d/hyannis-estimator-templator/7291841605.html
# https://capecod.craigslist.org/sof/d/hyannis-estimator-templator/7291841605.html
# #
# https://hartford.craigslist.org/sof/d/hartford-cyber-security-analysts-earn/7298191991.html
# https://hartford.craigslist.org/sof/d/hartford-cyber-security-analysts-earn/7298191991.html
# #
# #page-top
# #page-top
#
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof
#
# https://www.craigslist.org/about/help/
# https://www.craigslist.org/about/scams
# https://www.craigslist.org/about/privacy.policy
# https://forums.craigslist.org/?forumID=8
# https://www.craigslist.org/about/terms.of.use
# https://www.craigslist.org/about/

# %%
jobs = soup.find_all('div',{"class":"result-info"})

# %%
jobs
# Out:
# [<div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-13 10:29" title="Tue 13 Apr 10:29:23 AM">Apr 13</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7306130076" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7306130076.html" id="postid_7306130076">Software Engineer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Remote)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-13 09:16" title="Tue 13 Apr 09:16:19 AM">Apr 13</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7306093632" href="https://boston.craigslist.org/gbs/sof/d/newton-highlands-xamarine-software/7306093632.html" id="postid_7306093632">Xamarine Software Developer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Newton Highlands)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-09 17:59" title="Fri 09 Apr 05:59:17 PM">Apr  9</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7304410862" href="https://boston.craigslist.org/bmw/sof/d/boxborough-data-scientist-software/7304410862.html" id="postid_7304410862">Data Scientist &amp; Software Engineer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-08 12:34" title="Thu 08 Apr 12:34:29 PM">Apr  8</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7303697158" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7303697158.html" id="postid_7303697158">Software Engineer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Remote)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-06 10:44" title="Tue 06 Apr 10:44:04 AM">Apr  6</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7302580375" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7302580375.html" id="postid_7302580375">Software Engineer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Remote)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-04 13:51" title="Sun 04 Apr 01:51:21 PM">Apr  4</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7301724610" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7301724610.html" id="postid_7301724610">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-02 18:51" title="Fri 02 Apr 06:51:55 PM">Apr  2</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7300999570" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300999570.html" id="postid_7300999570">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-02 15:39" title="Fri 02 Apr 03:39:28 PM">Apr  2</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7300896102" href="https://boston.craigslist.org/gbs/sof/d/boston-python-engineer-weplayed-sports/7300896102.html" id="postid_7300896102">Python Engineer @ WePlayed Sports</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Boston (remote or on-site))</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-01 20:37" title="Thu 01 Apr 08:37:08 PM">Apr  1</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7300534100" href="https://boston.craigslist.org/bmw/sof/d/framingham-database-tutor/7300534100.html" id="postid_7300534100">database tutor</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (FRAMINGHAM)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-01 14:08" title="Thu 01 Apr 02:08:05 PM">Apr  1</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7300338438" href="https://boston.craigslist.org/nos/sof/d/billerica-powerbuilder-programmer/7300338438.html" id="postid_7300338438">PowerBuilder Programmer/Analyst Position</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Billerica)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-01 13:54" title="Thu 01 Apr 01:54:50 PM">Apr  1</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7300330242" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300330242.html" id="postid_7300330242">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-01 12:51" title="Thu 01 Apr 12:51:09 PM">Apr  1</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7300290359" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-underwriter/7300290359.html" id="postid_7300290359">Mortgage Loan Underwriter</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Medford, MA)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-01 12:50" title="Thu 01 Apr 12:50:53 PM">Apr  1</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7300290139" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-closer/7300290139.html" id="postid_7300290139">Mortgage Loan Closer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Medford, MA)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-01 12:48" title="Thu 01 Apr 12:48:15 PM">Apr  1</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7300288495" href="https://boston.craigslist.org/gbs/sof/d/medford-junior-items-processing-analyst/7300288495.html" id="postid_7300288495">Junior Items Processing Analyst</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Medford)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-31 19:08" title="Wed 31 Mar 07:08:03 PM">Mar 31</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7300007467" href="https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7300007467.html" id="postid_7300007467">Data Science Fellowship</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-31 19:07" title="Wed 31 Mar 07:07:39 PM">Mar 31</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7300007303" href="https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7300007303.html" id="postid_7300007303">Product Management Fellowship</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-31 19:06" title="Wed 31 Mar 07:06:47 PM">Mar 31</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7300006937" href="https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7300006937.html" id="postid_7300006937">Software Engineering Fellowship</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-31 13:09" title="Wed 31 Mar 01:09:34 PM">Mar 31</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7299811760" href="https://boston.craigslist.org/gbs/sof/d/boston-looking-for-senior-staff/7299811760.html" id="postid_7299811760">Looking For Senior/Staff Software Engineer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Remote)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-31 09:56" title="Wed 31 Mar 09:56:09 AM">Mar 31</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7299696969" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7299696969.html" id="postid_7299696969">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-30 10:36" title="Tue 30 Mar 10:36:09 AM">Mar 30</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7299216813" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7299216813.html" id="postid_7299216813">Software Engineer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Remote)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-30 09:33" title="Tue 30 Mar 09:33:46 AM">Mar 30</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7299185378" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7299185378.html" id="postid_7299185378">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-29 19:40" title="Mon 29 Mar 07:40:00 PM">Mar 29</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7299019544" href="https://boston.craigslist.org/gbs/sof/d/boston-vp-of-engineering/7299019544.html" id="postid_7299019544">VP of Engineering</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (boston: boston/cambridge/brookline)</span>
#  <span class="result-tags">
#  <span class="pictag">img</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-29 15:22" title="Mon 29 Mar 03:22:51 PM">Mar 29</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7298883871" href="https://boston.craigslist.org/bmw/sof/d/warwick-full-stack-developer/7298883871.html" id="postid_7298883871">FULL STACK DEVELOPER</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Rhode Island)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-29 13:51" title="Mon 29 Mar 01:51:25 PM">Mar 29</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7298826408" href="https://boston.craigslist.org/gbs/sof/d/newton-devops-engineer-new-position/7298826408.html" id="postid_7298826408">DevOps Engineer - New Position! Remote, in the office when it's safe</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Newton, MA)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-29 13:09" title="Mon 29 Mar 01:09:30 PM">Mar 29</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7298798871" href="https://boston.craigslist.org/nwb/sof/d/woburn-senior-software-engineer-team/7298798871.html" id="postid_7298798871">Senior Software Engineer/Team Coordinator</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Woburn)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-28 18:22" title="Sun 28 Mar 06:22:34 PM">Mar 28</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7298474884" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7298474884.html" id="postid_7298474884">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-28 13:02" title="Sun 28 Mar 01:02:32 PM">Mar 28</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7298302297" href="https://boston.craigslist.org/gbs/sof/d/boston-front-backend-website-developer/7298302297.html" id="postid_7298302297">Front / Backend Website Developer Team</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> ((Local or Remote USA ONLY))</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-28 10:15" title="Sun 28 Mar 10:15:57 AM">Mar 28</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7298217510" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7298217510.html" id="postid_7298217510">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-28 07:13" title="Sun 28 Mar 07:13:51 AM">Mar 28</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7298169719" href="https://boston.craigslist.org/gbs/sof/d/brookline-cyber-security-analysts-earn/7298169719.html" id="postid_7298169719">Cyber Security Analysts! Earn $56,000-$117,000 per year!</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Boston, MA)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-26 14:36" title="Fri 26 Mar 02:36:17 PM">Mar 26</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7297396536" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7297396536.html" id="postid_7297396536">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-25 15:48" title="Thu 25 Mar 03:48:38 PM">Mar 25</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7296925982" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7296925982.html" id="postid_7296925982">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-25 10:26" title="Thu 25 Mar 10:26:17 AM">Mar 25</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7296729470" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7296729470.html" id="postid_7296729470">Software Engineer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Remote)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-24 14:35" title="Wed 24 Mar 02:35:26 PM">Mar 24</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7296377572" href="https://boston.craigslist.org/gbs/sof/d/woburn-guitar-test-technician/7296377572.html" id="postid_7296377572">Guitar Test Technician</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Woburn)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-24 13:11" title="Wed 24 Mar 01:11:34 PM">Mar 24</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7296323620" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7296323620.html" id="postid_7296323620">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-23 21:08" title="Tue 23 Mar 09:08:27 PM">Mar 23</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7296062829" href="https://boston.craigslist.org/gbs/sof/d/cambridge-seeking-contractor-backend/7296062829.html" id="postid_7296062829">Seeking Contractor: Backend Developer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-23 15:07" title="Tue 23 Mar 03:07:54 PM">Mar 23</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7295881009" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7295881009.html" id="postid_7295881009">Software Engineer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Remote)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-23 12:45" title="Tue 23 Mar 12:45:41 PM">Mar 23</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7295788648" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7295788648.html" id="postid_7295788648">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-21 17:16" title="Sun 21 Mar 05:16:46 PM">Mar 21</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7294921377" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7294921377.html" id="postid_7294921377">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-21 08:57" title="Sun 21 Mar 08:57:24 AM">Mar 21</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7294674291" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7294674291.html" id="postid_7294674291">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-19 10:24" title="Fri 19 Mar 10:24:00 AM">Mar 19</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7293696773" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-closer/7293696773.html" id="postid_7293696773">Mortgage Loan Closer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Medford, MA)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-19 10:23" title="Fri 19 Mar 10:23:15 AM">Mar 19</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7293696372" href="https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-underwriter/7293696372.html" id="postid_7293696372">Mortgage Loan Underwriter</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Medford, MA)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-18 15:10" title="Thu 18 Mar 03:10:30 PM">Mar 18</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7293361981" href="https://boston.craigslist.org/gbs/sof/d/cambridge-engineering-manager/7293361981.html" id="postid_7293361981">Engineering Manager</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Cambriidge)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-18 09:53" title="Thu 18 Mar 09:53:14 AM">Mar 18</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7293165293" href="https://boston.craigslist.org/gbs/sof/d/boston-best-in-demand-it-skills-job/7293165293.html" id="postid_7293165293">Best In-Demand IT Skills &amp; Job Training Program</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-18 09:33" title="Thu 18 Mar 09:33:31 AM">Mar 18</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7293156483" href="https://boston.craigslist.org/bmw/sof/d/north-chelmsford-software-developer/7293156483.html" id="postid_7293156483">Software Developer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (North Chelmsford)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-18 09:32" title="Thu 18 Mar 09:32:24 AM">Mar 18</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7293155979" href="https://boston.craigslist.org/nwb/sof/d/software-developer/7293155979.html" id="postid_7293155979">Software Developer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (North Chelmsford)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-18 09:31" title="Thu 18 Mar 09:31:19 AM">Mar 18</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7293155440" href="https://boston.craigslist.org/nwb/sof/d/software-developer/7293155440.html" id="postid_7293155440">Software Developer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (North Chelmsford)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-18 09:30" title="Thu 18 Mar 09:30:15 AM">Mar 18</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7293154957" href="https://boston.craigslist.org/bmw/sof/d/north-chelmsford-software-developer/7293154957.html" id="postid_7293154957">Software Developer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (North Chelmsford)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-17 13:12" title="Wed 17 Mar 01:12:37 PM">Mar 17</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7292785355" href="https://boston.craigslist.org/bmw/sof/d/marlborough-qa-document-control/7292785355.html" id="postid_7292785355">QA Document Control Associate/ QA Compliance Associate</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> (Marlborough, MA)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-16 10:06" title="Tue 16 Mar 10:06:01 AM">Mar 16</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7292165185" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7292165185.html" id="postid_7292165185">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-12 13:40" title="Mon 12 Apr 01:40:03 PM">Apr 12</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7305727506" href="https://providence.craigslist.org/sof/d/mansfield-manager-or-director/7305727506.html" id="postid_7305727506">Manager or Director, Professional Services</a>
#  </h3>
#  <span class="result-meta">
#  <span class="nearby" title="rhode island">(prv &gt; Mansfield, MA)</span>
#  <span class="result-tags">
#  <span class="pictag">img</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-29 14:56" title="Mon 29 Mar 02:56:52 PM">Mar 29</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7298867620" href="https://providence.craigslist.org/sof/d/warwick-full-stack-developer/7298867620.html" id="postid_7298867620">Full Stack Developer</a>
#  </h3>
#  <span class="result-meta">
#  <span class="nearby" title="rhode island">(prv &gt; REGIONAL)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-28 18:52" title="Sun 28 Mar 06:52:11 PM">Mar 28</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7298487508" href="https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298487508.html" id="postid_7298487508">✭✭✭Start a Web Developer Career Today! No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="nearby" title="rhode island">(prv)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-28 11:34" title="Sun 28 Mar 11:34:07 AM">Mar 28</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7298253649" href="https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298253649.html" id="postid_7298253649">✭✭✭Start a Web Developer Career Today! No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="nearby" title="rhode island">(prv)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-21 09:50" title="Sun 21 Mar 09:50:21 AM">Mar 21</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7294691934" href="https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7294691934.html" id="postid_7294691934">✭✭✭Start a Web Developer Career Today! No Experience Needed (Remote)</a>
#  </h3>
#  <span class="result-meta">
#  <span class="nearby" title="rhode island">(prv)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-15 15:14" title="Mon 15 Mar 03:14:03 PM">Mar 15</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7291841605" href="https://capecod.craigslist.org/sof/d/hyannis-estimator-templator/7291841605.html" id="postid_7291841605">Estimator/Templator</a>
#  </h3>
#  <span class="result-meta">
#  <span class="nearby" title="cape cod / islands">(cap &gt; hyannis)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>,
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-03-28 09:03" title="Sun 28 Mar 09:03:59 AM">Mar 28</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7298191991" href="https://hartford.craigslist.org/sof/d/hartford-cyber-security-analysts-earn/7298191991.html" id="postid_7298191991">Cyber Security Analysts! Earn $56,000-$117,000 per year!</a>
#  </h3>
#  <span class="result-meta">
#  <span class="nearby" title="hartford, CT">(htf &gt; Hartford, CT)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>]

# %%
npo_jobs = {}
job_no = 0
while True:
    for job in jobs:
        title = job.find("a",{"class":"result-title hdrlnk"}).text
        location_tag = job.find("span",{"class":"result-hood"})
        location = location_tag.text[2:-1] if location_tag else "N/A"
        date = job.find("time",{"class":"result-date"}).text
        link = job.find("a",{"class":"result-title hdrlnk"}).get("href")
        job_response = requests.get(link)
        job_data = job_response.text
        job_soup = BeautifulSoup(job_data,'html.parser')
        job_description = job_soup.find('section',{'id':'postingbody'}).text
        job_atributtes_tag = job_soup.find('p',{'class':'attrgroup'})
        job_atributtes = job_atributtes_tag.text if job_atributtes_tag else 'N/A'
        
        job_no+=1
        npo_jobs[job_no]=[title,location,date,link,job_atributtes,job_description]
        
        print("Job Title: ",title, "\nLocation: ",location,"\nDate:",date,"\nLink: ",link,"\n", job_atributtes,"\nJob Description:",job_description,"\n-----")
    url_tag = soup.find('a',{'title':'next page'})
    if url_tag.get('href'):
        url = 'https://boston.craigslist.org' + url_tag.get('href')
        print(url)
    else:
        break
print('Total Jobs: ', job_no)
npo_jobs_df = pd.DataFrame.from_dict(npo_jobs,orient='index',columns=['Job Title','Location','Date','Link','Job Attributes','Job Description'])
# Out:
# Job Title:  Software Engineer
# Location:  Remote
# Date: Apr 13
# Link:  https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7306130076.html
#
# compensation: To Be Discussed
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
# Join Hired and find your dream job as a Software Engineer at one of 10,000+ companies looking for candidates just like you.
# This is a role that fuses both creative and practical concerns, as these engineers are responsible for everything the website user encounters, including scrolling functions and graphics, as well as creating the logic, database interactions and server configuration on the application's backend.
#
# Responsibilities Include:
#
# The development and maintenance of client-side and server-side applications.
# Working with other web developers as well as marketing teams and engineers to ensure the right look and necessary features are included in your work.
# Designing tests that will be implemented to keep software functional.
# Stay on top of expanding technologies and engineering trends.
#
#
#
# Companies on Hired apply to you, not the other way around. You'll receive salary and compensation details upfront - before the interview - and be able to choose from a variety of industries you're interested in, to find a job You'll love in less than 2 weeks.
# To Learn More and Apply: Click Here
# -----
# Job Title:  Xamarine Software Developer
# Location:  Newton Highlands
# Date: Apr 13
# Link:  https://boston.craigslist.org/gbs/sof/d/newton-highlands-xamarine-software/7306093632.html
#
# compensation: based on candidate's experience
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Our company, a Boston based system developer is looking for full stack hands-on Xamarin Software
# Developer to join our team! It's not a remote job, it's a full time employment and you need to be on site everyday.(some flexibility is available)
# We are small team of 4 people in the office on a daily basis.
# We provide SaaS products to our clients throughout the US and internationally.
# We focus on customer software solutions in the unattended retail marketplace, including scheduling
# and routing, sales and inventory transaction processing, remote data acquisition from automated and
# unattended points of sale, service call tracking.
# DUTIES/RESPONSIBILITIES:
#  Design, develop, test, and maintain mobile applications for iOS and Android on the Xamarin
# platform
#  Diagnose complex issues, evaluate, and recommend/execute the best resolution
#  Influence system design by identifying and recommending design and requirement needs for
# software
#  Write code that meets the production requirements and design specifications
#  Implement manual and automated testing for the mobile application development process
#  Participate in design reviews to provide a technical perspective on implementation
#  Able to perform research of Third-party tools and undertake implementation of them
#  Be able to comprehend, analyze and communicate Business requirements and issues arising
# from existing published implementations
#  Publishing app to testing environments and app stores.
# SKILLS/EXPERIENCE:
#  Bachelor’s in computer science, Computer Systems Engineering or a similar engineering
# discipline.
#  2-5 years of Full Stack experience in Software Development with Xamarin and associated
# Microsoft development tools and environment
#  Proven delivery experience with Xamarin, C# .NET and SQL, as well as ASP, MVVC, WCF,
# REST. Significant SQL server experience including schema development, query analysis
# and optimization.  Visual Studio and Infragistics.
#  Knowledge and expertise with Bluetooth and general wireless communication protocols
# This is a hands-on software development role with opportunity to grow and take on enhanced
# responsibilities for the development and direction of the product.
# The company name is Synectic Software Solutions. Web site is http://www.synecticssi.com/
# The product is here: http://www.vendsys.com/
# Synectic Software Solutions is a subsidiary of the Nayax company: https://www.nayax.com/about-
# nayax/
# -----
# Job Title:  Data Scientist & Software Engineer
# Location:  N/A
# Date: Apr  9
# Link:  https://boston.craigslist.org/bmw/sof/d/boxborough-data-scientist-software/7304410862.html
#
# compensation: TBD
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Cisco Systems, Inc. is accepting resumes for multiple positions in Boxborough, MA:  Data Scientist (Ref#: BOX435B): Define business goals that are expected from the insights derived from ‘Big Data’. Software Engineer (Ref#: BOX003B): Responsible for the definition, design, development, test, debugging, release, enhancement or maintenance of software/networking software.
#
# Please mail resumes with reference number to Cisco Systems, Inc., Attn: G51G, 170 W. Tasman Drive, Mail Stop: SJC 5/1/4, San Jose, CA 95134.  No phone calls please.  Must be legally authorized to work in the U.S. without sponsorship.  EOE.
# www.cisco.com
#
# -----
# Job Title:  Software Engineer
# Location:  Remote
# Date: Apr  8
# Link:  https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7303697158.html
#
# compensation: To Be Discussed
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
# Join Hired and find your dream job as a Software Engineer at one of 10,000+ companies looking for candidates just like you.
# This is a role that fuses both creative and practical concerns, as these engineers are responsible for everything the website user encounters, including scrolling functions and graphics, as well as creating the logic, database interactions and server configuration on the application's backend.
#
# Responsibilities Include:
#
# The development and maintenance of client-side and server-side applications.
# Working with other web developers as well as marketing teams and engineers to ensure the right look and necessary features are included in your work.
# Designing tests that will be implemented to keep software functional.
# Stay on top of expanding technologies and engineering trends.
#
#
#
# Companies on Hired apply to you, not the other way around. You'll receive salary and compensation details upfront - before the interview - and be able to choose from a variety of industries you're interested in, to find a job You'll love in less than 2 weeks.
# To Learn More and Apply: Click Here
# -----
# Job Title:  Software Engineer
# Location:  Remote
# Date: Apr  6
# Link:  https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7302580375.html
#
# compensation: To Be Discussed
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
# Join Hired and find your dream job as a Software Engineer at one of 10,000+ companies looking for candidates just like you.
# This is a role that fuses both creative and practical concerns, as these engineers are responsible for everything the website user encounters, including scrolling functions and graphics, as well as creating the logic, database interactions and server configuration on the application's backend.
#
# Responsibilities Include:
#
# The development and maintenance of client-side and server-side applications.
# Working with other web developers as well as marketing teams and engineers to ensure the right look and necessary features are included in your work.
# Designing tests that will be implemented to keep software functional.
# Stay on top of expanding technologies and engineering trends.
#
#
#
# Companies on Hired apply to you, not the other way around. You'll receive salary and compensation details upfront - before the interview - and be able to choose from a variety of industries you're interested in, to find a job You'll love in less than 2 weeks.
# To Learn More and Apply: Click Here
# -----
# Job Title:  ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# Location:  N/A
# Date: Apr  4
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7301724610.html
#
# compensation: $60,000-$120,000 depending on the company
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Start your next career in tech by joining Career Karma where we will help you prepare to become a Software Developer and help you get accepted into top Software job training programs. Career Karma is always free.
#
# Average graduate salaries range between $60,000-120,000 per year in Coding, Design, Data Science roles.
#
# 👉How to apply:  fill out this 1 minute form
#
# What is Career Karma?
# Career Karma is a free service that helps you explore courses and connect with other students like you, taking online courses to learn new in-demand skills. In less than 30 days, we will help you discover tech careers, prepare and get accepted into top job training programs in Boston.
#
# We’ve helped thousands of people get high paying jobs in less than 12 months. Check out the story of Kesha Lake, who is a mom and music teacher. She joined Career Karma in January 2019 by November 2019, we helped her get a  Remote Software Engineering job making $98,000 working for StitchFix.
#
# 📺Here is a video with our founder Ruben Harris on CNBC explaining how we have helped 100,000 Americans get jobs in technology.
#
#
# Who is this for:
# - Desire to acquire a new high in demand skill (like coding, design, cyber security, data science and analytics, and sales)
# - Have a high level of motivation, energy, and attitude
#
#
# Other highlights:
# - No previous experience in technology
# - No degree necessary
# - No upfront deposit or fees to Join Career Karma. Completely FREE
# - No one is too young or too old
# - Diverse backgrounds is a plus
#
# 👉How to apply:  fill out this 1 minute form
#
#
#
#
# -----
# Job Title:  ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# Location:  N/A
# Date: Apr  2
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300999570.html
#
# compensation: $60,000-$120,000 depending on the company
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Start your next career in tech by joining Career Karma where we will help you prepare to become a Software Developer and help you get accepted into top Software job training programs. Career Karma is always free.
#
# Average graduate salaries range between $60,000-120,000 per year in Coding, Design, Data Science roles.
#
# 👉How to apply:  fill out this 1 minute form
#
# What is Career Karma?
# Career Karma is a free service that helps you explore courses and connect with other students like you, taking online courses to learn new in-demand skills. In less than 30 days, we will help you discover tech careers, prepare and get accepted into top job training programs in Boston.
#
# We’ve helped thousands of people get high paying jobs in less than 12 months. Check out the story of Kesha Lake, who is a mom and music teacher. She joined Career Karma in January 2019 by November 2019, we helped her get a  Remote Software Engineering job making $98,000 working for StitchFix.
#
# 📺Here is a video with our founder Ruben Harris on CNBC explaining how we have helped 100,000 Americans get jobs in technology.
#
#
# Who is this for:
# - Desire to acquire a new high in demand skill (like coding, design, cyber security, data science and analytics, and sales)
# - Have a high level of motivation, energy, and attitude
#
#
# Other highlights:
# - No previous experience in technology
# - No degree necessary
# - No upfront deposit or fees to Join Career Karma. Completely FREE
# - No one is too young or too old
# - Diverse backgrounds is a plus
#
# 👉How to apply:  fill out this 1 minute form
#
#
#
#
# -----
# Job Title:  Python Engineer @ WePlayed Sports
# Location:  Boston (remote or on-site)
# Date: Apr  2
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-python-engineer-weplayed-sports/7300896102.html
#
# compensation: negotiable
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# About WePlayed.com:
#
# Our Team
#
# We are a small, well-funded start-up team of entrepreneurs focused on building a high-tech sports video platform. Our team includes former professional athletes and senior media and tech executives. Our development team consists of just a handful of true experts (UI, CV/ML, Big Data). WePlayed graduated from TechStars in 2019 and recently secured VC funding from a top-tier Boston-based venture capital firm.
#
# Our Tech
#
# We leverage Computer Vision and Machine Learning in our core technology. Currently, our primary product offering helps colleges and universities manage and publish their video content in short-form clips we call “Moments.” Check out these for more info: https://weplayed.com/intro and https://about.weplayed.com/. Our customers include over thirty D1 schools as well as smaller universities. We have secured media-rights and partnerships with NCAA, SEC, ACC, Big 12 and other market-leading channel partners. We are looking to grow beyond college sports to create an ecosystem where every “Moment” is easily discoverable to the sports community.
#
# Our Culture
#
# We believe in work-life balance and walk the walk – we focus on outcomes and goals rather than screen-time or face-time. We trust our team members and support and empower them when times get tough for any reason. We take a novel approach to helping our employees with career development and plan ahead for 5-10 years. Most importantly: we believe in and cultivate diversity and inclusion.
#
# About You
#
#  * You are really passionate about sports data, sports video, and most importantly, Python!
#  * You are a smart and self-motivated individual that enjoys working with likeminded people.
#  * You are outgoing, communicate very well and are never afraid to ask questions or to share new ideas.
#  * You thrive in fast-moving environments that are looking to build something cool while keeping quality and long-term vision in mind.
#  * You have a successful track record of working in startups, wearing many hats and taking ownership.
#  * You don’t always wait for requirements and specs to be fully formed – you are comfortable helping to figure things out in an agile way.
#  * You love building data-based systems and are no stranger to AWS.
#  * You consider the Linux/Unix command line to be your best non-human friend.
#  * You look after the production environment like it is your baby.
#  * You might not always Obey the Testing Goat but you recognize the value in the methodology and leverage test automation whenever possible.
#  * You have found your groove and enjoy working remotely.
#  * You are comfortable working in the Eastern time zone and look forward to in-person team events a couple of times a year (around Boston).
#
# Position Mission Statement
#
# Take ownership of various WePlayed backend systems including game data and roster management, all API interfaces and integrations, video serving, logging and many more. Introduce a number of key product features and new systems as the WePlayed platform enters the market. Introduce new design patterns and refactor existing modules with best practices, scalability and performance in mind. Report to and work closely with the CTO/Co-founder, collaborate with a small team of developers including Web UI and Computer Vision / ML engineers.
#
# Let’s Chat!
#
# To apply, please visit this page:
#
# https://forms.gle/rA6VGWL6KkCngKBU7
#
# This is a full-time, salaried and mostly-or-all-remote position.
#
# You must be authorized to work in the US to apply for this position.
#
# Unfortunately at this time WePlayed is not open to working with third-party recruiting agencies, vendors or contractors.
# -----
# Job Title:  database tutor
# Location:  FRAMINGHAM
# Date: Apr  1
# Link:  https://boston.craigslist.org/bmw/sof/d/framingham-database-tutor/7300534100.html
#
# compensation: depends on experience.
#
# employment type: contract
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Need tutoring on Access,SQL server and RDBMS
# Hourly rate, contract labor.  Should have experience in databasee applications development and maintenance.
# call 617-930-1684 Marc I am in Framingham.  Hours are flexible.  Let us discuss a potential match.
# -----
# Job Title:  PowerBuilder Programmer/Analyst Position
# Location:  Billerica
# Date: Apr  1
# Link:  https://boston.craigslist.org/nos/sof/d/billerica-powerbuilder-programmer/7300338438.html
#
# compensation: tbd
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# McCracken Financial Solutions, located in Billerica Ma., is a leading software provider for the financial lending industry. McCracken clients are the top commercial lenders including Mortgage Bankers, Banks, Insurance Agencies, Government Agencies, Credit Companies and Thrifts servicing mortgage loans on our STRATEGY system.  Our products support the origination and servicing of commercial loans from the application process to the disposition of the loan including asset management, accounting and customer communication.
#
# Job description:
# The ideal candidate will work as a member of the development team for our Strategy application. Candidates will be responsible for analysis, design, development, and testing of user interfaces using PowerBuilder and DB2.
#
# Requirements:
# This position is for a PowerBuilder candidate to work in PowerBuilder
#
# •	2-4 years of PowerBuilder required - will support current software application which is written in PowerBuilder using PFC and object oriented techniques.
# •	Will be writing SQL stored procedures in DB2 on IBM  iSeries.
# •	Must be able to hit the ground running - object inheritance, client server experience, relational DBMS experience.
# •	Must have excellent written and verbal communications skills and be a team player.
# •	Must be competent working through all phases of the SDLC, in either a team environment or independently.
# •	Outstanding analytical skills - Self starter, someone who naturally takes initiative, is pro-active and can work independently on a variety of projects.
# •	Ability to write technical documents and provide adequate documentation in code and in formal formats.
#
# Desired Profile:
# •	Object Oriented Programming experience is preferred
# •	Prior PowerBuilder experience required
# •	Two+ years of PFC (PowerBuilder Foundation Classes) preferred
#
# Applicants must be a U.S. citizen or a "U.S. Person". A U.S. Person is defined as a person who is a lawful permanent resident “Green Card holder" as defined by 8 U.S.C. 1101 (a)(20) or who is a "Protected Individual" as defined by 8 U.S.C. 1324b(a)(3).
#
# No telephone calls for this position will be accepted.
# No third party recruiters
#
# -----
# Job Title:  ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# Location:  N/A
# Date: Apr  1
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7300330242.html
#
# compensation: $60,000-$120,000 depending on the company
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Start your next career in tech by joining Career Karma where we will help you prepare to become a Software Developer and help you get accepted into top Software job training programs. Career Karma is always free.
#
# Average graduate salaries range between $60,000-120,000 per year in Coding, Design, Data Science roles.
#
# 👉How to apply:  fill out this 1 minute form
#
# What is Career Karma?
# Career Karma is a free service that helps you explore courses and connect with other students like you, taking online courses to learn new in-demand skills. In less than 30 days, we will help you discover tech careers, prepare and get accepted into top job training programs in Boston.
#
# We’ve helped thousands of people get high paying jobs in less than 12 months. Check out the story of Kesha Lake, who is a mom and music teacher. She joined Career Karma in January 2019 by November 2019, we helped her get a  Remote Software Engineering job making $98,000 working for StitchFix.
#
# 📺Here is a video with our founder Ruben Harris on CNBC explaining how we have helped 100,000 Americans get jobs in technology.
#
#
# Who is this for:
# - Desire to acquire a new high in demand skill (like coding, design, cyber security, data science and analytics, and sales)
# - Have a high level of motivation, energy, and attitude
#
#
# Other highlights:
# - No previous experience in technology
# - No degree necessary
# - No upfront deposit or fees to Join Career Karma. Completely FREE
# - No one is too young or too old
# - Diverse backgrounds is a plus
#
# 👉How to apply:  fill out this 1 minute form
#
#
#
#
# -----
# Job Title:  Mortgage Loan Underwriter
# Location:  Medford, MA
# Date: Apr  1
# Link:  https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-underwriter/7300290359.html
#
# compensation: Commensurate with Experience
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Founded locally in 1969 by Marshall M. Sloane, Century Bank is New England's largest family‐run bank with 27 branches throughout Greater Boston. Today Century Bank is the Bank families and businesses rely on -- a place where you can count on getting personal attention. Whether you need a free checking account, easy online banking or a sophisticated financial solution, you'll find it at Century Bank. For more information, visit www.CenturyBank.com.
# Currently, we are searching for enthusiastic individuals to join the Century team!
# Job overview:
#
#  Reporting to the Senior Vice President of Consumer Lending, the candidate for this position analyzes employment profile, credit strength, property characteristics, and all other information pertinent to the credit decision process on each mortgage application.  Underwrites and recommends for approval, denial, suspension or counteroffer, mortgage applications in accordance with established bank strategies, policies and procedures while also ensuring compliance with state and federal regulatory requirements. Maintains a constant working knowledge of portfolio and PMI underwriting guidelines as outlined in the bank’s credit policy manual.  Works closely with processing staff and branch managers to ensure all required documentation is obtained, reviewed and acceptable.
# Responsibilities:
# -----
# Job Title:  Mortgage Loan Closer
# Location:  Medford, MA
# Date: Apr  1
# Link:  https://boston.craigslist.org/gbs/sof/d/medford-mortgage-loan-closer/7300290139.html
#
# compensation: Commensurate with Experience
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Founded locally in 1969 by Marshall M. Sloane, Century Bank is New England's largest family‐run bank with 27 branches throughout Greater Boston. Today Century Bank is the Bank families and businesses rely on -- a place where you can count on getting personal attention. Whether you need a free checking account, easy online banking or a sophisticated financial solution, you'll find it at Century Bank. For more information, visit www.CenturyBank.com.
# Currently, we are searching for enthusiastic individuals to join the Century team!
# Job overview:
#
# The focus of the Mortgage Loan Closer is to coordinate loan closings for purchase and refinance mortgages, home equity lines/loans and HEAT loans in compliance with industry and banking regulations and standards.
# Responsibilities:
# -----
# Job Title:  Junior Items Processing Analyst
# Location:  Medford
# Date: Apr  1
# Link:  https://boston.craigslist.org/gbs/sof/d/medford-junior-items-processing-analyst/7300288495.html
#
# compensation: Commensurate with Experience.
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Founded locally in 1969 by Marshall M. Sloane, Century Bank is New England's largest family‐run bank with 27 branches throughout Greater Boston. Today Century Bank is the Bank families and businesses rely on -- a place where you can count on getting personal attention. Whether you need a free checking account, easy online banking or a sophisticated financial solution, you'll find it at Century Bank. For more information, visit www.CenturyBank.com.
# Currently, we are searching for enthusiastic individuals to join the Century team!
# Job overview:
#
#  Under the direction of the Items Processing Systems Analyst, this individual will help support the Items Processing applications and operations.
# Responsibilities:
# -----
# Job Title:  Data Science Fellowship
# Location:  N/A
# Date: Mar 31
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7300007467.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 1000 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# -----
# Job Title:  Product Management Fellowship
# Location:  N/A
# Date: Mar 31
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7300007303.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued tech professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 1000 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new professionals that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for tech professionals in their career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are interested in getting the best possible job in tech.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosproduct&utm_medium=job_board
#
# -----
# Job Title:  Software Engineering Fellowship
# Location:  N/A
# Date: Mar 31
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7300006937.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued tech professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 1000 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new professionals that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for tech professionals in their career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are interested in getting the best possible job in tech.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosswe&utm_medium=job_board
# -----
# Job Title:  Looking For Senior/Staff Software Engineer
# Location:  Remote
# Date: Mar 31
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-looking-for-senior-staff/7299811760.html
#
# compensation: Above Market! Highly competitive!
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Senior Software Engineer with +7 years of professional Experience
#
# - High Volume
# - Scalability
# - Unit Testing
# - Integration testing
# - Stress Testing
# - Infrastructure Design
# - SOX
#
# Experience in
# Sql
# Kafka
# Memcache
# Solar
# PHP
# Python
#
# Experience working in large teams, Sprint/Agile.
# Experience leading and overseeing tech initiatives
#
# Full Benefits, PTO, etc...
#
# Please send me an Updated Resume!
#
# A summary of your experience, and why you think you can lead/mentor a team of 10-15 Engineers, guide the direction and delivery of small to large scale technical initiatives.
# -----
# Job Title:  ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# Location:  N/A
# Date: Mar 31
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7299696969.html
#
# compensation: $60,000-$120,000 depending on the company
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Start your next career in tech by joining Career Karma where we will help you prepare to become a Software Developer and help you get accepted into top Software job training programs. Career Karma is always free.
#
# Average graduate salaries range between $60,000-120,000 per year in Coding, Design, Data Science roles.
#
# 👉How to apply:  fill out this 1 minute form
#
# What is Career Karma?
# Career Karma is a free service that helps you explore courses and connect with other students like you, taking online courses to learn new in-demand skills. In less than 30 days, we will help you discover tech careers, prepare and get accepted into top job training programs in Boston.
#
# We’ve helped thousands of people get high paying jobs in less than 12 months. Check out the story of Kesha Lake, who is a mom and music teacher. She joined Career Karma in January 2019 by November 2019, we helped her get a  Remote Software Engineering job making $98,000 working for StitchFix.
#
# 📺Here is a video with our founder Ruben Harris on CNBC explaining how we have helped 100,000 Americans get jobs in technology.
#
#
# Who is this for:
# - Desire to acquire a new high in demand skill (like coding, design, cyber security, data science and analytics, and sales)
# - Have a high level of motivation, energy, and attitude
#
#
# Other highlights:
# - No previous experience in technology
# - No degree necessary
# - No upfront deposit or fees to Join Career Karma. Completely FREE
# - No one is too young or too old
# - Diverse backgrounds is a plus
#
# 👉How to apply:  fill out this 1 minute form
#
#
#
#
# -----
# Job Title:  Software Engineer
# Location:  Remote
# Date: Mar 30
# Link:  https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7299216813.html
#
# compensation: To Be Discussed
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
# Join Hired and find your dream job as a Software Engineer at one of 10,000+ companies looking for candidates just like you.
# This is a role that fuses both creative and practical concerns, as these engineers are responsible for everything the website user encounters, including scrolling functions and graphics, as well as creating the logic, database interactions and server configuration on the application's backend.
#
# Responsibilities Include:
#
# The development and maintenance of client-side and server-side applications.
# Working with other web developers as well as marketing teams and engineers to ensure the right look and necessary features are included in your work.
# Designing tests that will be implemented to keep software functional.
# Stay on top of expanding technologies and engineering trends.
#
#
#
# Companies on Hired apply to you, not the other way around. You'll receive salary and compensation details upfront - before the interview - and be able to choose from a variety of industries you're interested in, to find a job You'll love in less than 2 weeks.
# To Learn More and Apply: Click Here
# -----
# Job Title:  ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# Location:  N/A
# Date: Mar 30
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7299185378.html
#
# compensation: $60,000-$120,000 depending on the company
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Start your next career in tech by joining Career Karma where we will help you prepare to become a Software Developer and help you get accepted into top Software job training programs. Career Karma is always free.
#
# Average graduate salaries range between $60,000-120,000 per year in Coding, Design, Data Science roles.
#
# 👉How to apply:  fill out this 1 minute form
#
# What is Career Karma?
# Career Karma is a free service that helps you explore courses and connect with other students like you, taking online courses to learn new in-demand skills. In less than 30 days, we will help you discover tech careers, prepare and get accepted into top job training programs in Boston.
#
# We’ve helped thousands of people get high paying jobs in less than 12 months. Check out the story of Kesha Lake, who is a mom and music teacher. She joined Career Karma in January 2019 by November 2019, we helped her get a  Remote Software Engineering job making $98,000 working for StitchFix.
#
# 📺Here is a video with our founder Ruben Harris on CNBC explaining how we have helped 100,000 Americans get jobs in technology.
#
#
# Who is this for:
# - Desire to acquire a new high in demand skill (like coding, design, cyber security, data science and analytics, and sales)
# - Have a high level of motivation, energy, and attitude
#
#
# Other highlights:
# - No previous experience in technology
# - No degree necessary
# - No upfront deposit or fees to Join Career Karma. Completely FREE
# - No one is too young or too old
# - Diverse backgrounds is a plus
#
# 👉How to apply:  fill out this 1 minute form
#
#
#
#
# -----
# Job Title:  VP of Engineering
# Location:  boston: boston/cambridge/brookline
# Date: Mar 29
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-vp-of-engineering/7299019544.html
#
# compensation: Negotiable
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# VP of Engineering  - $200-250k plus bonus100% remoteA leading EdTech SaaS platform for reading literacy is looking for a VP of Engineering to join their team. This is an established organization but with a huge opportunity to make a big impact. They are looking for someone who can help modernize their tech to better align with growing business needs.Your responsibilities:Continue to build out, mentor and lead technical teamDevelop a culture that encourages collaboration and innovationModernize development standards and architectureSupport organization change from a business perspectiveDevelop Engineering Directors and Managers for continuous growthCreate an architecture roadmap to achieve organizational goalsYour experience:Experience building out SaaS web and mobile applicationsExperience driving large technical projects from conception to productionExperience working with Agile/SCRUM teamsAbility to juggle multiple projects in a fast paced, collaborative environmentExcellent communication skills - demonstrated experience working across the business including with C-level executivesThis is a unique opportunity to step into a successful company with impressive market share that is poised for growth and change. This is a great team of highly motivated/collaborative people who are ready to take the company and their products to the next level.Find Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries utilizing a complete suite of staffing services.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Life Sciences and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future
# -----
# Job Title:  FULL STACK DEVELOPER
# Location:  Rhode Island
# Date: Mar 29
# Link:  https://boston.craigslist.org/bmw/sof/d/warwick-full-stack-developer/7298883871.html
#
# compensation: $75K -$90K
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Full Stack Developer (REGIONAL)   80% REMOTE   20% onsite until JULY 2021
# compensation: $75K-$90K
# employment type: full-time
#
# Our team is searching for a FULL STACK developer to assist in the development of an internal ERP/WMS/Mobile/Web system. The select candidate will participate in various types of application developments across the entire business process including sales, distribution, production, CRM, accounting, supply chain, and marketing.
#
# The select candidate will work closely with internal teams and outside business partners to drive key elements of the product definition, execution and QA.
#
# Responsibilities include but are not limited to:
# -Interpret business requirements
# -Design, implement and test n-tier enterprise web, hybrid, and or native applications
# -Review, troubleshoot and optimize code level problems quickly and efficiently
#
# Skills Requirements
# -4+ years of combined experience working as a Full Stack Developer
# -Experience developing and maintaining applications using VB6 and or VB.Net, ASP.net, C#, XML
# -Knowledge of and experience with HTML, CSS, SCSS, JavaScript, jQuery, Angular
# -Back End development skills and knowledge of relational databases (MSSQL)
# -Create prototypes, codes, tests, debugs, documents, and implements systems
# -Participate in technical meetings
#
# EDUCATIONAL REQUIREMENTS
# -B.S. Computer Engineering, Computer Science or Information Systems
#
# -REMOTE WORK POSSIBLE
# -Must be able to work within the office for a two week training period and onboarding period.
# -Only Regional Candidates will be considered- RI, MA-CT-NH-VT-MAINE
# -----
# Job Title:  DevOps Engineer - New Position! Remote, in the office when it's safe
# Location:  Newton, MA
# Date: Mar 29
# Link:  https://boston.craigslist.org/gbs/sof/d/newton-devops-engineer-new-position/7298826408.html
#
# compensation: Excellent compensation and benefits package!  Medical and dental start on day 1 of employment!
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Powerhouse Dynamics (PhD), a Middleby company, is a growing and innovative firm operating at the intersection between food-tech and clean-tech – and that growth has resulted in the need to expand our DevOps capabilities and bring on board a high energy DevOps Engineer.
#
# PhD delivers customer-proven, IoT-based solutions that help restaurants, retailers, and other multi-site organizations better manage their equipment, lower costs, reduce energy consumption, enhance food safety and quality, and achieve their sustainability goals. SiteSage® and Open Kitchen® have been adopted by numerous major brands at thousands of their locations, including Arby's, Dunkin’ Donuts, Buffalo Wild Wings, Texas Roadhouse, Pizza Hut, Ann Taylor, Five Below, Lush Cosmetics, and many more.
#
# The successful candidate will work closely with the Chief Architect and other members of the software development team to deliver the highest level of software quality and services in a high availability environment.
#
# Responsibilities will include but not be limited to:
# •	Manage cloud infrastructure to ensure high availability, security, and performance
# •	Work with agile development team to ensure the delivery of highest quality software in rapid cycles
# •	Identify, trouble-shoot, and resolve technical or systems issues
# •	Optimize public cloud costs
# •	Implement and maintain the company’s relevant information security policies and support the annual PCI audit process
#
# Qualifications:
# •	3+ years in DevOps or equivalent experience
# •	In-depth experience with public cloud services (AWS preferred)
# •	System administrator experience on Linux servers and strong command line skills
# •	Thorough understanding of network infrastructure and concepts (VPNs, routers and routing protocols, TCP/IP, IPv4 andv6, UDP, OSI layers, etc.)
# •	Experience reading and/or developing scripts in Bash, PHP, NodeJS, Python or similar languages
# •	Proficiency with Git, including branching and merging strategies
# •	Experience managing MySQL or equivalent databases
# •	Experience working in Agile environments
# •	Experience with supporting and managing PCI, GDPR, or similar cloud security policies a plus
# •	Strong written and verbal communication skills
# •	Strong problem-solving skills and the ability to learn and apply new technologies
# •	Self-motivated and detail oriented individual with a strong sense of ownership
#
# We offer an excellent compensation and benefits package including medical, dental, vision, PTO, a 401K and more!  Benefits start on your first day of employment.  We believe in a work/life balance!
#
# No relocation available.
#
# Do you want to be part of a dynamic, growing organization?  Come work with us to help our customers achieve higher profitability, lower energy costs, and more sustainable operations!
#
# To apply, please email your resume and salary requirements with the subject “DevOps Engineer” to: Jobs@powerhousedynamics.com
#
# No phone calls or third parties please. Powerhouse Dynamics is an equal opportunity employer.
#
#
#
# -----
# Job Title:  Senior Software Engineer/Team Coordinator
# Location:  Woburn
# Date: Mar 29
# Link:  https://boston.craigslist.org/nwb/sof/d/woburn-senior-software-engineer-team/7298798871.html
#
# compensation: Not Specified
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Senior Software Engineer/Team Coordinator (Auriga, Inc. – Woburn, MA) Propose, develop and deploy technical solutions for business needs related to medical device software. Work with customers as well as sales and engineering teams to create software designs, source code, and technical documentation that fulfill customer needs. Coordinate work performed by remote and external project team members. Perform research and development activities requiring physical access to equipment. Develop prototypes to estimate the feasibility of different design approaches and evaluate technologies to use in future projects. Review software code and other artefacts created by other team members to ensure compliance with internal and external regulatory standards.
#
# Requires Bachelor’s degree (or foreign equivalent) in Computer Science, Computer Engineering or a related field and 7 years of experience in the job offered or in medical device software development. In lieu of a Bachelor’s degree in stated field, will accept 2 additional years of experience in the job offered or in medical device software development.
#
# Must have 5 years of experience in each of the following: programming with C or C++ using Active Template Library (ATL), Qt and .NET frameworks; working in Linux, Windows or similar mature operating system on kernel and application levels; working in VxWorks, ThreadX or other real-time operation system; working on software architecture, multithreaded programming, networking, enterprise development or database development; embedded hardware platforms including SOC, FPGA, ARM and x86; utilizing software development methodologies (including Agile or Scrum) as well as software development standards (including CMMI or ISO 9001); quality management systems for medical equipment based on IEC 62304 and ISO 13485 medical device software standards; and, technical project management including coordinating work for multicultural remote teams. Experience may be gained concurrently.
#
# Please send resumes to Auriga, Inc., Yuri Kirkel, 400 TradeCenter, Suite 5900, Woburn, MA 01801. Reference JobID: 4964485.
# -----
# Job Title:  ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# Location:  N/A
# Date: Mar 28
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7298474884.html
#
# compensation: $60,000-$120,000 depending on the company
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Start your next career in tech by joining Career Karma where we will help you prepare to become a Software Developer and help you get accepted into top Software job training programs. Career Karma is always free.
#
# ...
# For the full list of our open positions, please check www.spectraforce.com
#
# -----
# Job Title:  ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# Location:  N/A
# Date: Mar 16
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7292165185.html
#
# compensation: $60,000-$120,000 depending on the company
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Start your next career in tech by joining Career Karma where we will help you prepare to become a Software Developer and help you get accepted into top Software job training programs. Career Karma is always free.
#
# Average graduate salaries range between $60,000-120,000 per year in Coding, Design, Data Science roles.
#
# 👉How to apply:  fill out this 1 minute form
#
# What is Career Karma?
# Career Karma is a free service that helps you explore courses and connect with other students like you, taking online courses to learn new in-demand skills. In less than 30 days, we will help you discover tech careers, prepare and get accepted into top job training programs in Boston.
#
# We’ve helped thousands of people get high paying jobs in less than 12 months. Check out the story of Kesha Lake, who is a mom and music teacher. She joined Career Karma in January 2019 by November 2019, we helped her get a  Remote Software Engineering job making $98,000 working for StitchFix.
#
# 📺Here is a video with our founder Ruben Harris on CNBC explaining how we have helped 100,000 Americans get jobs in technology.
#
#
# Who is this for:
# - Desire to acquire a new high in demand skill (like coding, design, cyber security, data science and analytics, and sales)
# - Have a high level of motivation, energy, and attitude
#
#
# Other highlights:
# - No previous experience in technology
# - No degree necessary
# - No upfront deposit or fees to Join Career Karma. Completely FREE
# - No one is too young or too old
# - Diverse backgrounds is a plus
#
# 👉How to apply:  fill out this 1 minute form
#
#
#
#
# -----
# Job Title:  Manager or Director, Professional Services
# Location:  N/A
# Date: Apr 12
# Link:  https://providence.craigslist.org/sof/d/mansfield-manager-or-director/7305727506.html
#
# compensation: $130000 - $160000 per year
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Manager or Director, Professional Services - Mansfield, MA - $160K                        Established in 2005, this major ERP partner is an industry leading provider of Enterprise Content Management Software. They are currently seeking a strong Manager or Director level of Professional Services. YOUR CAREER GOALSTo lead a growing professional services department while setting the standard for excellence behind best practices, strong documentation, and complex software implementations for customers. To oversee a team that operates under a billable utilization model where you have a direct impact on the organization's revenue and success.YOUR AMAZING QUALITIESYou're passionate about professional services and bringing strong documentation to an organization. You recognize process or programming inefficiencies and can recommend improvements in a heartbeat. You have a B.S. degree or higher in Computer Science, Information Technology & Services, Software Engineering, or a related field, and at least 5 years of professional experience.KEY RESPONSIBILITIESManage and motivate a Professional Services department staff of up to 10 team membersManage the write-up and editing of all customer project paperwork including solution designs, work orders and statements of workManage and maintain 65-75% billable utilization (hours and revenue)Maintain and improve usage of PS Automation tools including Mavenlink and SmartsheetDocumenting and Leading continuous improvement efforts for processes and implementation best practicesManage the targeted Professional Services revenueManage forecasting and budgeting within the departmentEstablishing and maintain relationships with customer executive sponsors and project teamsAnd if you've got knowledge or experience in:Enterprise Content Management (ECM)ERP Software...those are certainly pluses!You must also be able to thrive in a fast-paced, deadline-driven environment. Leadership ability and excellent interpersonal & communication skills here are absolutely essential.IN EXCHANGE FOR YOUR HARD WORKWe offer you:A comprehensive health & medical benefits packageGenerous PTO401(k) planGreat office perks and Remote FlexibilityCompany fun through social events & partiesCareer development & advancement opportunitiesAnd much more!Find Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries utilizing a complete suite of staffing services.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Life Sciences and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future
# -----
# Job Title:  Full Stack Developer
# Location:  N/A
# Date: Mar 29
# Link:  https://providence.craigslist.org/sof/d/warwick-full-stack-developer/7298867620.html
#
# compensation: $75K-$90K
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
# Our team is searching for a FULL STACK developer to assist in the development of an internal ERP/WMS/Mobile/Web system.  The select candidate will participate in various types of application developments across the entire business process including sales, distribution, production, CRM, accounting, supply chain, and marketing.
#
# The select candidate will work closely with internal teams and outside business partners to drive key elements of the product definition, execution and QA.
#
# Responsibilities include but are not limited to:
# -Interpret business requirements
# -Design, implement and test n-tier enterprise web, hybrid, and or native applications
# -Review, troubleshoot and optimize code level problems quickly and efficiently
#
# Skills Requirements
# -4+ years of combined experience working as a Full Stack Developer
# -Experience developing and maintaining applications using VB6 and or VB.Net, ASP.net, C#, XML
# -Knowledge of and experience with HTML, CSS, SCSS, JavaScript, jQuery, Angular
# -Back End development skills and knowledge of relational databases (MSSQL)
# -Create prototypes, codes, tests, debugs, documents, and implements systems
# -Participate in technical meetings
#
# EDUCATIONAL REQUIREMENTS
# -B.S. Computer Engineering, Computer Science or Information Systems
#
# -REMOTE WORK POSSIBLE
# -Must be able to work within the office for a two week training period and onboarding period.
# -Only Regional Candidates will be considered- RI, MA-CT-NH-VT-MAINE
#
#
# -----
# Job Title:  ✭✭✭Start a Web Developer Career Today! No Experience Needed (Remote)
# Location:  N/A
# Date: Mar 28
# Link:  https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298487508.html
#
# compensation: $60,000-$120,000 depending on the company
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Start your next career in tech by joining Career Karma where we will help you prepare to become a Software Developer and help you get accepted into top Software job training programs. Career Karma is always free.
#
# Average graduate salaries range between $60,000-120,000 per year in Coding, Design, Data Science roles.
#
# 👉How to apply:  fill out this 1 minute form
#
# What is Career Karma?
# Career Karma is a free service that helps you explore courses and connect with other students like you, taking online courses to learn new in-demand skills. In less than 30 days, we will help you discover tech careers, prepare and get accepted into top job training programs in Rhode Island.
#
# We’ve helped thousands of people get high paying jobs in less than 12 months. Check out the story of Kesha Lake, who is a mom and music teacher. She joined Career Karma in January 2019 by November 2019, we helped her get a  Remote Software Engineering job making $98,000 working for StitchFix.
#
# 📺Here is a video with our founder Ruben Harris on CNBC explaining how we have helped 100,000 Americans get jobs in technology.
#
#
# Who is this for:
# - Desire to acquire a new high in demand skill (like coding, design, cyber security, data science and analytics, and sales)
# - Have a high level of motivation, energy, and attitude
#
#
# Other highlights:
# - No previous experience in technology
# - No degree necessary
# - No upfront deposit or fees to Join Career Karma. Completely FREE
# - No one is too young or too old
# - Diverse backgrounds is a plus
#
# 👉How to apply:  fill out this 1 minute form
#
#
#
#
# -----
# Job Title:  ✭✭✭Start a Web Developer Career Today! No Experience Needed (Remote)
# Location:  N/A
# Date: Mar 28
# Link:  https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7298253649.html
#
# compensation: $60,000-$120,000 depending on the company
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Start your next career in tech by joining Career Karma where we will help you prepare to become a Software Developer and help you get accepted into top Software job training programs. Career Karma is always free.
#
# Average graduate salaries range between $60,000-120,000 per year in Coding, Design, Data Science roles.
#
# 👉How to apply:  fill out this 1 minute form
#
# What is Career Karma?
# Career Karma is a free service that helps you explore courses and connect with other students like you, taking online courses to learn new in-demand skills. In less than 30 days, we will help you discover tech careers, prepare and get accepted into top job training programs in San Francisco.
#
# We’ve helped thousands of people get high paying jobs in less than 12 months. Check out the story of Kesha Lake, who is a mom and music teacher. She joined Career Karma in January 2019 by November 2019, we helped her get a  Remote Software Engineering job making $98,000 working for StitchFix.
#
# 📺Here is a video with our founder Ruben Harris on CNBC explaining how we have helped 100,000 Americans get jobs in technology.
#
#
# Who is this for:
# - Desire to acquire a new high in demand skill (like coding, design, cyber security, data science and analytics, and sales)
# - Have a high level of motivation, energy, and attitude
#
#
# Other highlights:
# - No previous experience in technology`
# - No degree necessary
# - No upfront deposit or fees to Join Career Karma. Completely FREE
# - No one is too young or too old
# - Diverse backgrounds is a plus
#
# 👉How to apply:  fill out this 1 minute form
#
#
#
# -----
# Job Title:  ✭✭✭Start a Web Developer Career Today! No Experience Needed (Remote)
# Location:  N/A
# Date: Mar 21
# Link:  https://providence.craigslist.org/sof/d/providence-start-web-developer-career/7294691934.html
#
# compensation: $60,000-$120,000 depending on the company
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Start your next career in tech by joining Career Karma where we will help you prepare to become a Software Developer and help you get accepted into top Software job training programs. Career Karma is always free.
#
# Average graduate salaries range between $60,000-120,000 per year in Coding, Design, Data Science roles.
#
# 👉How to apply:  fill out this 1 minute form
#
# What is Career Karma?
# Career Karma is a free service that helps you explore courses and connect with other students like you, taking online courses to learn new in-demand skills. In less than 30 days, we will help you discover tech careers, prepare and get accepted into top job training programs in Rhode Island.
#
# We’ve helped thousands of people get high paying jobs in less than 12 months. Check out the story of Kesha Lake, who is a mom and music teacher. She joined Career Karma in January 2019 by November 2019, we helped her get a  Remote Software Engineering job making $98,000 working for StitchFix.
#
# 📺Here is a video with our founder Ruben Harris on CNBC explaining how we have helped 100,000 Americans get jobs in technology.
#
#
# Who is this for:
# - Desire to acquire a new high in demand skill (like coding, design, cyber security, data science and analytics, and sales)
# - Have a high level of motivation, energy, and attitude
#
#
# Other highlights:
# - No previous experience in technology
# - No degree necessary
# - No upfront deposit or fees to Join Career Karma. Completely FREE
# - No one is too young or too old
# - Diverse backgrounds is a plus
#
# 👉How to apply:  fill out this 1 minute form
#
#
#
#
# -----
# Job Title:  Estimator/Templator
# Location:  N/A
# Date: Mar 15
# Link:  https://capecod.craigslist.org/sof/d/hyannis-estimator-templator/7291841605.html
#
# compensation: Based of experience
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# We are a well established, very busy Marble & Granite business. We sell, fabricate and install countertops, fireplaces etc. We are currently looking for the right candidate to assist with our templating and CAD programming. Experience is not necessary but a strong background is computer is required, and general construction knowledge is helpful.
#
# PLEASE APPLY WITHIN
# -----
# Job Title:  Cyber Security Analysts! Earn $56,000-$117,000 per year!
# Location:  N/A
# Date: Mar 28
# Link:  https://hartford.craigslist.org/sof/d/hartford-cyber-security-analysts-earn/7298191991.html
#
# compensation: Certified Cyber Security Analysts earn $56,000-$117,000 per year!
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# *There will be 3.5 million unfilled Cyber Security jobs by 2022 (Forbes/CSO report)
# *There are currently 1 million unfilled IT jobs right now (U.S. Department of Labor Stat)
# *Cyber security professionals report an average salary of $116,000 (Bureau of Labor Statistics)
#
# Train NOW, GET certified NOW, GET HIRED and PAY LATER in as little as 4 - 6 weeks. Day, Evening and Live remote/hands-on instructor led training classes where we bring the live training right to your desktop! Special tuition deferment plans allow you to train NOW, get certified NOW, get HIRED and PAY later!
#
# Whether you are looking to get into IT or looking to advance your current IT career, our Cyber security training, certification and job placement program has helped thousands of professionals "Change their lives while advancing their careers." You can earn 4-6 certifications in as little as 4-6 weeks (Security+, A+, Network+, Certified Cyber Security Analyst, Certified Ethical Hacker, Cisco CCNA and Microsoft certifications). Live remote training where we bring the live training and certification right to you! Special tuition deferment program that allows you to TRAIN now, get CERTIFIED now, get HIRED and PAY later.
#
# Reply to this ad and click on the link below and fill out the form:
#
# https://nhorlando.lpages.co/tuition-deferment-orl2021cl/
# -----
# Total Jobs:  56

# %%
npo_jobs_df.head()
# Out:
#                             Job Title          Location    Date  \
# 1                   Software Engineer            Remote  Apr 13
# 2         Xamarine Software Developer  Newton Highlands  Apr 13
# 3  Data Scientist & Software Engineer               N/A  Apr  9
# 4                   Software Engineer            Remote  Apr  8
# 5                   Software Engineer            Remote  Apr  6
#
#                                                 Link  \
# 1  https://boston.craigslist.org/gbs/sof/d/andove...
# 2  https://boston.craigslist.org/gbs/sof/d/newton...
# 3  https://boston.craigslist.org/bmw/sof/d/boxbor...
# 4  https://boston.craigslist.org/gbs/sof/d/andove...
# 5  https://boston.craigslist.org/gbs/sof/d/andove...
#
#                                       Job Attributes  \
# 1  \ncompensation: To Be Discussed\n\nemployment ...
# 2  \ncompensation: based on candidate's experienc...
# 3  \ncompensation: TBD\n\nemployment type: full-t...
# 4  \ncompensation: To Be Discussed\n\nemployment ...
# 5  \ncompensation: To Be Discussed\n\nemployment ...
#
#                                      Job Description
# 1  \n\nQR Code Link to This Post\n\n\n\nJoin Hire...
# 2  \n\nQR Code Link to This Post\n\n\nOur company...
# 3  \n\nQR Code Link to This Post\n\n\nCisco Syste...
# 4  \n\nQR Code Link to This Post\n\n\n\nJoin Hire...
# 5  \n\nQR Code Link to This Post\n\n\n\nJoin Hire...

# %%
npo_jobs_df.to_csv('npo_jobs.csv',sep='|')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Tarea

# %%
url = "https://www.programmableweb.com/category/all/apis"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data = response.text

# %%
data
# Out:
# '<!DOCTYPE html><html xmlns="https://www.w3.org/1999/xhtml" lang="en" dir="ltr" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#"><head profile="http://www.w3.org/1999/xhtml/vocab"><meta name="viewport" content="width=device-width, initial-scale=1.0"> <!--[if IE]><![endif]--><link rel="preload" href="https://fonts.gstatic.com/s/opensans/v16/mem6YaGs126MiZpBA-UFUK0Zdcg.ttf" as="font" type="font/ttf" crossorigin="anonymous" /><link rel="preload" href="https://fonts.gstatic.com/s/opensans/v16/memnYaGs126MiZpBA-UFUKXGUdhrIqY.ttf" as="font" type="font/ttf" crossorigin="anonymous" /><link rel="preload" href="https://fonts.gstatic.com/s/opensans/v16/memnYaGs126MiZpBA-UFUKWiUNhrIqY.ttf" as="font" type="font/ttf" crossorigin="anonymous" /><link rel="preload" href="https://fonts.gstatic.com/s/opensans/v16/mem8YaGs126MiZpBA-UFVZ0e.ttf" as="font" type="font/ttf" crossorigin="anonymous" /><link rel="preload" href="https://fonts.gstatic.com/s/opensans/v16/mem5YaGs126MiZpBA-UNirkOUuhs.ttf" as="font" type="font/ttf" crossorigin="anonymous" /><link rel="preload" href="https://fonts.gstatic.com/s/opensans/v16/mem5YaGs126MiZpBA-UN7rgOUuhs.ttf" as="font" type="font/ttf" crossorigin="anonymous" /><link rel="preload" href="https://fonts.gstatic.com/s/opensans/v16/mem5YaGs126MiZpBA-UN8rsOUuhs.ttf" as="font" type="font/ttf" crossorigin="anonymous" /><link rel="preload" href="/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.eot" as="font" type="font/eot" crossorigin="anonymous" /><link rel="preload" href="/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.eot?#iefix" as="font" type="font/eot" crossorigin="anonymous" /><link rel="preload" href="/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.woff" as="font" type="font/woff" crossorigin="anonymous" /><link rel="preload" href="/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.ttf" as="font" type="font/ttf" crossorigin="anonymous" /><link rel="preload" href="/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.svg#glyphicons-halflingsregular" as="font" type="font/svg+xml" crossorigin="anonymous" /><link rel="preload" href="/sites/all/themes/pw_bootstrap_two/images/logo_onscroll.png" as="image" type="image/png" /><link rel="preload" href="/sites/all/themes/pw_bootstrap_two/font/pw-icons.eot?35082076" as="font" type="font/eot" crossorigin="anonymous" /><link rel="preload" href="/sites/all/themes/pw_bootstrap_two/font/pw-icons.eot?35082076#iefix" as="font" type="font/eot" crossorigin="anonymous" /><link rel="preload" href="/sites/all/themes/pw_bootstrap_two/font/pw-icons.woff?35082076" as="font" type="font/woff" crossorigin="anonymous" /><link rel="preload" href="/sites/all/themes/pw_bootstrap_two/font/pw-icons.ttf?35082076" as="font" type="font/ttf" crossorigin="anonymous" /><link rel="preload" href="/sites/all/themes/pw_bootstrap_two/font/pw-icons.svg?35082076#pw-icons" as="font" type="font/svg+xml" crossorigin="anonymous" /><link rel="dns-prefetch" href="//fonts.gstatic.com" /><link rel="preconnect" href="//fonts.gstatic.com" /><link rel="dns-prefetch" href="//plausible.io" /><link rel="preconnect" href="//plausible.io" /><link rel="dns-prefetch" href="//honeypot" /><link rel="preconnect" href="//honeypot" /><link rel="dns-prefetch" href="//less" /><link rel="preconnect" href="//less" /><link rel="dns-prefetch" href="//www.mulesoft.com" /><link rel="preconnect" href="//www.mulesoft.com" /><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><link rel="next" href="/category/all/apis?page=1" /><script src="/sites/default/files/cef/www.google.com/recaptcha/api.js" async="async" defer="defer"></script><link rel="shortcut icon" href="https://www.programmableweb.com/sites/default/files/pwfav.png" type="image/png" /><meta name="msvalidate.01" content="A831B864E788CA09524699B47E05A41D" /><meta name="description" content="Possible search results  ...

# %%
soup = BeautifulSoup(data,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#" xmlns="https://www.w3.org/1999/xhtml"><head profile="http://www.w3.org/1999/xhtml/vocab"><meta content="width=device-width, initial-scale=1.0" name="viewport"/> <!--[if IE]><![endif]--><link as="font" crossorigin="anonymous" href="https://fonts.gstatic.com/s/opensans/v16/mem6YaGs126MiZpBA-UFUK0Zdcg.ttf" rel="preload" type="font/ttf"/><link as="font" crossorigin="anonymous" href="https://fonts.gstatic.com/s/opensans/v16/memnYaGs126MiZpBA-UFUKXGUdhrIqY.ttf" rel="preload" type="font/ttf"/><link as="font" crossorigin="anonymous" href="https://fonts.gstatic.com/s/opensans/v16/memnYaGs126MiZpBA-UFUKWiUNhrIqY.ttf" rel="preload" type="font/ttf"/><link as="font" crossorigin="anonymous" href="https://fonts.gstatic.com/s/opensans/v16/mem8YaGs126MiZpBA-UFVZ0e.ttf" rel="preload" type="font/ttf"/><link as="font" crossorigin="anonymous" href="https://fonts.gstatic.com/s/opensans/v16/mem5YaGs126MiZpBA-UNirkOUuhs.ttf" rel="preload" type="font/ttf"/><link as="font" crossorigin="anonymous" href="https://fonts.gstatic.com/s/opensans/v16/mem5YaGs126MiZpBA-UN7rgOUuhs.ttf" rel="preload" type="font/ttf"/><link as="font" crossorigin="anonymous" href="https://fonts.gstatic.com/s/opensans/v16/mem5YaGs126MiZpBA-UN8rsOUuhs.ttf" rel="preload" type="font/ttf"/><link as="font" crossorigin="anonymous" href="/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.eot" rel="preload" type="font/eot"/><link as="font" crossorigin="anonymous" href="/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.eot?#iefix" rel="preload" type="font/eot"/><link as="font" crossorigin="anonymous" href="/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.woff" rel="preload" type="font/woff"/><link as="font" crossorigin="anonymous" href="/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.ttf" rel="preload" type="font/ttf"/><link as="font" crossorigin="anonymous" href="/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.svg#glyphicons-halflingsregular" rel="preload" type="font/svg+xml"/><link as="image" href="/sites/all/themes/pw_bootstrap_two/images/logo_onscroll.png" rel="preload" type="image/png"/><link as="font" crossorigin="anonymous" href="/sites/all/themes/pw_bootstrap_two/font/pw-icons.eot?35082076" rel="preload" type="font/eot"/><link as="font" crossorigin="anonymous" href="/sites/all/themes/pw_bootstrap_two/font/pw-icons.eot?35082076#iefix" rel="preload" type="font/eot"/><link as="font" crossorigin="anonymous" href="/sites/all/themes/pw_bootstrap_two/font/pw-icons.woff?35082076" rel="preload" type="font/woff"/><link as="font" crossorigin="anonymous" href="/sites/all/themes/pw_bootstrap_two/font/pw-icons.ttf?35082076" rel="preload" type="font/ttf"/><link as="font" crossorigin="anonymous" href="/sites/all/themes/pw_bootstrap_two/font/pw-icons.svg?35082076#pw-icons" rel="preload" type="font/svg+xml"/><link href="//fonts.gstatic.com" rel="dns-prefetch"/><link href="//fonts.gstatic.com" rel="preconnect"/><link href="//plausible.io" rel="dns-prefetch"/><link href="//plausible.io" rel="preconnect"/><link href="//honeypot" rel="dns-prefetch"/><link href="//honeypot" rel="preconnect"/><link href="//less" rel="dns-prefetch"/><link href="//less" rel="preconnect"/><link href="//www.mulesoft.com" rel="dns-prefetch"/><link href="//www.mulesoft.com" rel="preconnect"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"><link href="/category/all/apis?page=1" rel="next"/><script async="async" defer="defer" src="/sites/default/files/cef/www.google.com/recaptcha/api.js"></script><link href="https://www.programmableweb.com/sites/default/files/pwfav.png" rel="shortcut icon" type="image/png"/><meta content="A831B864E788CA09524699B47E05A41D" name="msvalidate.01"/><meta content="Possible search results for APIs, SDKs, as well as related news, source code, how-to's, fra ...
# <!-- Google Tag Manager -->
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-N2BDGD');
# <!-- End Google Tag Manager --></script><link href="https://www.programmableweb.com/apis/directory" rel="canonical"/><link href="https://www.programmableweb.com/category/all/apis" rel="shortlink"/><meta content="ProgrammableWeb" property="og:site_name"/><meta content="website" property="og:type"/><meta content="https://www.programmableweb.com/category/all/apis" property="og:url"/><meta content="Most Recent" property="og:title"/><meta content="https://www.programmableweb.com/sites/all/themes/pw_bootstrap_two/images/logo-65x65.png" property="og:image"/><meta content="summary" name="twitter:card"/><meta content="@programmableweb" name="twitter:site"/><meta content="17413602" name="twitter:site:id"/><meta content="https://www.programmableweb.com/category/all/apis" name="twitter:url"/><meta content="ProgrammableWeb" name="twitter:title"/><meta content="https://www.programmableweb.com/sites/all/themes/pw_bootstrap_two/images/logo-65x65.png" name="twitter:image"/><meta content="65" name="twitter:image:width"/><meta content="65" name="twitter:image:height"/><title>API Directory | ProgrammableWeb</title><link as="font" href="//fonts.googleapis.com/css?family=Open+Sans:400,400i,600,600i,700,700i,800&amp;display=swap" rel="preload"/> <style>@font-face{font-family:'Open Sans';font-style:italic;font-weight:400;font-display:swap;src:local('Open Sans Italic'),local('OpenSans-Italic'),url(https://fonts.gstatic.com/s/opensans/v16/mem6YaGs126MiZpBA-UFUK0Zdcg.ttf) format('truetype')}@font-face{font-family:'Open Sans';font-style:italic;font-weight:600;font-display:swap;src:local('Open Sans SemiBold Italic'),local('OpenSans-SemiBoldItalic'),url(https://fonts.gstatic.com/s/opensans/v16/memnYaGs126MiZpBA-UFUKXGUdhrIqY.ttf) format('truetype')}@font-face{font-family:'Open Sans';font-style:italic;font-weight:700;font-display:swap;src:local('Open Sans Bold Italic'),local('OpenSans-BoldItalic'),url(https://fonts.gstatic.com/s/opensans/v16/memnYaGs126MiZpBA-UFUKWiUNhrIqY.ttf) format('truetype')}@font-face{font-family:'Open Sans';font-style:normal;font-weight:400;font-display:swap;src:local('Open Sans Regular'),local('OpenSans-Regular'),url(https://fonts.gstatic.com/s/opensans/v16/mem8YaGs126MiZpBA-UFVZ0e.ttf) format('truetype')}@font-face{font-family:'Open Sans';font-style:normal;font-weight:600;font-display:swap;src:local('Open Sans SemiBold'),local('OpenSans-SemiBold'),url(https://fonts.gstatic.com/s/opensans/v16/mem5YaGs126MiZpBA-UNirkOUuhs.ttf) format('truetype')}@font-face{font-family:'Open Sans';font-style:normal;font-weight:700;font-display:swap;src:local('Open Sans Bold'),local('OpenSans-Bold'),url(https://fonts.gstatic.com/s/opensans/v16/mem5YaGs126MiZpBA-UN7rgOUuhs.ttf) format('truetype')}@font-face{font-family:'Open Sans';font-style:normal;font-weight:800;font-display:swap;src:local('Open Sans ExtraBold'),local('OpenSans-ExtraBold'),url(https://fonts.gstatic.com/s/opensans/v16/mem5YaGs126MiZpBA-UN8rsOUuhs.ttf) format('truetype')}.container-inline div{display:inline}.element-invisible{position:absolute;clip:rect(1px 1px 1px 1px);clip:rect(1px,1px,1px,1px);overflow:hidden;height:1px}.clearfix:after{content:".";display:block;height:0;clear:both;visibility:hidden}.views-view-grid tbody{border-top:none}.quicktabs-hide{display:none}ul.quicktabs-tabs{margin-top:0}ul.quicktabs-tabs li{display:inline;background:0 0;list-style-type:none;padding:2px;white-space:nowrap}article,header,section{display:block}html{font-family:sans-serif;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}body{margin:0}img{border:0}button,input{font-family:inherit;font-size:100%;margin:0}button,input{line-height:normal}button{text-transform:none}button{-webkit-appearance:button}button::-moz-focus-inner,input::-moz-focus-inner{border:0;padding:0}table{border-collapse:collapse;border-spacing:0}*,*:before,*:after{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box}html{font-size:62.5%}body{font-family:"Helvetica Neue",Helvetica,Arial,sans-serif;font- ...
# .form-control:-moz-placeholder{color:#f2f2f2}.form-control::-moz-placeholder{color:#f2f2f2}.form-control:-ms-input-placeholder{color:#f2f2f2}.form-control::-webkit-input-placeholder{color:#f2f2f2}.form-control{display:block;width:100%;height:34px;padding:6px 12px;font-size:14px;line-height:1.428571429;color:#e5e9ec;vertical-align:middle;background-color:#fff;border:1px solid #ccc;border-radius:4px;-webkit-box-shadow:inset 0 1px 1px rgba(0,0,0,.075);box-shadow:inset 0 1px 1px rgba(0,0,0,.075);-moz-box-shadow:inset 0 1px 1px rgba(0,0,0,.075)}.form-group{margin-bottom:15px}.btn{display:inline-block;padding:6px 12px;margin-bottom:0;font-size:14px;font-weight:400;line-height:1.428571429;text-align:center;vertical-align:middle;border:1px solid transparent;border-radius:4px;white-space:nowrap}.btn-default{color:#333;background-color:#fff;border-color:#ccc}.btn-primary{color:#fff;background-color:#0098ce;border-color:#0085b5}.collapse{display:none}@font-face{font-display:swap;font-family:'Glyphicons Halflings';src:url(/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.eot);src:url(/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.eot?#iefix) format('embedded-opentype'),url(/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.woff) format('woff'),url(/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.ttf) format('truetype'),url(/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.svg#glyphicons-halflingsregular) format('svg')}.glyphicon{position:relative;top:1px;display:inline-block;font-family:'Glyphicons Halflings';font-style:normal;font-weight:400;line-height:1;-webkit-font-smoothing:antialiased}.glyphicon-search:before{content:"\e003"}.caret{display:inline-block;width:0;height:0;margin-left:2px;vertical-align:middle;border-top:4px solid #000;border-right:4px solid transparent;border-left:4px solid transparent;border-bottom:0 dotted;content:""}.dropdown{position:relative}.dropdown-menu{position:absolute;top:100%;left:0;z-index:1000;display:none;float:left;min-width:160px;padding:5px 0;margin:2px 0 0;list-style:none;font-size:14px;background-color:#fff;border:1px solid #ccc;border:1px solid rgba(0,0,0,.15);border-radius:4px;-webkit-box-shadow:0 6px 12px rgba(0,0,0,.175);box-shadow:0 6px 12px rgba(0,0,0,.175);-moz-box-shadow:0 6px 12px rgba(0,0,0,.175);background-clip:padding-box}.dropdown-menu>li>a{display:block;padding:3px 20px;clear:both;font-weight:400;line-height:1.428571429;color:#333;white-space:nowrap}.input-group{position:relative;display:table;border-collapse:separate}.input-group .form-control{width:100%;margin-bottom:0}.input-group-btn,.input-group .form-control{display:table-cell}.input-group-btn:not(:first-child):not(:last-child){border-radius:0}.input-group-btn{width:1%;white-space:nowrap;vertical-align:middle}.input-group .form-control:first-child{border-bottom-right-radius:0;border-top-right-radius:0}.input-group .form-control:last-child{border-bottom-left-radius:0;border-top-left-radius:0}.input-group-btn{position:relative;white-space:nowrap}.input-group-btn>.btn{position:relative}.nav{margin-bottom:0;padding-left:0;list-style:none}.nav:before,.nav:after{content:" ";display:table}.nav:after{clear:both}.nav>li{position:relative;display:block}.nav>li>a{position:relative;display:block;padding:10px 15px}.nav .caret{border-top-color:#0098ce;border-bottom-color:#0098ce}.navbar{position:relative;z-index:1000;min-height:50px;margin-bottom:20px;border:1px solid transparent}.navbar:before,.navbar:after{content:" ";display:table}.navbar:after{clear:both}@media (min-width:768px){.navbar{border-radius:4px}}.navbar-header:before,.navbar-header:after{content:" ";display:table}.navbar-header:after{clear:both}@media (min-width:768px){.navbar-header{float:left}}.navbar-collapse{max-height:340px;overflow-x:visible;padding-right:15px;padding-left:15px;border-top:1px solid transparent;box-shadow:in ...
# .navbar-collapse:before,.navbar-collapse:after{content:" ";display:table}.navbar-collapse:after{clear:both}@media (min-width:768px){.navbar-collapse{width:auto;border-top:0;box-shadow:none}.navbar-collapse.collapse{display:block;height:auto;padding-bottom:0;overflow:visible}}.container>.navbar-header,.container>.navbar-collapse{margin-right:-15px;margin-left:-15px}@media (min-width:768px){.container>.navbar-header,.container>.navbar-collapse{margin-right:0;margin-left:0}}.navbar-fixed-top{position:fixed;right:0;left:0;border-width:0 0 1px}@media (min-width:768px){.navbar-fixed-top{border-radius:0}}.navbar-fixed-top{z-index:1030;top:0}.navbar-brand{float:left;padding:15px;font-size:18px;line-height:20px}.navbar-toggle{position:relative;float:right;margin-right:15px;padding:9px 10px;margin-top:8px;margin-bottom:8px;background-color:transparent;border:1px solid transparent;border-radius:4px}.navbar-toggle .icon-bar{display:block;width:22px;height:2px;border-radius:1px}.navbar-toggle .icon-bar+.icon-bar{margin-top:4px}@media (min-width:768px){.navbar-toggle{display:none}}.navbar-nav{margin:7.5px -15px}.navbar-nav>li>a{padding-top:10px;padding-bottom:10px;line-height:20px}@media (min-width:768px){.navbar-nav{float:left;margin:0}.navbar-nav>li{float:left}.navbar-nav>li>a{padding-top:15px;padding-bottom:15px}}@media (min-width:768px){.navbar-left{float:left}.navbar-right{float:right}}.navbar-nav>li>.dropdown-menu{margin-top:0;border-top-right-radius:0;border-top-left-radius:0}.navbar-btn{margin-top:8px;margin-bottom:8px}.navbar-default{background-color:#f8f8f8;border-color:#e7e7e7}.navbar-default .navbar-brand{color:#777}.navbar-default .navbar-nav>li>a{color:#777}.navbar-default .navbar-nav>.active>a{color:#555;background-color:#e7e7e7}.navbar-default .navbar-toggle{border-color:#ddd}.navbar-default .navbar-toggle .icon-bar{background-color:#ccc}.navbar-default .navbar-collapse{border-color:#e6e6e6}.navbar-default .navbar-nav>.dropdown>a .caret{border-top-color:#777;border-bottom-color:#777}.clearfix:before,.clearfix:after{content:" ";display:table}.clearfix:after{clear:both}.pull-right{float:right}.pull-left{float:left}@-ms-viewport{width:device-width}@media screen and (max-width:400px){@-ms-viewport{width:320px}}.visible-xs{display:none}@media (max-width:767px){.visible-xs{display:block}}@media (min-width:768px) and (max-width:991px){.visible-xs.visible-sm{display:block}}.visible-sm{display:none}@media (max-width:767px){.visible-sm.visible-xs{display:block}}@media (min-width:768px) and (max-width:991px){.visible-sm{display:block}}@media (min-width:992px) and (max-width:1199px){.visible-sm.visible-md{display:block}}@media (min-width:1200px){.visible-sm.visible-lg{display:block}}.visible-md{display:none}@media (min-width:768px) and (max-width:991px){.visible-md.visible-sm{display:block}}@media (min-width:992px) and (max-width:1199px){.visible-md{display:block}}@media (min-width:1200px){.visible-md.visible-lg{display:block}}.visible-lg{display:none}@media (min-width:768px) and (max-width:991px){.visible-lg.visible-sm{display:block}}@media (min-width:992px) and (max-width:1199px){.visible-lg.visible-md{display:block}}@media (min-width:1200px){.visible-lg{display:block}}.hidden-xs{display:block}@media (max-width:767px){.hidden-xs{display:none}}@media (min-width:768px) and (max-width:991px){.hidden-xs.hidden-sm{display:none}}@media (min-width:992px) and (max-width:1199px){.hidden-xs.hidden-md{display:none}}@media (min-width:1200px){.hidden-xs.hidden-lg{display:none}}.hidden-sm{display:block}@media (max-width:767px){.hidden-sm.hidden-xs{display:none}}@media (min-width:768px) and (max-width:991px){.hidden-sm{display:none}}@media (min-width:992px) and (max-width:1199px){.hidden-sm.hidden-md{display:none}}@media (min-width:1200px){.hidden-sm.hidden-lg{display:none}}.hidden-md{display:block}@media (max-width:767px){.hidden-md.hidden-xs{display:none}}@media (min-width:768px) and (max-width:991px){.hidden-md.hidden-sm{display:none}}@media (min ...
# }.hidden-lg{display:block}@media (max-width:767px){.hidden-lg.hidden-xs{display:none}}@media (min-width:768px) and (max-width:991px){.hidden-lg.hidden-sm{display:none}}@media (min-width:992px) and (max-width:1199px){.hidden-lg.hidden-md{display:none}}@media (min-width:1200px){.hidden-lg{display:none}}body{position:relative}.element-invisible{margin:0;padding:0;width:1px}p:last-child{margin-bottom:0}input{max-width:100%;width:auto}ul li.expanded,ul li.leaf{list-style:none;list-style-image:none}@media (max-width:360px){ul.menuicons>li:nth-child(2){display:none}.visible-xs.navbar-default ul.navbar-right a.search{margin:14px 8px 10px}div.view-home-feature-images img{margin:0 15px 0 0;width:35%}}@font-face{font-display:swap;font-family:'Glyphicons Halflings';src:url(/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.eot);src:url(/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.eot?#iefix) format('embedded-opentype'),url(/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.woff) format('woff'),url(/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.ttf) format('truetype'),url(/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.svg#glyphicons-halflingsregular) format('svg')}body{color:#343838;background:#fff}body .form-control{height:45px;color:#87888c;border:1px solid #bdbec0;border-radius:0;-webkit-box-shadow:none;box-shadow:none}body .form-control::-webkit-input-placeholder{color:#87888c}body .form-control:-moz-placeholder{color:#87888c}body .form-control::-moz-placeholder{color:#87888c}body .form-control:-ms-input-placeholder{color:#87888c}body .form-group{margin-bottom:20px}body .btn-primary,body button.form-submit{height:45px;font-weight:700;border-radius:0;border:none;background:#0098ce;text-transform:uppercase}#navbar{z-index:1002;text-align:right}#navbar .container{padding:15px 0 20px}#navbar .navbar-btn{margin:20px 0 0;padding:0}#navbar .navbar-btn img{width:100%}#navbar .region-header-left{margin:0 0 -20px;display:inline-block;position:relative;vertical-align:bottom}#navbar .region-header-right{display:inline-block;position:relative;width:340px;vertical-align:bottom}.navbar{border:none}.navbar.secondary>.container{padding:0}.navbar>.container{padding:15px 0}@media screen and (max-width:768px){.navbar{min-height:0px}}.navbar-default{background:#fff;margin-bottom:0}.navbar-default a{background:#fff}.navbar-default a.social-icons{background:#343838;color:#fff}.navbar-default a.top-action-icons{background:#343838;color:#fff}.navbar-default a.top-action-icons.rss,.navbar-default a.top-action-icons.user{background:0 0}.top-right-search .form-control,.secondary-search .form-control{-webkit-box-shadow:none;box-shadow:none;height:45px;color:#343838}@media (min-width:768px){.top-right-search .form-control::-webkit-input-placeholder,.secondary-search .form-control::-webkit-input-placeholder{color:#87888c}.top-right-search .form-control:-moz-placeholder,.secondary-search .form-control:-moz-placeholder{color:#87888c}.top-right-search .form-control::-moz-placeholder,.secondary-search .form-control::-moz-placeholder{color:#87888c}.top-right-search .form-control:-ms-input-placeholder,.secondary-search .form-control:-ms-input-placeholder{color:#87888c}}.top-right-search .input-group-btn,.secondary-search .input-group-btn{float:right;position:relative;width:19px}.top-right-search .input-group-btn .btn,.secondary-search .input-group-btn .btn{padding:0;font-size:18px;color:#343838;border-radius:0;border:none;background:0 0;position:absolute;top:-34px;right:13px}.top-right-search .form-submit,.secondary-search .form-submit{display:none}.secondary ul.navbar-nav li{border-left:1px solid #bdbec0}.secondary ul.navbar-nav li:nth-child(8) a{padding:13px 25px}.secondary ul.navbar-nav li a{padding:13px 20px;text-transform:uppercase;color:#343838;font-weight:600;font-size:14px;text-decoration:none}.secondary ul. ...
# .secondary ul.navbar-nav li a.addanapi .caret{margin:0 0 0 5px;border-top-color:#fff;border-bottom-color:#fff}.secondary ul.navbar-nav li a.addanapi:before,.secondary ul.navbar-nav li a.addanapi:after{position:absolute;top:-1px;left:0;content:"";width:100%;height:1px;background:#0098ce}.secondary ul.navbar-nav li a.addanapi:after{top:auto;bottom:-1px}@media (max-width:1200px){.secondary ul.navbar-nav li a{padding:13px 20px}}@media (max-width:800px){.secondary ul.navbar-nav li a{padding-right:9px}}.secondary ul.navbar-nav li.addapi>a:after{position:absolute;bottom:-1px;left:0;content:"";width:100%;height:1px;background:#0098ce}.secondary ul.navbar-nav li.addapi a{background:#0098ce;color:#fff;line-height:20px;outline:none}.secondary ul.navbar-nav li.addapi .caret{margin:0 0 0 5px;border-top-color:#fff;border-bottom-color:#fff}.secondary ul.navbar-nav li.addapi .dropdown-menu{margin:1px 0 0;padding:0;left:0;width:380px;height:auto;text-align:center;background:0 0;border:none;border-radius:0;-webkit-box-shadow:0 2px 0 rgba(0,0,0,.1);box-shadow:0 1px 0 2px rgba(0,0,0,.1)}.secondary ul.navbar-nav li.addapi li{float:left;height:75px;vertical-align:top;border-left:none}.secondary ul.navbar-nav li.addapi li a{margin:0;padding:15px;display:block;background:#0098ce;width:190px;border-bottom:1px solid #007aa5;border-right:1px solid #007aa5;height:75px;font-weight:600;color:#fff;line-height:46px;text-align:center}.secondary ul.navbar-nav li.addapi li:last-child{border-right:transparent}.secondary ul.navbar-nav.menuicons{display:block}.secondary ul.navbar-nav.menuicons li{border-left:none}.secondary ul.navbar-nav.menuicons li a{padding-top:13px;padding-bottom:13px;font-weight:400;color:#fff}.secondary ul.navbar-nav.menuicons li a.social-icons{margin:13px 5px 11px;padding:11px;overflow:hidden;white-space:nowrap;font-size:0}.secondary ul.navbar-nav.menuicons li a.social-icons.linkedin:before{margin:-10px 0 0 -7px}.secondary ul.navbar-nav.menuicons li.dropdown .dropdown-menu{margin:1px 0 0;padding:0;display:block;overflow:hidden;left:0;z-index:1;width:225px;height:0;text-align:center;background:0 0;border:none;border-radius:0}.secondary ul.navbar-nav.menuicons li.dropdown li{height:70px;vertical-align:top}.secondary ul.navbar-nav.menuicons li.dropdown li a{margin:0;padding:15px;display:block;background:#0098ce;width:auto;height:70px;font-weight:600;color:#fff;line-height:42px;text-align:center;border-bottom:1px solid #007aa5}.secondary ul.navbar-nav.menuicons li.dropdown li:last-child a{border-bottom:none}.secondary ul.navbar-nav.menuicons li:nth-child(2) a{padding:11px;margin:13px 5px 11px 15px;background:0 0}.secondary ul.navbar-nav.menuicons li:nth-child(2) a:before{color:#343838}.secondary ul.navbar-nav.menuicons li:last-child a{margin:13px 0 11px 5px}@media (max-width:1200px){.secondary ul.navbar-nav.menuicons{margin:0 20px 0 0}}@media (max-width:1200px){.secondary ul.navbar-nav{margin:0 0 0 20px}}#top-menus-wrapper,.visible-xs.navbar-default{z-index:1001;border:1px solid #bdbec0;background:#fff;border-left:none;border-right:none;border-radius:0;min-height:40px}#top-menus-wrapper{position:relative;width:100%}.visible-xs.navbar-default{top:-1px;-webkit-box-shadow:0 2px 0 rgba(0,0,0,.1);box-shadow:0 2px 0 rgba(0,0,0,.1)}.visible-xs.navbar-default .container{padding:0}.visible-xs.navbar-default ul{margin:0}.visible-xs.navbar-default ul li{float:left}.visible-xs.navbar-default ul.navbar-left{float:left}.visible-xs.navbar-default ul.navbar-left li{border-left:1px solid #bdbec0}.visible-xs.navbar-default ul.navbar-left .navbar-more button{margin:0;padding:8px 15px 7px;border:none;background:0 0}.visible-xs.navbar-default ul.navbar-left .navbar-more button:before{content:"\e839";font-family:'pw-icons';font-size:22px}.visible-xs.navbar-default ul.navbar-left .navbar-menu{display:none}.visible-xs.navbar-default ul.navbar-left .navbar-menu .navbar-toggle{margin:0;padding:13px 16px;border:none;background:0 0}.visible-xs.navbar-default ul.navbar-lef ...
# @media (max-width:568px){.visible-xs.navbar-default ul.navbar-left .navbar-more button{padding:8px 0 7px 15px}}@media (max-width:480px){.visible-xs.navbar-default ul.navbar-left .api-news,.visible-xs.navbar-default ul.navbar-left .api-directory,.visible-xs.navbar-default ul.navbar-left .navbar-more{display:none}.visible-xs.navbar-default ul.navbar-left .navbar-menu{display:block}}.visible-xs.navbar-default ul.navbar-right{margin:0 6px 0 0;float:right}.visible-xs.navbar-default ul.navbar-right.menuicons a{color:#fff}.visible-xs.navbar-default ul.navbar-right a{display:block;position:relative;overflow:hidden;white-space:nowrap;font-size:16px;text-align:center;width:20px;height:20px;font-family:'pw-icons';margin:12px 8px 10px;padding:11px;line-height:20px;color:transparent}.visible-xs.navbar-default ul.navbar-right a:before{margin:-10px 0 0 -7px;position:absolute;top:50%;left:50%}.visible-xs.navbar-default ul.navbar-right a.search{margin:12px 8px 10px}.visible-xs.navbar-default ul.navbar-right a.search:before{margin:-12px 0 0 -11px;content:'\e003';font-family:'Glyphicons Halflings';font-size:21px;color:#343838}.visible-xs.navbar-default ul.navbar-right a.rss{margin:11px 8px 11px}.visible-xs.navbar-default ul.navbar-right a.rss:before{margin:-9px 0 0 -12px;content:'\e819';font-size:26px;color:#343838}.visible-xs.navbar-default ul.navbar-right a.share{background:#343838}.visible-xs.navbar-default ul.navbar-right a.share:before{content:'\e818';font-size:14px;color:#fff}.visible-xs.navbar-default ul.navbar-right a.user{margin:11px 8px 11px}.visible-xs.navbar-default ul.navbar-right a.user:before{margin:-10px 0 0 -10px;content:'\e80e';font-size:20px;color:#343838}@media (min-width:481px) and (max-width:568px){.visible-xs.navbar-default ul.navbar-right a{margin:12px 5px 10px}.visible-xs.navbar-default ul.navbar-right a.search{margin:12px 5px 10px}.visible-xs.navbar-default ul.navbar-right a.rss,.visible-xs.navbar-default ul.navbar-right a.user{margin:11px 5px 11px}}.visible-xs.navbar-default .navbar-header{margin:0}.visible-xs.navbar-default .navbar-header a{padding:13px 15px;text-transform:uppercase;color:#343838;font-weight:600;font-size:14px;text-decoration:none}.visible-xs.navbar-default .navbar-header .sitelogo a{background:url("/sites/all/themes/pw_bootstrap_two/images/logo_onscroll.png") no-repeat scroll center center rgba(0,0,0,0);color:#fff;padding:13px 30px;text-indent:-9999px}.visible-xs.navbar-default .navbar-collapse li{display:block;float:none;text-align:center}.visible-xs.navbar-default .navbar-collapse li a{padding:13px 20px;font-weight:600;font-size:14px;color:#343838;text-transform:uppercase}@media (min-width:481px){.visible-xs.navbar-default .navbar-collapse li:nth-child(1),.visible-xs.navbar-default .navbar-collapse li:nth-child(2){display:none}}#block-views-home-feature-images-block-1{margin:0 0 35px}.front .front-banner-featured-graphic img{width:100%;height:auto}.left-article h2 a{margin:0 8px 0 0;font-size:26px;font-weight:700;color:#343838;line-height:1.4}.front .region-content .block{padding:0}@media (min-width:768px){.secondary-search{width:325px;border-right:1px solid #bdbec0}}.secondary-search-onscroll{display:none}@media screen and (max-width:767px){.secondary-search-onscroll{display:block}}@media screen and (max-width:768px){.secondary-search-onscroll{display:block}}.secondary-search-onscroll{float:left}.secondary-search-onscroll .form-text{height:46px;border:none;border-right:#ccc}.menu-onscroll{display:block}.top-action-icons{display:none}.social-icons{display:inline-block;position:relative;font-size:16px;text-align:center;width:20px;height:20px;font-family:'pw-icons';margin:10px 5px}.social-icons.rss{margin:10px}.social-icons:before{margin:-10px 0 0 -6px;position:absolute;top:50%;left:50%}.facebook:before{content:'\e802';margin:-10px 0 0 -3px;font-size:14px}.twitter:before{margin:-10px 0 0 -6.5px;content:'\e803';font-size:14px}.linkedin:before{content:'\e805';font-size:14px}.googleplus:before{content:' ...
# #block-klaviyo-lists-1-klaviyo input{margin:0;font-size:14px}#block-quicktabs-right-sidebar-api-client .views-row{padding:15px 30px 15px 20px;position:relative;background:#fff;border-bottom:1px solid #e5e9ec}#block-quicktabs-right-sidebar-api-client .views-row .views-field-php a{padding:11px 11px 10px 10px;display:block;position:absolute;top:16px;right:13px;font-size:0;line-height:1;width:18px;height:18px}#block-quicktabs-right-sidebar-api-client .views-row .views-field-php a:before{position:absolute;top:2px;left:2px;content:"\e843";font-family:pw-icons;font-weight:400;font-size:18px;color:#0098ce}#block-quicktabs-right-sidebar-api-client .views-row .views-field-title{padding:0 15px 0 0}#block-quicktabs-right-sidebar-api-client .views-row .views-field-title a{font:16px 'Open Sans',sans-serif;font-weight:700;color:#343838;line-height:1.4}#block-quicktabs-right-sidebar-api-client .views-row .views-field-body{margin:5px 0 0;font-size:14px;color:#343838;line-height:1.6}#block-quicktabs-right-sidebar-api-client .views-row .views-field-body a{color:#343838}#block-quicktabs-right-sidebar-api-client .views-row:last-of-type{border-bottom:none}#block-quicktabs-right-sidebar-api-client .view-footer p a{padding:10px 0;display:block;text-align:center;font-size:12px;font-weight:700;color:#fff;background:#0098ce;text-transform:uppercase}#block-quicktabs-right-sidebar-api-client .view-footer p a:last-of-type{margin:15px 0 0;padding:0;float:none;text-align:right;font-size:14px;font-weight:400;color:#0098ce;line-height:1;background:0 0;text-transform:none}.navbar-right #pw-search-small-form--3{display:none}.navbar-right form .form-type-textfield input{padding:11px 12px}@media (max-width:1200px){body{background:#f2f2f2}#navbar .container{padding:15px 20px 20px}#navbar .region-header-right{width:313px}}@media (max-width:991px){#navbar .region-header-left{display:none}#navbar .region-header-right{width:64%}}.left-article h2 .more-related-apis-wrapper a{font-size:12px;line-height:1;padding:6px 8px;vertical-align:middle;color:#343838}*{margin:0;-webkit-font-smoothing:antialiased;-moz-font-smoothing:antialiased;font-smoothing:antialiased}body,p{font-family:"Open Sans",Helvetica,Arial,sans-serif;font-weight:400}h3{font-family:"Open Sans",Helvetica,Arial,sans-serif;font-weight:400}@media screen and (min-width:1200px){.container{max-width:1200px}}@media (max-width:1200px){.container{padding:15px 20px;max-width:none;width:auto}.container>.row{margin-left:auto;margin-right:auto}}@media screen and (max-width:768px){.container{max-width:none}}@media screen and (min-width:1200px){.no-gutter{padding-right:0;padding-left:0}}@media screen and (min-width:992px){.no-gutter{padding-right:0;padding-left:0}}.main-container{padding-top:25px;padding-bottom:0}@media (max-width:767px){.main-container{padding:0}}.content-section .region-content{padding-right:40px;padding-bottom:40px}@media (max-width:1200px){.content-section .region-content{margin:0 20px 25px 0;padding:20px;background:#fff}}@media (max-width:767px){.content-section .region-content{margin:0 0 25px;padding:67px 20px 20px}}@media screen and (min-width:992px){.content-section{float:left}}@media screen and (min-width:1200px){.content-section{width:830px}}.content-section:after{margin-left:830px;position:fixed;top:0;content:"";width:9999px;height:9999px;background:#f2f2f2}@media (max-width:1200px){.content-section:after{display:none}}@media (max-width:991px){.content-section{padding-left:0;padding-right:0}}.btn-default{background:#0098ce none repeat scroll 0 0;color:#fff}.btn{border:0 none;border-radius:0}input.form-text{font-weight:400;height:45px;padding:6px 12px}#block-pw-common-search-block .input-group .form-control{display:table-cell}.region-header-right .signup{float:none}.navbar-collapse-share{width:100%}.navbar-collapse-share ul{width:100%;border:1px solid #bdbec0;padding-left:20px;padding-right:20px;margin-right:0}.navbar-collapse-share ul li a{font-size:0px}.navbar-collapse-share ul li a.rss:before{ ...
# .navbar-collapse-search .form-type-textfield{width:100%}.visible-xs.navbar-default ul.navbar-right a{height:23px}.visible-xs.navbar-default ul.navbar-right a.search{margin:11px 8px 11px}.front .home-slider-image{margin:0 0 20px}.leaf-api-directory ul.menu li a{padding:0;line-height:19px}.leaf-api-directory .view-api-directory-list-content .view-content{margin:0 0 15px;display:block;overflow:hidden;float:left;width:100%}#navbar .block-pw-homepage.signup{height:21px}@font-face{font-display:swap;font-family:'pw-icons';src:url('/sites/all/themes/pw_bootstrap_two/font/pw-icons.eot?35082076');src:url('/sites/all/themes/pw_bootstrap_two/font/pw-icons.eot?35082076#iefix') format('embedded-opentype'),url('/sites/all/themes/pw_bootstrap_two/font/pw-icons.woff?35082076') format('woff'),url('/sites/all/themes/pw_bootstrap_two/font/pw-icons.ttf?35082076') format('truetype'),url('/sites/all/themes/pw_bootstrap_two/font/pw-icons.svg?35082076#pw-icons') format('svg');font-weight:400;font-style:normal}[class^=icon-]:before{font-family:"pw-icons";font-style:normal;font-weight:400;speak:none;display:inline-block;text-decoration:inherit;width:1em;margin-right:.2em;text-align:center;font-variant:normal;text-transform:none;line-height:1em;margin-left:.2em}.inlineGlossaryTerm{border-bottom:2px dotted #bdbec0}.tooltipster-light .tooltipster-content h3.heading-glossary{padding:0 10px;margin-top:10px}.tooltipster-light .tooltipster-content p.heading-description{font-weight:400;padding:10px;font-size:14px;line-height:22px}.tooltipster-light .tooltipster-content p.heading-url{font-weight:400;padding:0 10px;margin-bottom:10px;font-size:14px;line-height:22px}.tooltipster-light .tooltipster-content h3.heading-glossary a{color:#343838}</style><noscript id="advagg_loadcss_1"><link href="/sites/default/files/advagg_css/css__9cWqptSUNYq5YedfIwh33VxtugFVWjDdEsblT8GhLKI__quUjyhSfbEukHj8a0hYvzm9VTmPALmSZvA0xfM_Oxzo__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.css" media="all" rel="stylesheet" type="text/css"/></noscript><noscript id="advagg_loadcss_2"><link href="/sites/default/files/advagg_css/css__qi8YWDPFPT47Hua3Uo8V-CwYV79O8gYOw4xRshlFw2o__3xbmlSYfD5Z9oYAFZCJZDeKB8gckcBfk-yMlANNdw6A__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.css" media="all" rel="stylesheet" type="text/css"/></noscript><noscript id="advagg_loadcss_3"><link href="/sites/default/files/advagg_css/css__iRtm_E1dYryZPFIFk9pokobb3FxMFRIo2mqO7hKN7A0__iSec1Q6JfYpIzg296XMtBK-80q1PX9u2b1w8dhqijBo__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.css" media="all" rel="stylesheet" type="text/css"/></noscript><noscript id="advagg_loadcss_4"><link href="/sites/default/files/advagg_css/css__IND9Ea9cZJoyPbSkNshnqYv4c5MRWiCE06f8uY8qHPM__P6MQmonPAG9EwAkymq3qjeHUqjIQEfCps7JxljLqlUY__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.css" media="all" rel="stylesheet" type="text/css"/></noscript><noscript id="advagg_loadcss_5"><link href="/sites/default/files/advagg_css/css__wnSz6RFVBhmGqYV-C7ZkEY4CuxwUxoXjOofANhNrfEY__BFf2ckV9GvO5WJjbOVmjqnVnFli_ppSAA3qnxouoBPg__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.css" media="all" rel="stylesheet" type="text/css"/></noscript><noscript id="advagg_loadcss_6"><link href="/sites/default/files/advagg_css/css__Q6VQMBrdLoRe0wCeJzgDtp1j7WCguz1QYbpEWHZVpiw__WQ8SZ5jt2LMrejyG8oPqweryFG5KVk5Cib5nHz_jc6o__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.css" media="all" rel="stylesheet" type="text/css"/></noscript><noscript id="advagg_loadcss_7"><link href="/sites/default/files/advagg_css/css__lgfn19CDYxEbG2M_9wSih1TDKKUksjSlokdnhethkXI__B-j-StU84dPB1ih5KRN1B_796lm7G6L5mHQOUb-PlhY__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.css" media="all" rel="stylesheet" type="text/css"/></noscript><noscript id="advagg_loadcss_8"><link href="/sites/default/files/advagg_css/css__vP1bhFEwKrZkNwt1wEgWQHdPGxctn-GuL5FJRabPuQ0__wq2cMTqH2xzpUaajNK-ntVjmRA-Umb0bp3Uq5h5tINo__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.css" media="all" rel="stylesheet" type="text/css"/></noscript><noscript id="advagg_loadcss_9"><link href= ...
# .glyphicon{position:relative;top:1px;display:inline-block;font-family:'Glyphicons Halflings';font-style:normal;font-weight:400;line-height:1;-webkit-font-smoothing:antialiased}.glyphicon-search:before{content:'\e003'}.caret{display:inline-block;width:0;height:0;margin-left:2px;vertical-align:middle;border-width:4px 4px 0;border-style:solid solid dotted;border-top-color:#000;border-right-color:transparent;border-left-color:transparent;content:''}.dropdown{position:relative}.dropdown-menu{position:absolute;top:100%;left:0;z-index:1000;display:none;float:left;min-width:160px;padding:5px 0;margin:2px 0 0;list-style:none;font-size:14px;background-color:#fff;border:1px solid rgba(0,0,0,.14902);border-top-left-radius:4px;border-top-right-radius:4px;border-bottom-right-radius:4px;border-bottom-left-radius:4px;-webkit-box-shadow:rgba(0,0,0,.172549) 0px 6px 12px;box-shadow:rgba(0,0,0,.172549) 0px 6px 12px;background-clip:padding-box}.dropdown-menu>li>a{display:block;padding:3px 20px;clear:both;font-weight:400;line-height:1.428571429;color:#333;white-space:nowrap}.input-group{position:relative;display:table;border-collapse:separate}.input-group .form-control{width:100%;margin-bottom:0}.input-group-btn,.input-group .form-control{display:table-cell}.input-group-btn:not(:first-child):not(:last-child){border-top-left-radius:0;border-top-right-radius:0;border-bottom-right-radius:0;border-bottom-left-radius:0}.input-group-btn{width:1%;white-space:nowrap;vertical-align:middle}.input-group .form-control:first-child{border-bottom-right-radius:0;border-top-right-radius:0}.input-group .form-control:last-child{border-bottom-left-radius:0;border-top-left-radius:0}.input-group-btn{position:relative;white-space:nowrap}.input-group-btn>.btn{position:relative}.nav{margin-bottom:0;padding-left:0;list-style:none}.nav:before,.nav:after{content:' ';display:table}.nav:after{clear:both}.nav:before,.nav:after{content:' ';display:table}.nav:after{clear:both}.nav>li{position:relative;display:block}.nav>li>a{position:relative;display:block;padding:10px 15px}.nav .caret{border-top-color:#0098ce;border-bottom-color:#0098ce}.navbar{position:relative;z-index:1000;min-height:50px;margin-bottom:20px;border:1px solid transparent}.navbar:before,.navbar:after{content:' ';display:table}.navbar:after{clear:both}.navbar:before,.navbar:after{content:' ';display:table}.navbar:after{clear:both}@media (min-width:768px){.navbar{border-top-left-radius:4px;border-top-right-radius:4px;border-bottom-right-radius:4px;border-bottom-left-radius:4px}}.navbar-header:before,.navbar-header:after{content:' ';display:table}.navbar-header:after{clear:both}.navbar-header:before,.navbar-header:after{content:' ';display:table}.navbar-header:after{clear:both}@media (min-width:768px){.navbar-header{float:left}}.navbar-collapse{max-height:340px;overflow-x:visible;padding-right:15px;padding-left:15px;border-top-width:1px;border-top-style:solid;border-top-color:transparent;box-shadow:rgba(255,255,255,.0980392) 0px 1px 0px inset}.navbar-collapse:before,.navbar-collapse:after{content:' ';display:table}.navbar-collapse:after{clear:both}.navbar-collapse:before,.navbar-collapse:after{content:' ';display:table}.navbar-collapse:after{clear:both}@media (min-width:768px){.navbar-collapse{width:auto;border-top-width:0;box-shadow:none}.navbar-collapse.collapse{padding-bottom:0;display:block !important;height:auto !important;overflow:visible !important}}.container>.navbar-header,.container>.navbar-collapse{margin-right:-15px;margin-left:-15px}@media (min-width:768px){.container>.navbar-header,.container>.navbar-collapse{margin-right:0;margin-left:0}}.navbar-fixed-top{position:fixed;right:0;left:0;border-width:0 0 1px}@media (min-width:768px){.navbar-fixed-top{border-top-left-radius:0;border-top-right-radius:0;border-bottom-right-radius:0;border-bottom-left-radius:0}}.navbar-fixed-top{z-index:1030;top:0}.navbar-brand{float:left;padding:15px;font-size:18px;line-height:20px}.navbar-toggle{position:relative;float:righ ...
# .navbar-toggle .icon-bar{display:block;width:22px;height:2px;border-top-left-radius:1px;border-top-right-radius:1px;border-bottom-right-radius:1px;border-bottom-left-radius:1px}.navbar-toggle .icon-bar+.icon-bar{margin-top:4px}@media (min-width:768px){.navbar-toggle{display:none}}.navbar-nav{margin:7.5px -15px}.navbar-nav>li>a{padding-top:10px;padding-bottom:10px;line-height:20px}@media (min-width:768px){.navbar-nav{float:left;margin:0}.navbar-nav>li{float:left}.navbar-nav>li>a{padding-top:15px;padding-bottom:15px}}@media (min-width:768px){.navbar-left{float:left !important}.navbar-right{float:right !important}}.navbar-nav>li>.dropdown-menu{margin-top:0;border-top-right-radius:0;border-top-left-radius:0}.navbar-btn{margin-top:8px;margin-bottom:8px}.navbar-default{background-color:#f8f8f8;border-color:#e7e7e7}.navbar-default .navbar-brand{color:#777}.navbar-default .navbar-nav>li>a{color:#777}.navbar-default .navbar-toggle{border-color:#ddd}.navbar-default .navbar-toggle .icon-bar{background-color:#ccc}.navbar-default .navbar-collapse{border-color:#e6e6e6}.navbar-default .navbar-nav>.dropdown>a .caret{border-top-color:#777;border-bottom-color:#777}.clearfix:before,.clearfix:after{content:' ';display:table}.clearfix:after{clear:both}.pull-left{float:left !important}.visible-xs{display:none !important}@media (max-width:767px){.visible-xs{display:block !important}}@media (max-width:991px) and (min-width:768px){.visible-xs.visible-sm{display:block !important}}.visible-sm{display:none !important}@media (max-width:767px){.visible-sm.visible-xs{display:block !important}}@media (max-width:991px) and (min-width:768px){.visible-sm{display:block !important}}@media (max-width:1199px) and (min-width:992px){.visible-sm.visible-md{display:block !important}}@media (min-width:1200px){.visible-sm.visible-lg{display:block !important}}.visible-md{display:none !important}@media (max-width:991px) and (min-width:768px){.visible-md.visible-sm{display:block !important}}@media (max-width:1199px) and (min-width:992px){.visible-md{display:block !important}}@media (min-width:1200px){.visible-md.visible-lg{display:block !important}}.visible-lg{display:none !important}@media (max-width:991px) and (min-width:768px){.visible-lg.visible-sm{display:block !important}}@media (max-width:1199px) and (min-width:992px){.visible-lg.visible-md{display:block !important}}@media (min-width:1200px){.visible-lg{display:block !important}}.hidden-xs{display:block !important}@media (max-width:767px){.hidden-xs{display:none !important}}.hidden-sm{display:block !important}@media (max-width:991px) and (min-width:768px){.hidden-sm{display:none !important}}@media (max-width:1199px) and (min-width:992px){.hidden-sm.hidden-md{display:none !important}}@media (min-width:1200px){.hidden-sm.hidden-lg{display:none !important}}.hidden-md{display:block !important}@media (max-width:991px) and (min-width:768px){.hidden-md.hidden-sm{display:none !important}}@media (max-width:1199px) and (min-width:992px){.hidden-md{display:none !important}}@media (min-width:1200px){.hidden-md.hidden-lg{display:none !important}}.hidden-lg{display:block !important}@media (max-width:991px) and (min-width:768px){.hidden-lg.hidden-sm{display:none !important}}@media (max-width:1199px) and (min-width:992px){.hidden-lg.hidden-md{display:none !important}}@media (min-width:1200px){.hidden-lg{display:none !important}}body{position:relative}.element-invisible{margin:0;padding:0;width:1px}input{max-width:100%;width:auto}ul li.expanded,ul li.leaf{list-style:none none}@media (max-width:360px){ul.menuicons>li:nth-child(2){display:none}.visible-xs.navbar-default ul.navbar-right a.search{margin:14px 8px 10px !important}}@font-face{font-family:'Glyphicons Halflings';src:url(/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.eot?#iefix) format('embedded-opentype'),url(/sites/all/themes/pw_bootstrap_two/bootstrap/fonts/glyphicons-halflings-regular.woff) format('woff'),url(/sites/all/themes/pw_bootstrap_ ...
# ...
# The Bing API provides an experience similar to Bing.com/search by...</td><td class="views-field views-field-field-article-primary-category"> <a href="/category/search">Search</a></td><td class="views-field views-field-flag-follow-api-count"> 354</td><td class="views-field views-field-pw-version-links"> <a href="/api/bing-rest-api-v7">REST v7</a></td></tr><tr class="even"><td class="views-field views-field-pw-version-title"> <a href="/api/instagram-graph">Instagram Graph API</a><br/></td><td class="views-field views-field-search-api-excerpt views-field-field-api-description hidden-xs visible-md visible-sm col-md-8"> Instagram is a photo sharing iPhone app and service. Users take photos and can share them with Instagram contacts, as well as friends on other social networks like Twitter and Facebook. The Instagram...</td><td class="views-field views-field-field-article-primary-category"> <a href="/category/photos">Photos</a></td><td class="views-field views-field-flag-follow-api-count"> 1,233</td><td class="views-field views-field-pw-version-links"> <a href="/api/instagram-graph-rest-api-v211">REST v2.11</a></td></tr><tr class="odd views-row-last"><td class="views-field views-field-pw-version-title"> <a href="/api/yelp-fusion">Yelp Fusion API</a><br/></td><td class="views-field views-field-search-api-excerpt views-field-field-api-description hidden-xs visible-md visible-sm col-md-8"> The Yelp Fusion APIs are RESTful APIs and users can retrieve business review and rating, information for a particular geographic region or location.display review information for a particular...</td><td class="views-field views-field-field-article-primary-category"> <a href="/category/recommendations">Recommendations</a></td><td class="views-field views-field-flag-follow-api-count"> 360</td><td class="views-field views-field-pw-version-links"> <a href="/api/yelp-fusion-rest-api">REST</a></td></tr><div class="text-center"><ul class="pagination"><li class="pager-current active"><a href="#">1</a></li><li class="pager-item"><a href="/category/all/apis?page=1" title="Go to page 2">2</a></li><li class="pager-item"><a href="/category/all/apis?page=2" title="Go to page 3">3</a></li><li class="pager-ellipsis disabled"><span>…</span></li><li class="pager-next"><a href="/category/all/apis?page=888" title="Go to page 889">889</a></li><li class="pager-last"><a href="/category/all/apis?page=1" title="Go to next page">next ›</a></li></ul></div>  <aside class="col-xs-12 col-sm-4 col-md-4 col-lg-3 no-gutter sidebar-aside" role="complementary"><div class="region region-sidebar-second"> <section class="block block-block" id="block-block-46"><div class="callout-covid"><h3>Coronavirus Developer Resource Center</h3><p>COVID-19 APIs, SDKs, coverage, open source code and other related dev resources »</p></div></section> <noscript><style>form.antibot { display: none !important; }</style><div class="antibot-no-js antibot-message antibot-message-warning messages warning"> You must have JavaScript enabled to use this form.</div></noscript><section class="block block-klaviyo-lists" id="block-klaviyo-lists-1-klaviyo"><form accept-charset="UTF-8" action="/antibot" class="klaviyo-lists-user-subscribe-form antibot" id="klaviyo-lists-user-subscribe-form" method="post"><div><fieldset class="panel panel-default form-wrapper" id="edit-klaviyo-form"><div class="panel-body" id="edit-klaviyo-form-body"><div class="newsletter_container"> <span class="heading">Today in APIs</span> <span class="newsletter_text">Latest news about the API economy and newest APIs, delivered daily:</span></div><div class="form-item form-item-klaviyo-form-klaviyo-programmableweb-today-email form-type-textfield form-group"> <label class="control-label" for="edit-klaviyo-form-klaviyo-programmableweb-today-email">Today in APIs</label><input aria-label="Today in APIs" class="form-control form-text" id="edit-klaviyo-form-klaviyo-programmableweb-today-email" maxlength="128" name="klaviyo_form[klaviyo_programmableweb_tod ...
# img[data-src] { display: none !important; }
# </style></noscript><script async="async" src="/sites/all/libraries/respondjs/respond.min.js?qqtyk1" type="text/javascript"></script><script onload="if(jQuery.isFunction(jQuery.holdReady)){jQuery.holdReady(true);}" src="/sites/default/files/advagg_js/js__6jXNzWqaGAGxRzYR67Gb8-P-1otXnhTgmpniIS0W_ek__Q7lSYgpjXbvsuMK3mJ1dt1Yl-WkU5aSQuvaBpAZ45bc__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__y2PjXQc12RxY_q4r5REyLh0lvX3pzql1w3fDK0T5wNY__FdTI2hs6QcF4l_4XXXMIBgD6J0HC6QmPpihDo3PA1mM__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__mNdHOs16qqyjxIWIpfKqaz4NZoqetfuHYTaTxei57y8__ehkbXErZq8gAr3y8ATBMlGbcst-MMDfQXpEsySH2tbk__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__9ici6QMeDS-cROq8R0RhuICsMGMP2wcJZNQQFsqQi44__kScSwG4RXGl1LXnj4qqt0ZxtNX4Gh2TK5W-o8Uup4SA__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__5zhFBHWG8cFOCNCpDlj7pwNwFoSGFvQEfYJiiLp0EY8__1QZk3htrAFX0roX9iYK1m1kMTROR0qrjHwLZiki82Ko__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__v6Ydsa-oLVsCbWBUPEs_rmv-EgYK35mJXlwzszDg2io__NcbPgl6yce1cPkJcub1SVldKst10pVo0nN36XtkHZn8__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__6__IQ9wfCOnkxxh3-xBv65bwhmZoNtcwHNnhprahFvw__JiTknG935-WORDUVnvwp_OgAgDnyJVjXiT5MkO5L2LY__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__ylcODMPWo_13MLom5ZqWGQsJNZKFh4uV-YcKFVTNVmY__udl9eol5cfcZrwikn8Dwm7QH7SvVG2cLtO8U9MwiAl0__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__bFOh74rblCNfeAqBWGqF603OXHEBWOI8xUWm9gk-Mnw__EBNOtXb-FCEjFlZFDdnpg4YYSmssKyrojBPzZ8hk0lo__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__Naf1oKUAzdgRGEFTkelN4-FApHS8_d9QPYw6mQGcJis__K429xtHLGa5I9Cf5o8U8v5l0eB_vVHBbt4levtzvC-o__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__2bzbrE24coPm5uj_fnejfHFhxP4MnERSax237TPs4fw__UWTtPfeGY2BaEq71d-wgRTo2EBi6XFPNo2OFeuWDWi4__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__CajjMgHTE1PwscR_Jluzv5MrC9NzoWq9mLHWtwesgIo__mrArwSTL6Ys68_y7Bl6G-QfcTe_19aanxfiq3UfUwwQ__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__jp6TUQ2Srp80BmV58e_PyqqxgOCuOA528XdUfU_qqvA__rFcDqVCxZApZvAQaD0vHnMxN_f0Z9oVCScW8LZJVE8A__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__MKD2VoBtH97fIwZn6Hfceqr3PrVcFQTKl_SufkWdVCg__LBO4dfauMpZj288x9OdM_WeeoBLh6hxVhS3sHVoaVcI__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/all/libraries/jgrowl/jquery.jgrowl.min.js?qqtyk1" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__NWr0dtL2v5iPdVadAWuTp-uHNgHXz3PPLpVzumVGDEk__EJiM83jRUqAsnLZnoutUvqJoLibreqEyyGqKMogzsUI__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__bFkQVHbEhtS1uBigxpGi19rOUSSjmz5npcHnzuoHI8Y__jnBy3voieCOrT5mS-H2uMYWYMPWls4qT80FsxpVYpiw__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__HkwJgIXAUvvbbl426ldOxVgTabxL2LZDUodxoyBmWDE__UikOZk7WCKQJKe_fRD65trmQXrQgby7r6gRQB75YoLU__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascr ...
# <!--//--><![CDATA[//><!--
# ;function advagg_mod_defer_3(){jQuery.migrateMute=!0;jQuery.migrateTrace=!1};window.setTimeout(advagg_mod_defer_3,0);
# //--><!]]>
# </script><script type="text/javascript">
# <!--//--><![CDATA[//><!--
# ;jQuery(document).ready(function(e){e('#om-maximenu-top-most-menu li.om-leaf .om-maximenu-content').removeClass('om-maximenu-content-nofade');e('#om-maximenu-top-most-menu li.om-leaf').hoverIntent({over:o,timeout:250,out:m});function o(){e('.om-maximenu-content.closed',this).fadeIn('fast')};function m(){e('.om-maximenu-content.closed',this).fadeOut('fast')}});
# //--><!]]>
# </script><script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings,{"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"pw_bootstrap_two","theme_token":"FwgRY4oly9WespFy_Q4VsScLDIiJxStB0uzj4G-AZho","jquery_version":"2.2","js":{"sites\/all\/libraries\/respondjs\/respond.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/jquery\/2.2\/jquery.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/jquery-migrate\/1\/jquery-migrate.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/libraries\/chosen\/chosen.jquery.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/external\/jquery.cookie.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/jquery.form\/4\/jquery.form.min.js":1,"misc\/form.js":1,"misc\/ajax.js":1,"sites\/all\/modules\/contrib\/jquery_update\/js\/jquery_update.js":1,"sites\/all\/modules\/contrib\/comment_notify\/comment_notify.js":1,"sites\/all\/modules\/custom\/contrib\/om_maximenu\/js\/om_maximenu.js":1,"sites\/all\/modules\/custom\/pw_articles\/js\/pw_articles.js":1,"sites\/all\/modules\/contrib\/lazyloader\/jquery.lazyloader.js":1,"sites\/all\/modules\/contrib\/extlink\/extlink.js":1,"sites\/all\/themes\/bootstrap\/js\/misc\/_progress.js":1,"sites\/all\/modules\/custom\/contrib\/user_registration_and_management\/lr_social_login\/js\/LoginRadiusSDK.js":1,"sites\/all\/modules\/contrib\/lightbox2\/js\/lightbox.js":1,"sites\/all\/libraries\/jgrowl\/jquery.jgrowl.min.js":1,"sites\/all\/modules\/contrib\/nicemessages\/js\/nicemessages.js":1,"sites\/all\/modules\/custom\/contrib\/om_maximenu\/contrib\/jquery.hoverIntent.minified.js":1,"sites\/all\/modules\/custom\/contrib\/views\/js\/base.js":1,"sites\/all\/modules\/custom\/contrib\/views\/js\/ajax_view.js":1,"sites\/all\/modules\/contrib\/captcha\/captcha.js":1,"sites\/all\/modules\/contrib\/antibot\/js\/antibot.js":1,"sites\/all\/modules\/custom\/pw_api\/pw_api_clone_cookie.js":1,"sites\/all\/modules\/contrib\/quicktabs\/js\/quicktabs.js":1,"sites\/all\/modules\/contrib\/ajaxblocks\/ajaxblocks.js":1,"https:\/\/plausible.io\/js\/plausible.js":1,"sites\/all\/modules\/custom\/pw_custom_ga\/window_plausible.js":1,"sites\/all\/modules\/contrib\/chosen\/chosen.js":1,"sites\/all\/themes\/pw_bootstrap_two\/js\/dev.js":1,"sites\/all\/themes\/pw_bootstrap_two\/js\/pw_nodetrack.js":1,"sites\/all\/themes\/pw_bootstrap_two\/js\/jquery.tooltipster.js":1,"sites\/all\/themes\/pw_bootstrap_two\/js\/pw_bootstrap_two_tooltipster.js":1,"sites\/all\/themes\/pw_bootstrap_two\/js\/pw_custom.js":1,"sites\/all\/themes\/pw_bootstrap_two\/bootstrap\/js\/affix.js":1,"sites\/all\/themes\/pw_bootstrap_two\/bootstrap\/js\/alert.js":1,"sites\/all\/themes\/pw_bootstrap_two\/bootstrap\/js\/button.js":1,"sites\/all\/themes\/pw_bootstrap_two\/bootstrap\/js\/carousel.js":1,"sites\/all\/themes\/pw_bootstrap_two\/bootstrap\/js\/collapse.js":1,"sites\/all\/themes\/pw_bootstrap_two\/bootstrap\/js\/dropdown.js":1,"sites\/all\/themes\/pw_bootstrap_two\/bootstrap\/js\/modal.js":1,"sites\/all\/themes\/pw_bootstrap_two\/bootstrap\/js\/tooltip.js":1,"sites\/all\/themes\/pw_bootstrap_two\/bootstrap\/js\/popover.js":1,"sites\/all\/themes\/pw_bootstrap_two\/bootstrap\/js\/scrollspy.js":1,"sites\/all\/themes\/pw_bootstrap_two\/bootstrap\/js\/tab.js":1,"sites\/all\/themes\/pw_bootstrap_two\/bootstrap\/js\/transition.js":1,"sites\/all\/themes\/pw_bootstrap_two\/js\/helpscript.js":1,"sites\/all\/themes\/pw_bootstrap_two\/js\/ajax_view.js":1,"sites\/all\/themes\/bootstrap\/js\/misc\/ajax.js":1,"sites\/all\/modules\/custom\/pw_custom_ga\/pw_custom_ga.js":1,"sites\/all\/modules\/custom\/pw_klaviyo_tracking\/checkGDPR.js":1,"sites\/all\/modules\/custom\/pw_social\/js\/pw_social.js":1,"sites\/all\/modules\/custom\/pw_ad\/js\/pwad_script.js":1,"sites\/all\/modules\/custom\/pw_ad\/js\/customscript.js":1,"sites\/all\/modules\/custom\/pw_ad\/js\/adzerkCheckGDPR.js":1,"sites\/all\/modules\/custom\/pw_ad\/js\/pw_adz ...
# //--><!]]>
# </script><script src="/sites/default/files/advagg_js/js__V-CSygCpzRvcrBj2xzP_pWUmThmgxZB0WJas_46jZJQ__r7EHE-qIIJI_ZzSfHcvp09rPzxBzdRzRF8OoBpp04gA__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script src="https://www.mulesoft.com/pw/prod/oneTrust/04856e97-6bf2-42aa-9a14-8122a16ebcf2.js" type="text/javascript"></script><script src="/sites/default/files/advagg_js/js__-SzXQOp_SP23Ut5ela1gIX3WLaQxa4Cb8oYfAsdsPBw__ccIm7XUg5YUjEAMMywhTGpZ5o4QVoqohyHMK3cjXYgc__mKGJ8DxblHFKsOwzAG9PC2n7qs4HFgIXUo66tMQxojc.js" type="text/javascript"></script><script type="text/javascript">
# <!--//--><![CDATA[//><!--
# ;function advagg_mod_defer_4(){(function(a){Drupal.behaviors.lazyloader={attach:function(d,e){a('img[data-src]').lazyloader({distance:0,icon:''})}}}(jQuery))};window.setTimeout(advagg_mod_defer_4,0);
# //--><!]]>
# </script>

# %%
apis_table = soup.find('tbody')

# %%
apis_table
# Out:
# <tbody><tr class="odd views-row-first"><td class="views-field views-field-pw-version-title"> <a href="/api/google-maps">Google Maps API</a><br/></td><td class="views-field views-field-search-api-excerpt views-field-field-api-description hidden-xs visible-md visible-sm col-md-8"> [This API is no longer available. Google Maps' services have been split into multiple APIs, including the Static Maps API, Street View Image API, Directions APIs, Distance Matrix API, Elevation API,...</td><td class="views-field views-field-field-article-primary-category"> <a href="/category/mapping">Mapping</a></td><td class="views-field views-field-flag-follow-api-count"> 3,850</td><td class="views-field views-field-pw-version-links"> <a href="/api/google-maps-rest-api">REST</a></td></tr><tr class="even"><td class="views-field views-field-pw-version-title"> <a href="/api/twitter">Twitter API</a><br/></td><td class="views-field views-field-search-api-excerpt views-field-field-api-description hidden-xs visible-md visible-sm col-md-8"> [This API is no longer available. It has been split into multiple APIs, including the Twitter Ads API, Twitter Search Tweets API, and Twitter Direct Message API.
# This profile is maintained for...</td><td class="views-field views-field-field-article-primary-category"> <a href="/category/social">Social</a></td><td class="views-field views-field-flag-follow-api-count"> 2,361</td><td class="views-field views-field-pw-version-links"><div class="version-links-wrapper dropdown"><a class="version-links-trigger dropdown dropdown-toggle active" data-target="#" data-toggle="dropdown" href="#">Version<span class="caret"></span></a><ul class="dropdown-menu"><li><a class="other-version-values" href="/api/twitter-feed-api" id="version-link-1"> <span class="style"> FEED</span> <span class="version-status deactivated">Deactivated</span></a></li><li><a class="other-version-values" href="/api/twitter-rest-api" id="version-link-2"> <span class="style"> REST</span> <span class="version-status deactivated">Deactivated</span></a></li><li><a class="other-version-values" href="/api/twitter-rest-api-v2" id="version-link-3"> <span class="style"> REST</span> v 2 <span class="version-status pre-release">Pre-release</span></a></li></ul></div></td></tr></tbody>

# %%
def request_soup(url="https://www.programmableweb.com/category/all/apis"):
    response = requests.get(url)
    data = response.text
    return BeautifulSoup(data,'html.parser')

# %%
npo_apis = {}
apis_no = 0
while True:
    soup = request_soup(url)
    apis_table = soup.find('tbody')
    for tr in apis_table.select('tr'):
        name_tag = tr.find("td",{"class":"views-field views-field-pw-version-title"})
        name = name_tag.text if name_tag else "N/A"
        description = tr.find("td",{"class":"views-field views-field-search-api-excerpt views-field-field-api-description hidden-xs visible-md visible-sm col-md-8"}).text
        category = tr.find("td",{"class":"views-field views-field-field-article-primary-category"}).text
        link = 'https://www.programmableweb.com' + tr.find("td",{"class":"views-field views-field-pw-version-title"}).a.get("href")

        apis_no+=1
        npo_apis[apis_no]=[name,description,category,link]

        print("Api Name: ",name, "\nDescription: ",description,"\nCategory:",category,"\nLink: ",link,"\n-----")
    url_tag = soup.find('a',{'title':'Go to next page'})
    if url_tag.get('href'):
        url = 'https://www.programmableweb.com' + url_tag.get('href')
        #print(url)
        #break
    else:
        break
    
print('Total Apis: ', apis_no)

#DataFrame
npo_apis_df = pd.DataFrame.from_dict(npo_apis,orient='index',columns=['Api Name','Description','Category','Link'])
#CSV
npo_apis_df.to_csv('npo_apis.csv',sep='|')
# Out:
# Api Name:   Mapbox API
# Description:   Mapbox is a suite of open source mapping tools. This API can be used to create interactive maps using a wide range of file formats and databases. It also allows users to host their maps so that they...
# Category:  Mapping
# Link:  https://www.programmableweb.com/api/mapbox
# -----
# Api Name:   Groupon API
# Description:   Groupon features a daily deal on the best stuff to do, see, eat, and buy in a variety of cities across the United States. Groupon gets discounts you won't find anywhere else through the power of...
# Category:  eCommerce
# Link:  https://www.programmableweb.com/api/groupon
# -----
# Api Name:   Forvo API
# Description:   The Forvo API allows users to integrate the functionality of Forvo into their websites or applications. Forvo is the largest pronunciation guide in the world, the place where you will find millions...
# Category:  Reference
# Link:  https://www.programmableweb.com/api/forvo
# -----
# Api Name:   Google OpenID API
# Description:   The Google OpenID API lets third-party web sites and applications let visitors sign in using their Google user accounts. The OpenID standard allows users to nor have to set up separate login accounts...
# Category:  Security
# Link:  https://www.programmableweb.com/api/google-openid
# -----
# Api Name:   Guardian API
# Description:   The Guardian Open Platform is the suite of web services that make it possible for our partners to build applications with the Guardian. We've opened up our platform so that everyone can benefit from...
# Category:  News Services
# Link:  https://www.programmableweb.com/api/guardian
# -----
# Api Name:   Discogs API
# Description:   From their site: Discogs is a user-built database containing information on artists, labels, and their recordings. Discogs is constantly growing as users submit releases to the database.
# Category:  Music
# Link:  https://www.programmableweb.com/api/discogs
# -----
# Api Name:   Yahoo Mail API
# Description:   The Yahoo Mail Web Service API is a full-featured interface to Yahoo! Mail. With it, you can build applications that display message summary information, parse message contents, manage folders, and...
# Category:  Email
# Link:  https://www.programmableweb.com/api/yahoo-mail
# -----
# Api Name:   23 API
# Description:   From their site: We believe that APIs should be open and non-vendor specific to create a common field for interoperability and competition. It does not make a lot of sense for us to create a 23 API...
# Category:  Photos
# Link:  https://www.programmableweb.com/api/23
# -----
# Api Name:   CoinDesk API
# Description:   CoinDesk is an information center on Bitcoins, a decentralized digital currency used around the world. One service that CoinDesk provides is the Bitcoin Price Index (BPI). This Bitcoin pricing data...
# Category:  Financial
# Link:  https://www.programmableweb.com/api/coindesk
# -----
# Api Name:   IMSAS API
# Description:   IMSAS LLC is a leading provider of Web Service solutions across a range of background screening data, MVR records, income and medical license verifications. IMSAS products are delivered using XML...
# Category:  Database
# Link:  https://www.programmableweb.com/api/imsas
# -----
# Api Name:   Dailymotion API
# Description:   Dailymotion is one of the biggest video platforms in the world, and as such, we offer video storage and viewing capability to our users. We would like to make it easy for you developers to integrate...
# Category:  Video
# Link:  https://www.programmableweb.com/api/dailymotion
# -----
# Api Name:   WordPress.com API
# Description:   WordPress.com is the hosted version of the popular open source blogging software. WordPress.com exposes site, post, comment, and like data via an REST Application Programming Interface (API) in a...
# Category:  Blogging
# Link:  https://www.programmableweb.com/api/wordpresscom
# -----
# Api Name:   Withings API
# Description:   Withings is a company focusing on the development of connected measuring devices, such as scales and blood pressure monitors, that can send health information directly to the internet. Withings Body...
# Category:  Medical
# Link:  https://www.programmableweb.com/api/withings
# -----
# Api Name:   Google Fonts API
# Description:   The Google Fonts API in REST architecture returns JSON data to add web fonts to any web page. Available open source fonts, browser compatibility, and shared stylesheet link to HTML documents in a CSS...
# Category:  Fonts
# Link:  https://www.programmableweb.com/api/google-fonts
# -----
# Api Name:   ChartLyrics Lyric API
# Description:   ChartLyrics is a lyrics database sorted by artists or songs. The Lyric API uses either a SOAP or REST interface to allow users and developers to access the database. The API provides 2 functions....
# Category:  Music
# Link:  https://www.programmableweb.com/api/chartlyrics-lyric
# -----
# Api Name:   Amazon RDS Relational Database Service API
# Description:   Amazon Relational Database Service, aka Amazon RDS, is a web service that lets you set up, operate, and scale a relational database in the cloud. It provides cost-effective and resizable capacity....
# Category:  Database
# Link:  https://www.programmableweb.com/api/amazon-rds-relational-database-service
# -----
# Api Name:   WatchMouse API
# Description:   The WatchMouse service checks the behavior and availability of websites. WatchMouse allows site owners to optimize the internet experience of their customers.
# A worldwide network checks websites...
# Category:  Monitoring
# Link:  https://www.programmableweb.com/api/watchmouse
# -----
# Api Name:   CareerBuilder API
# Description:   Currently a private API, the CareerBuilder API allows you to integrate their database of over 1.5 million jobs with your software or website. The API provides methods for basic job searching,...
# Category:  Jobs
# Link:  https://www.programmableweb.com/api/careerbuilder
# -----
# Api Name:   Janrain Engage API
# Description:   Janrain Engage (formerly RPX) is a service that allows customers to add social networking logins to their websites and applications, using a single login for their website.
# The Janrain Engage API...
# Category:  Security
# Link:  https://www.programmableweb.com/api/janrain-engage
# -----
# Api Name:   Twitter Search API
# Description:   Twitter search API with optional restriction on language, from, to, and hashtags. Use it to find tweets, people and trends. Note that Summize was acquired by Twitter and is now their official search...
# Category:  Search
# Link:  https://www.programmableweb.com/api/twitter-search
# -----
# Api Name:   Bebo API
# Description:   From their site: Allows users to share photos with music, and blogs, and draw on members White Boards.
# Category:  Social
# Link:  https://www.programmableweb.com/api/bebo
# -----
# Api Name:   Veoh API
# Description:   Veoh has both Veoh.com and VeohTV. Veoh.com is for video hosting, aggregating, and sharing (700,000+ uploaders, independent producers, major networks). VeohTV is an app where you play videos or...
# Category:  Video
# Link:  https://www.programmableweb.com/api/veoh
# -----
# Api Name:   Fotolia API
# Description:   Fotolia has created an open Application Programming Interface (API). This API has made it possible for creative people to earn more money through affiliation (Partner API), to integrate Fotolia to...
# Category:  Photos
# Link:  https://www.programmableweb.com/api/fotolia
# -----
# Api Name:   geocoder.ca API
# Description:   We strive to provide the most reliable and accurate geocoding services for Canada and the USA. Using our xml port you can integrate geocoding functionalities into your application in real time. We...
# Category:  Mapping
# Link:  https://www.programmableweb.com/api/geocoderca
# -----
# Api Name:   SecondLife API
# Description:   From their site: Second Life is a 3-D virtual world entirely built and owned by its residents. Since opening to the public in 2003, it has grown explosively and today is inhabited by nearly 100,000...
# Category:  Games
# Link:  https://www.programmableweb.com/api/secondlife
# -----
# Api Name:   Page2Images API
# Description:   Page2Images is a website thumbnail creater optimized for mobile devices. Page2Images exposes its service through a REST API. The API allows websites and applications to generate thumbnails of a given...
# Category:  Screenshots
# Link:  https://www.programmableweb.com/api/page2images
# -----
# Api Name:   Zapier API
# Description:   Zapier is an application that integrates applications together. Users can choose triggers that automatically push data and content from one application to another.
# With Zapier, developers and users...
# Category:  Tools
# Link:  https://www.programmableweb.com/api/zapier
# -----
# Api Name:   ESPN API
# Description:   ESPN.com is an online platform for multiple sports news, statistics, team information, and player information. ESPN.com offers sports scores, standings, and other statistics for a variety of sports...
# Category:  Sports
# Link:  https://www.programmableweb.com/api/espn
# -----
# Api Name:   Edmunds.com Vehicle API
# Description:   Edmunds has been a publisher of new and used automotive pricing guides to assist automobile buyers since 1966. In addition to pricing information, Edmunds.com includes car reviews; vehicle...
# Category:  Reference
# Link:  https://www.programmableweb.com/api/edmundscom-vehicle
# -----
# Api Name:   eBay Shopping API
# Description:   The eBay Shopping API allows developers can programmatically interact with the eBay website. eBay Shopping Web Services lets developers query eBay for information, and receive data in XML, JSON, or...
# Category:  eCommerce
# Link:  https://www.programmableweb.com/api/ebay-shopping
# -----
# Api Name:   Thrutu API
# Description:   Thrutu is an application that lets users access real-time features while making calls on their Android phones. These features can be used to share information and media while on a call. The Thrutu...
# Category:  Telephony
# Link:  https://www.programmableweb.com/api/thrutu
# -----
# Api Name:   Genability API
# Description:   Genability provides tools to gain insight into electricity usage. The Genability API is a RESTful interface to detailed, accurate and up-to-date tariff and energy pricing data. Search by zipcode and...
# Category:  Reference
# Link:  https://www.programmableweb.com/api/genability
# -----
# Api Name:   Aviary Effects API
# Description:   Separate from its flagship Aviary API, an embedded photo editor, this API provides filters and effects. Developers can automatically fix red-eye and color adjust photos. Create watermarks so that all...
# Category:  Photos
# Link:  https://www.programmableweb.com/api/aviary-effects
# -----
# Api Name:   Instagram Real-time API
# Description:   Instagram Real-time API provides access to Instagram photos as they're added. Subscribe to users, tags, locations or geographies and receive notice when there are new photos. The real-time API uses...
# Category:  Photos
# Link:  https://www.programmableweb.com/api/instagram-real-time
# -----
# Api Name:   Active.com API
# Description:   The Active.com API provides read-only access to data produced by systems within The Active Network. This includes things like running events, tennis tournaments, triathlons, high school sports...
# Category:  Sports
# Link:  https://www.programmableweb.com/api/activecom
# -----
# Api Name:   Authorize.Net API
# Description:   Authorize.Net provides IP based payment gateway services. The Authorize.Net API enables developers to integrate digital payments into applications. It is optimized for mobile, provides PCI compliance...
# Category:  Payments
# Link:  https://www.programmableweb.com/api/authorizenet
# -----
# Api Name:   RapLeaf API
# Description:   The personalization API provides a simple interface to rich data about consumers. Developers use the data provided by the API to create more personalized experiences for consumers.
# Query with an...
# Category:  Email
# Link:  https://www.programmableweb.com/api/rapleaf
# -----
# Api Name:   Alexa Top Sites API
# Description:   From their site: The Alexa Top Sites web service provides access to lists of web sites ordered by Alexa Traffic Rank. Using the web service developers can understand traffic rankings from the largest...
# Category:  SEO
# Link:  https://www.programmableweb.com/api/alexa-top-sites
# -----
# Api Name:   Nestoria API
# Description:   Nestoria is a vertical search engine for property in the UK and Spain. The site offers an API to their database of geocoded properties.
# Category:  Real Estate
# Link:  https://www.programmableweb.com/api/nestoria
# -----
# Api Name:   Microsoft MapPoint API
# Description:   Note that this is a commercial, fee-based service but that 45 trial accounts are available.
# Category:  Mapping
# Link:  https://www.programmableweb.com/api/microsoft-mappoint
# -----
# Api Name:   43Things API
# Description:   43 Things is a social networking web site that is built on the principles of tagging, rather than links. Users create accounts and then list a number of goals or hopes; these goals are connected to...
# Category:  Goals
# Link:  https://www.programmableweb.com/api/43things
# -----
# Api Name:   Ning API
# Description:   Ning is a platform for creating social networks. The Ning REST API integrates with any Ning Pro account to import, export, and share data from apps running on Ning across the web or onto your desktop...
# Category:  Social
# Link:  https://www.programmableweb.com/api/ning
# -----
# Api Name:   Factual v3 API
# Description:   Factual is an open data platform for application developers that leverages large-scale data aggregation and community exchange. Our focus is on making data more accessible (i.e. cheaper, higher...
# Category:  Database
# Link:  https://www.programmableweb.com/api/factual-v3
# -----
# Api Name:   SEOmoz API
# Description:   SEOmoz provides companies around the world with consulting, Internet marketing and search engine optimization services. Our goal is to provide a high level of service and education to businesses,...
# Category:  Search
# Link:  https://www.programmableweb.com/api/seomoz
# -----
# Api Name:   Rezgo API
# Description:   Rezgo is tour operator software designed for companies who run tours, activities, and attractions. Many of the companies using Rezgo for their on-line bookings include: whale watching tours, river...
# Category:  Travel
# Link:  https://www.programmableweb.com/api/rezgo
# -----
# Api Name:   Yahoo Placemaker API
# Description:   Yahoo Placemaker is a new "geo-enrichment" platform. The freely-available API enables developers and publishers to make applications and data sets location-aware by determining the "whereness" of...
# Category:  Mapping
# Link:  https://www.programmableweb.com/api/yahoo-placemaker
# -----
# Api Name:   Maponics API
# Description:   A professional-grade GIS data provider offering neighborhood boundaries dataset via an API. Also an API for neighborhood boundaries, ZIP Code boundaries and postal carrier route boundaries.
# Category:  Mapping
# Link:  https://www.programmableweb.com/api/maponics
# -----
# Api Name:   TripIt API
# Description:   The TripIt API allows users to access the TripIt's information about travel and itineraries. TripIt facilitates integration and organization of travel information from many different sources. The...
# Category:  Travel
# Link:  https://www.programmableweb.com/api/tripit
# -----
# Api Name:   Shizzow API
# Description:   The Shizzow API lets you announce your location to your friends. You can add and remove friends, add and remove locations, post arrival and departure times and more.
# Category:  Social
# Link:  https://www.programmableweb.com/api/shizzow
# -----
# Api Name:   ConstantContact API
# Description:   Integrate your software with Email Marketing from Constant Contact. Our API allows you to seamlessly integrate our industry-leading Email Marketing service. Today more than 300,000 small businesses...
# Category:  Email
# Link:  https://www.programmableweb.com/api/constantcontact
# -----
# Api Name:   Hyves API
# Description:   Use the Hyves API to get blog posts, get Hyves' user albums, view friends, view invitations, create gadgets, get user blog posts, get blog comments, create blog posts, get tips, get user information...
# Category:  Social
# Link:  https://www.programmableweb.com/api/hyves
# -----
# Api Name:   LongURL API
# Description:   Use the LongURL API to expand shortened URLs from TinyURL, etc. Submit a shortened URL and then get its long equivalent returned. You can also use the API to get a list of known shortening services...
# Category:
# Link:  https://www.programmableweb.com/api/longurl
# -----
# Api Name:   Social Actions API
# Description:   Use the Social Actions Open API to search the SocialActions.com database of volunteer and philanthropy opportunities, called social actions, useful for those interested in peer-to-peer social change...
# Category:  Other
# Link:  https://www.programmableweb.com/api/social-actions
# -----
# Api Name:   Blip.fm API
# Description:   Use the Blip.fm API to access Blip.fm users and their data. Get a Blip by user ID, or for multiple user IDs. Get the most recent Blips for a user, sequentially listed by most recent. Create your...
# Category:  Music
# Link:  https://www.programmableweb.com/api/blipfm
# -----
# Api Name:   NPR One Station Finder API
# Description:   The NPR API provides an open and extensive way for users to share and mash-up the radio station's content. The Station Finder API can be used to identify local NPR member stations based on zip code...
# Category:  News Services
# Link:  https://www.programmableweb.com/api/npr-one-station-finder
# -----
# Api Name:   Yahoo Internet Location Platform API
# Description:   From their site: a resource for managing all geo-permanent named places on Earth. Our purpose in creating the Internet Location Platform is to provide the Yahoo! Geographic Developer Community with...
# Category:  Mapping
# Link:  https://www.programmableweb.com/api/yahoo-internet-location-platform
# -----
# Api Name:   Scribd Platform API
# Description:   From their site: A REST-based API with methods for uploading, converting, editing, deleting, and searching documents. Using the API, you can use Scribd as a back-end for an application that needs to...
# Category:  Office
# Link:  https://www.programmableweb.com/api/scribd-platform
# -----
# Api Name:   Amazon Fulfillment Web Service API
# Description:   Amazon Fulfillment Web Service (Amazon FWS) allows merchants to access Amazon.com's world-class fulfillment capabilities through a simple web services interface. Merchants can programmatically send...
# Category:  eCommerce
# Link:  https://www.programmableweb.com/api/amazon-fulfillment-web-service
# -----
# Api Name:   Google Book Search Book Viewability API
# Description:   The Google Book Search Book Viewability API enables developers to: Link to Books in Google Book Search using ISBNs, LCCNs, and OCLC numbers; Know whether Google Book Search has a specific title and...
# Category:  Search
# Link:  https://www.programmableweb.com/api/google-book-search-book-viewability
# -----
# Api Name:   Widgetbox API
# Description:   Our mission is to help people make and get widgets and apps for their social network profile, blog, or start page. Through our AppAccelerator, developers can easily convert their web widgets into...
# Category:  Widgets
# Link:  https://www.programmableweb.com/api/widgetbox
# -----
# Api Name:   Google Web Authentication API
# Description:   From their site: Google Accounts authentication for web-based applications allows the application to access a Google service protected by a user's Google account. To maintain a high level of security...
# Category:  Security
# Link:  https://www.programmableweb.com/api/google-web-authentication
# -----
# Api Name:   WebThumb API
# Description:   From their site: Web Page Thumbnails with API support.
# Category:
# Link:  https://www.programmableweb.com/api/webthumb
# -----
# Api Name:   FreshBooks API
# Description:   The FreshBooks API is an interface for accessing FreshBooks data using JSON. The API can be used to create web and desktop applications that integrate with an account. API methods are available to...
# Category:  Financial
# Link:  https://www.programmableweb.com/api/freshbooks
# -----
# Api Name:   30 Boxes API
# Description:   30 Boxes is a calendaring service that allows you to organize your life, then share it with friends. You can also keep track of friends' calendars. 30 Boxes interfaces with Flickr, Livejournal,...
# Category:  Calendars
# Link:  https://www.programmableweb.com/api/30-boxes
# -----
# Api Name:   Bloglines API
# Description:   From their site: Bloglines is a FREE online service for searching, subscribing, creating and sharing news feeds, blogs and rich web content. With Bloglines, there is no software to download or...
# Category:  Feeds
# Link:  https://www.programmableweb.com/api/bloglines
# -----
# Api Name:   US Stocks Fundamentals API
# Description:   The US Stocks Fundamentals API offers access to stock data based on the U.S. Securities and Exchange Commission. Over 12,000 companies are supported with over 8,000 indicators. Developers need to...
# Category:  Stocks
# Link:  https://www.programmableweb.com/api/us-stocks-fundamentals
# -----
# Api Name:   Food API
# Description:   The Food and Recipe API is spoonacular's Food, Recipe, Menu, Restaurant and Nutrition API which allows users to access over 360,000 recipes and 80,000 food products. The API has a food ontology that...
# Category:  Food
# Link:  https://www.programmableweb.com/api/food
# -----
# Api Name:   Travel Portal API
# Description:   The Travel Portal API provides programmatic access to functions that allow customers to book hotels, flights, cars, and tours from the developer's websites. Travel Portal allows users to make...
# Category:  Travel
# Link:  https://www.programmableweb.com/api/travel-portal
# -----
# Api Name:   Dansk Supermarked API
# Description:   The Salling Group API, a Danish Retailer in Denmark, Sweden, Poland and Germany provides a Web API that serves geocoded store information incl. opening hours for Netto, Bilka and føtex retail stores...
# Category:  API
# Link:  https://www.programmableweb.com/api/dansk-supermarked
# -----
# Api Name:   WooCommerce API
# Description:   WooCommerce is a WordPress eCommerce plugin, with different features built for website development. The WooCommerce API lets developers integrate its features into their WordPress website. Data is in...
# Category:  eCommerce
# Link:  https://www.programmableweb.com/api/woocommerce
# -----
# Api Name:   Uber API
# Description:   Using the Uber API, developers can integrate the power of Uber into 3rd party applications. Calls to the API can be made to request information on available car types, driver location expressed in...
# Category:  Transportation
# Link:  https://www.programmableweb.com/api/uber
# -----
# Api Name:   Google Play Developer API
# Description:   The Google Play Developer API allows developers the opportunity to automate tasks concerning subscriptions, in-app purchasing, and general app-management. One may gain access to the API by signing...
# Category:  Purchasing
# Link:  https://www.programmableweb.com/api/google-play-developer
# -----
# Api Name:   Developer Garden IP Location API
# Description:   The IP Location API by Developer Garden allows developers to retrieve geographic information on where a user comes from, allowing the content of a website or application to be adjusted to the unique...
# Category:  Localization
# Link:  https://www.programmableweb.com/api/developer-garden-ip-location
# -----
# Api Name:   Jawbone UP API
# Description:   Jawbone develops human-centered wearable technology and audio devices. Jawboneâ€™s flagship product is Jambox, a wireless speaker and speakerphone. Jawboneâ€™s UP is a wristband and app that tracks...
# Category:  Tools
# Link:  https://www.programmableweb.com/api/jawbone
# -----
# Api Name:   SEMrush API
# Description:   SEMrush creates software products for search and marketing professionals. Features include keywords research, SEO metric comparison, advertising research, and comparison of competitorsâ€™ organic...
# Category:  Search
# Link:  https://www.programmableweb.com/api/semrush
# -----
# Api Name:   Strava API
# Description:   Strava is a social fitness service that allows users to share, compare and compete with other users' personal fitness data via mobile and online apps. Focusing on cyclists and runners, Strava lets...
# Category:  Social
# Link:  https://www.programmableweb.com/api/strava
# -----
# Api Name:   Walgreens QuickPrints API
# Description:   QuickPrints allows mobile application developers to include the ability for their app users to print photos to any of the 8,000+ Walgreens locations.
# With every photo order that is successfully...
# Category:  Photos
# Link:  https://www.programmableweb.com/api/walgreens-quickprints
# -----
# Api Name:   Plivo API
# Description:   Plivo is a telephony platform for integration with other apps. It is built to be integrative and take desired call making and receiving functions off of developersâ€™ hands. It provides capacity for...
# Category:  Telephony
# Link:  https://www.programmableweb.com/api/plivo
# -----
# Api Name:   Mandrill API
# Description:   Mandrill is an email application and email template service hosted by MailChimp. The Mandrill API allows developers to access and integrate the functionality of Mandrill with other applications and...
# Category:  Email
# Link:  https://www.programmableweb.com/api/mandrill
# -----
# Api Name:   Spy Dialer API
# Description:   Spy Dialer lets users identify missed calls and mystery numbers by going directly to any U.S. based cell phone's outgoing voicemail to hear whose cell phone it is. With the Spy Dialer API, users can...
# Category:  Telephony
# Link:  https://www.programmableweb.com/api/spy-dialer
# -----
# Api Name:   Bing Maps Search API
# Description:   Bing Maps Search Service allows users to parse a mapping related search queries as well as return search results. Search filters include property name and ID, minimum and maximum values,...
# Category:  Mapping
# Link:  https://www.programmableweb.com/api/bing-maps-search
# -----
# Api Name:   Mt Gox API
# Description:   Mt Gox allows users to trade US Dollars for Bitcoins and vice versa. The Mt Gox API allows users to fetch public data and place orders. It uses RESTful calls and responses are formatted in JSON.
# Category:  Financial
# Link:  https://www.programmableweb.com/api/mt-gox
# -----
# Api Name:   Google Distance Matrix API
# Description:   The Google Distance Matrix API is a service that provides travel distance and time for a matrix of origins and destinations. The information returned is based on the recommended route between start...
# Category:  Mapping
# Link:  https://www.programmableweb.com/api/google-distance-matrix
# -----
# Api Name:   Instapaper API
# Description:   The Instapaper API allows third-party applications to add URLs to Instapaper. Instapaper is a service that lets users save long web pages to read at a later time. The API has a single method. It uses...
# Category:  Bookmarks
# Link:  https://www.programmableweb.com/api/instapaper
# -----
# Api Name:   iFixit API
# Description:   The iFixit API provides programmatic access to iFixit enabling anyone to write applications and utilities on top of the repair database. iFixit is the world's largest collection of free photographic...
# Category:  Reference
# Link:  https://www.programmableweb.com/api/ifixit
# -----
# Api Name:   PeerIndex API
# Description:   PeerIndex is a social media analytics company that is building the Influence Graph: who influences whom in which topics across the social platforms. The PeerIndex API provides programmatic access to...
# Category:  Social
# Link:  https://www.programmableweb.com/api/peerindex
# -----
# Api Name:   Topsy API
# Description:   As the only Twitter partner certified as both a data reseller and an analytics provider, Topsy APIs give you access to any and all social conversations, in their entirety or summarizedâ€”whether...
# Category:  Social
# Link:  https://www.programmableweb.com/api/topsy
# -----
# Api Name:   Bandcamp API
# Description:   Bandcamp is a music discovery website and marketplace where artists can provide tracks to stream or download and earn money from music sales.
# The Bandcamp features a RESTful interface and returns...
# Category:  Music
# Link:  https://www.programmableweb.com/api/bandcamp
# -----
# Api Name:   eBay Product Services API
# Description:   Parts Compatibility is an eBay feature that uses structured data to associate compatible assemblies with parts listed on eBay. It is meant to improve search relevancy allow item titles and...
# Category:  eCommerce
# Link:  https://www.programmableweb.com/api/ebay-product-services
# -----
# Api Name:   AMEE API
# Description:   AMEE is a platform for greenhouse gas calculation, with access to emissions factors, calculation algorithms, and storage for data history. Our science team take the published methodologies from the...
# Category:  Science
# Link:  https://www.programmableweb.com/api/amee
# -----
# Api Name:   Ipernity API
# Description:   The ipernity API allows creating applications that can do whatever you see on the ipernity website and even more. For example: import new documents, tag a photo, create an album, search in your...
# Category:  Media
# Link:  https://www.programmableweb.com/api/ipernity
# -----
# Api Name:   Coinkite API
# Description:   Coinkite is a bitcoin service that provides an exchange and bank for bitcoin and other crypto-currency use. Coinkite also both online banking and a debit card with which to transact in bitcoins...
# Category:  Financial
# Link:  https://www.programmableweb.com/api/coinkite
# -----
# Api Name:   MYOB AccountRight Live API
# Description:   MYOB AccountRight Live is an accounting application for businesses in Australia. MYOB AccountRight Live offers a variety of accounting and bookkeeping features.
# The MYOB AccountRight Live API...
# Category:  Financial
# Link:  https://www.programmableweb.com/api/myob-accountright-live
# -----
# Api Name:   Images API
# Description:   Images API is a service from Graphics Factory Clip Art allowing users to integrate royalty free clip art images into websites, applications, or print-on-demand services. The Images API supports XML...
# Category:  Photos
# Link:  https://www.programmableweb.com/api/images
# -----
# Api Name:   Daybreak Game Company Census API
# Description:   Daybreak Games (DGC) is a leader in massively multiplayer online games. Some of it's most popular titles include EverQuest, EverQuest II, PlanetSide 2, Planetside 2, H1Z1, Landmark, and DC Universe...
# Category:  Games
# Link:  https://www.programmableweb.com/api/daybreak-game-company-census
# -----
# Api Name:   SERPs SEO & Rankings API
# Description:   SERPs.com is an SEO dashboard that lets users easily identify what's working and what isn't. It lets users do correlation testing by automatically logging their rankings and traffic after any event....
# Category:  SEO
# Link:  https://www.programmableweb.com/api/serps-seo-rankings
# -----
# Api Name:   Coinbase API
# Description:   Coinbase is an electronic service and "wallet" for bitcoins and digital currency. Users can transfer currency, pay merchants, and make other payments instantly.
# The Coinbase API allows developers...
# Category:  Financial
# Link:  https://www.programmableweb.com/api/coinbase
# -----
# Api Name:   Pushover Message API
# Description:   Pushover Message is a service for sending real-time notifications to Android and iOS devices. A simple REST API allows users to send messages to Pushover from their applications. Those messages are...
# Category:  Messaging
# Link:  https://www.programmableweb.com/api/pushover-message
# -----
# Api Name:   ImpossibleFX API
# Description:   The ImpossibleFX API allows developers to create dynamic movie templates from scratch or to script and extend existing movie templates created with the ImpossibleFX Editor. This API is RESTful and...
# Category:  Video
# Link:  https://www.programmableweb.com/api/impossiblefx
# -----
# Api Name:   Analytics SEO API
# Description:   Analytics SEO is an online suite of SaaS based SEO tools that allow users to optimize multiple SEO campaigns. The API provides access to core site auditing functionality, ongoing site monitoring and...
# Category:  Search
# Link:  https://www.programmableweb.com/api/analytics-seo
# -----
# Api Name:   Readmill API
# Description:   Readmill is an online and mobile platform for readers to share information about what eBooks they are reading, allowing them to highlight and discuss sections of eBooks with other users.
# The...
# Category:  Social
# Link:  https://www.programmableweb.com/api/readmill
# -----
# Api Name:   LyricFind API
# Description:   LyricFind provides a legal music lyrics service. LyricFind has licensing from over 2,000 music publishers, including the four majors EMI Music Publishing, Universal Music Publishing Group, Warner/...
# Category:  Music
# Link:  https://www.programmableweb.com/api/lyricfind
# -----
# Api Name:   Trello API
# Description:   Trello is an online project management and collaboration platform. Users can manage their projects on Trello boards that display the various aspects of their projects, such as what has been done and...
# Category:  Project Management
# Link:  https://www.programmableweb.com/api/trello
# -----
# Api Name:   Blekko API
# Description:   blekko is a search engine that sorts out spam, content farms and malware by crawling a subset of about 3 billion pages. To improve search results, blekko uses a tool called a slashtag that organizes...
# Category:  Search
# Link:  https://www.programmableweb.com/api/blekko
# -----
# Api Name:   BreweryDB API
# Description:   BreweryDB is a fully moderated, open library of breweries and beers from all around the world. The library is updated by our users. For breweries, we keep track of information such as location,...
# Category:  Reference
# Link:  https://www.programmableweb.com/api/brewerydb
# -----
# Api Name:   Readability API
# Description:   Readability is a subscription service that lets users bookmark articles/webpages and read them later in a comfortable reading view. Readability also supports the writers and publishers of content/...
# Category:  Bookmarks
# Link:  https://www.programmableweb.com/api/readability
# -----
# Api Name:   QuickBooks Payments API
# Description:   QuickBooks Payments API lets developers use eCommerce websites or online processing for customer sites, process credit card payments. It can also be used for QuickBooks Online to record transactions...
# Category:  Payments
# Link:  https://www.programmableweb.com/api/quickbooks-payments
# -----
# Api Name:   Pocket API
# Description:   Previously offered under the name Read It Later, Pocket is a service that allows users to save articles, videos and more to read or use later. The Pocket API allows for applications that interact...
# Category:  Bookmarks
# Link:  https://www.programmableweb.com/api/pocket
# -----
# Api Name:   Layar API
# Description:   Layar is augmented reality application on your mobile phone which shows what is around you by displaying real time digital information on top of reality though the camera of your mobile phone....
# Category:  Other
# Link:  https://www.programmableweb.com/api/layar
# -----
# Api Name:   Amazon CloudWatch API
# Description:   Amazon CloudWatch is a web service that provides visibility into your cloud assets. Amazon CloudWatch provides the data you need to make informed decisions. It is designed to provide comprehensive...
# Category:  Platform-as-a-Service
# Link:  https://www.programmableweb.com/api/amazon-cloudwatch
# -----
# Api Name:   Wolfram Alpha API
# Description:   Wolfram|Alpha is a "computational knowledge engine" whose long-term goal is "to make all systematic knowledge immediately computable and accessible to everyone. We aim to collect and curate all...
# Category:  Reference
# Link:  https://www.programmableweb.com/api/wolfram-alpha
# -----
# Api Name:   Sensebot API
# Description:   Sensebot Semantic Cloud API features extraction of semantic concepts from a page; creating ï¿½semantic cloudï¿½ of concepts describing a group of documents; generating a multi-document summary of a...
# Category:  Search
# Link:  https://www.programmableweb.com/api/sensebot
# -----
# Api Name:   Norway Weather API
# Description:   met.no is the joint online weather service from the Norwegian Meteorological Institute (met.no) and the Norwegian Broadcasting Corporation (NRK). met.no offers weather forecasts in English for more...
# Category:  Weather
# Link:  https://www.programmableweb.com/api/norway-weather
# -----
# Api Name:   Microsoft Translator API
# Description:   The Microsoft Translator API is a cloud based machine translation service. It lets users translate text, pictures, websites, documents and full conversations in over 60 languages within their...
# Category:  Translation
# Link:  https://www.programmableweb.com/api/microsoft-translator
# -----
# Api Name:   Ergast API
# Description:   The Ergast Motor Racing Data API provides a historical record of motor racing data for non-commercial purposes. The API provides data for the Formula 1 and Formula E series, from the start of the...
# Category:  Sports
# Link:  https://www.programmableweb.com/api/ergast
# -----
# Api Name:   ShopStyle API
# Description:   The ShopStyle API allows client applications to retrieve the underlying data for all the basic elements of the ShopStyle website, including products, brands, retailers, and categories.
# For ease...
# Category:  eCommerce
# Link:  https://www.programmableweb.com/api/shopstyle
# -----
# Api Name:   PostalMethods API
# Description:   PostalMethods provides a postal gateway service (SaaS) for sending letters and postcards. Use our flexible and well documented SOAP interface to send mail directly from your business applications....
# Category:  Messaging
# Link:  https://www.programmableweb.com/api/postalmethods
# -----
# Api Name:   Scribd iPaper API
# Description:   From their site: The iPaper Javascript API allows you to control how your documents are displayed when embedded in your webpage. Similar to the Google Maps API, it is a simple set of Javascript...
# Category:  Office
# Link:  https://www.programmableweb.com/api/scribd-ipaper
# -----
# Api Name:   Geograph API
# Description:   The Geograph England and Ireland project was established to create geographically representative images and data of every square kilometer of the two countries. The Geograph API makes it easier for...
# Category:  Geography
# Link:  https://www.programmableweb.com/api/geograph
# -----
# Api Name:   SimpleAPI API
# Description:   Japanese web service for creating web site thumbnail images.
# Category:  Photos
# Link:  https://www.programmableweb.com/api/simpleapi
# -----
# Api Name:   LibraryThing API
# Description:   From their site: Three APIs available: (1) thingISBN takes an ISBN and returns a list of ISBNs from the same "work" (ie., other editions and translations); (2) thingTitle takes a title and returns a...
# Category:  Reference
# Link:  https://www.programmableweb.com/api/librarything
# -----
# Api Name:   Seesmic API
# Description:   Public API is in beta now. Use the API to view who a user follows, view their list of videos, get videos for a timeline, and more.
# Category:  Video
# Link:  https://www.programmableweb.com/api/seesmic
# -----
# Api Name:   Snipshot API
# Description:   Snipshot Services is the way for outside sites to hook into Snipshot. As a site developer, you can use Services to give your users the power to edit their pictures online with Snipshot.
# Category:  Photos
# Link:  https://www.programmableweb.com/api/snipshot
# -----
# Api Name:   Windows Sidebar Gadgets API
# Description:   For Windows Vista sidebar.
# Category:  Widgets
# Link:  https://www.programmableweb.com/api/windows-sidebar-gadgets
# -----
# Api Name:   PhishTank API
# Description:   From their site: PhishTank is a free community site where anyone can submit, verify, track and share phishing data.
# Category:  Security
# Link:  https://www.programmableweb.com/api/phishtank
# -----
# Api Name:   Blinksale API
# Description:   Blinksale is a web application that allows professionals and small businesses to send invoices on the Web. Users can create invoices from a template or choose to customize the design. The API allows...
# Category:  Financial
# Link:  https://www.programmableweb.com/api/blinksale
# -----
# Api Name:   Yahoo BBauth API
# Description:   From their site: You build great web applications. We have millions of users who store their data on Yahoo!. Browser-Based Authentication (BBAuth) makes it possible for your applications to use that...
# Category:  Security
# Link:  https://www.programmableweb.com/api/yahoo-bbauth
# -----
# Api Name:   Microsoft adCenter API
# Description:   From their site: The Microsoft adCenter application programming interface (API) enables you to create applications that: Create and manage adCenter campaigns, orders, keywords, and ads. Obtain the...
# Category:  Advertising
# Link:  https://www.programmableweb.com/api/microsoft-adcenter
# -----
# Api Name:   Akismet API
# Description:   From their site: Akismet is basically a big machine that sucks up all the data it possibly can, looks for patterns, and learns from its mistakes. Thus far it has been highly effective at stopping...
# Category:  Blogging
# Link:  https://www.programmableweb.com/api/akismet
# -----
# Api Name:   Skyhook Precision Location API
# Description:   The Skyhook Precision Location API allows tracking applications and location-based services to track phones and devices. Location information is derived from the analysis of positioning anchors such...
# Category:  Location
# Link:  https://www.programmableweb.com/api/skyhook-precision-location
# -----
# Api Name:   EditGrid API
# Description:   From their site: EditGrid is an online spreadsheet service with real-time-update and extensive collaboration features.
# EditGrid offers two APIs. The Web API is used for controlling and manipulating...
# Category:  Office
# Link:  https://www.programmableweb.com/api/editgrid
# -----
# Api Name:   Weblogs API
# Description:   From their site: The Weblogs.com ping service is used to automatically inform VeriSign whenever you update content on your site. The service receives notification (a "ping") from your site that you...
# Category:  Blogging
# Link:  https://www.programmableweb.com/api/weblogs
# -----
# Api Name:   ISBN db API
# Description:   From their site: ISBNdb.com's remote access application programming interface (API) is designed to allow other websites and standalone applications use the vast collection of data collected by ISBNdb...
# Category:  Reference
# Link:  https://www.programmableweb.com/api/isbn-db
# -----
# Api Name:   SplogSpot API
# Description:   From their site: The SplogSpot API enables you to integrate the power of SplogSpot database into your custom application. It provides a simple interface that you can query, results being returned in...
# Category:  Search
# Link:  https://www.programmableweb.com/api/splogspot
# -----
# Api Name:   Syndic8 API
# Description:   Syndic8 aggregates RSS and atom news feeds on a variety of topics. Syndic8 supports feed tagging to help users find blogs similar to those they are already subscribed to.
# Category:  Feeds
# Link:  https://www.programmableweb.com/api/syndic8
# -----
# Api Name:   Digital Podcast API
# Description:   The Digital Podcast Search Service allows you to access Digital Podcast's content and services in your favorite programming languages. This means you can now build Digital Podcast directly into your...
# Category:  Music
# Link:  https://www.programmableweb.com/api/digital-podcast
# -----
# Api Name:   ESV Bible Lookup API
# Description:   From their site: The English Standard Version (ESV) Bible is a new, essentially literal Bible translation that combines word-for-word precision and accuracy with literary excellence, beauty, and...
# Category:  Reference
# Link:  https://www.programmableweb.com/api/esv-bible-lookup
# -----
# Api Name:   Western Union Mass Payments API
# Description:   This Western Union API is a REST based service with a JSON structured payload for the Mass Payments product that enables you with the ability to process up to 10,000 payments in a single file upload...
# Category:  Payments
# Link:  https://www.programmableweb.com/api/western-union-mass-payments
# -----
# Api Name:   ECommPay Gate API
# Description:   The ECommPay Gate API enables merchants to perform all types of payments and operations and retrieve additional information including customer data, refunds, and providers. The API features REST...
# Category:  Payments
# Link:  https://www.programmableweb.com/api/ecommpay-gate
# -----
# Api Name:   WhatsApp Business API
# Description:   The WhatsApp Business API provides a way for businesses to interact with and reach customers all over the world. It powers communication with customers to connect with them on WhatsApp using end-to-...
# Category:  Business
# Link:  https://www.programmableweb.com/api/whatsapp-business
# -----
# Api Name:   WinSMS API
# Description:   The WinSMS API provides tools for developers that allow the capability to easily integrate SMS messaging into existing database applications, custom software and web sites. This WinSMS API is useful...
# Category:  Messaging
# Link:  https://www.programmableweb.com/api/winsms
# -----
# Api Name:   SMS API
# Description:   The SMS API aims to provide a SMS communication to existing applications. This REST interface uses the SMPP protocol to send messages between entities. SMSAPI offers bulk services, email SMS, 5...
# Category:  Messaging
# Link:  https://www.programmableweb.com/api/sms
# -----
# Api Name:   Sportradar API
# Description:   The Sportradar API allows developers to integrate their applications with the Sportradar service, using RESTful methods. Sportradar is a provider of sports data and content for over 40 different...
# Category:  Sports
# Link:  https://www.programmableweb.com/api/sportradar
# -----
# Api Name:   Pinterest API
# Description:   This API is RESTful, and it allows developers to use the Pinterest Pin features by integrating the API into their applications. API Methods are available for users, boards, pins, and sections....
# Category:  Images
# Link:  https://www.programmableweb.com/api/pinterest
# -----
# Api Name:   Chartie API
# Description:   Chartie is a free web API that mines the relevant trend patterns from your signal.
# Thanks to our technololgy, Chartie's output identifies the relevant trend in the input data.
# Chartie employs...
# Category:  Analytics
# Link:  https://www.programmableweb.com/api/chartie
# -----
# Api Name:   Information Machine API
# Description:   Our API can automatically...
# Category:  eCommerce
# Link:  https://www.programmableweb.com/api/information-machine
# -----
# Api Name:   Facebook Business Mapping API
# Description:   The Business Mapping API by Facebook is useful for businesses that are operating several Facebook Apps and require the user ID to be the same between them. This is a common procedure for games...
# Category:  Social
# Link:  https://www.programmableweb.com/api/facebook-business-mapping
# -----
# Api Name:   Mozscape API
# Description:   Moz is an analytics software for search, links, and brand. Moz has a large index of URLs from around the web that might be of benefit to marketers. With the Mozscape API, developers will be able to...
# Category:  Marketing
# Link:  https://www.programmableweb.com/api/mozscape
# -----
# Api Name:   Walgreens Balance Rewards API
# Description:   The Balance® Rewards API enables pre-qualified partners to connect into Walgreens to share individual member health and wellness information to be eligible to receive Balance Rewards points for...
# Category:  Health
# Link:  https://www.programmableweb.com/api/walgreens-balance-rewards
# -----
# Api Name:   Bittrex API
# ...
# Category:  DevOps
# Link:  https://www.programmableweb.com/api/vamp
# -----
# Api Name:   Giant Swarm API
# Description:   Giant Swarm provides a fully-managed Kubernetes cluster, which can be used to deploy containers as you see fit. With Giant Swarm, you have full admin rights to the cluster through its API, so you can...
# Category:  Platform-as-a-Service
# Link:  https://www.programmableweb.com/api/giant-swarm
# -----
# Api Name:   Salesforce Tooling SOAP API
# Description:   The Salesforce Tooling SOAP API is Tooling API objects with programmatic access to data and metadata. It is recommended for strongly typed languages that generate Web service client code. This...
# Category:  Platform-as-a-Service
# Link:  https://www.programmableweb.com/api/salesforce-tooling-soap
# -----
# Api Name:   Visa Funds Transfer Attributes Inquiry API
# Description:   The Visa Funds Transfer Attributes Inquiry API retrieves payment account data. The API sends requests and returns responses about transfers in JSON or XML format.
# Category:  Financial
# Link:  https://www.programmableweb.com/api/visa-funds-transfer-attributes-inquiry
# -----
# Api Name:   Salesforce Analytics API
# Description:   The Analytics REST API provides programmatic access to Analytics features like datasets, dashboards and lenses. It allows you to; Send queries, Access datasets, Create and retrieve Analytics lenses...
# Category:  Analytics
# Link:  https://www.programmableweb.com/api/salesforce-analytics
# -----
# Api Name:   Happykwik API
# Description:   The Happykwik mobile recharge API support covers a wider range of fields from operating system to the manipulation of raw data. It is a total solution for recharge business - Portal design,...
# Category:  Mobile
# Link:  https://www.programmableweb.com/api/happykwik
# -----
# Api Name:   Threadeo API
# Description:   The Threadeo API allows developers to access the Threadeo platform for video and audio transcription, translation, and search. This API provides methods for uploading video and audio recordings for...
# Category:  Transcription
# Link:  https://www.programmableweb.com/api/threadeo
# -----
# Api Name:   Smartcar API
# Description:   Smartcar enables developers to locate, unlock, and read mileage data from cars using an API. It lets mobile and web apps send HTTP requests to vehicles without the need for aftermarket hardware. The...
# Category:  Auto
# Link:  https://www.programmableweb.com/api/smartcar
# -----
# Api Name:   mTalkz SMS API
# Description:   The mTalkz SMS API allows developers to send bulk SMS to more than 225 countries. mTalkz operates over multiple channels and provides direct connectivity with nine telecommunication companies,...
# Category:  Messaging
# Link:  https://www.programmableweb.com/api/mtalkz-sms
# -----
# Api Name:   EdgeX Foundry API
# Description:   EdgeX Foundry provides an ecosystem for Internet of Things platforms based on open source configurations. The EdgeX Foundry API offers several endpoints for services including client registration,...
# Category:  Internet of Things
# Link:  https://www.programmableweb.com/api/edgex-foundry
# -----
# Api Name:   Visa Merchant Benchmark API
# Description:   The Visa Merchant Benchmark API processes credit, debit, and gift cards in JSON format, using base64 HTTP as the authentication method. With the API, developers can access Visa's data insights and...
# Category:  Credit Cards
# Link:  https://www.programmableweb.com/api/visa-merchant-benchmark
# -----
# Api Name:   Share Count API
# Description:   This is a Social Animal Share Count service that provides a way to retrieve counts of how many times a given URL was shared on popular social media sites. It retrieves share counts for the URLs...
# Category:  Social
# Link:  https://www.programmableweb.com/api/share-count
# -----
# Api Name:   Social Animal Content API
# Description:   This is a Social Animal content search service that provides a simple API for popular web content. Social Animal News API query filters help content marketers, data scientists and coders retrieve...
# Category:  Social
# Link:  https://www.programmableweb.com/api/social-animal-content
# -----
# Api Name:   Sentiance API
# Description:   The Sentiance REST API adds IoT sensor data to applications. The Sentiance API interprets data in real-time to determine user location, transport mode, and base-level activities. Sentiance predicts...
# Category:  Internet of Things
# Link:  https://www.programmableweb.com/api/sentiance
# -----
# Api Name:   Sentiance GraphQL API
# Description:   The Sentiance GraphQL API supports mutable queries related to user information, events, and segmentation. The Sentiance API interprets data in real-time to determine user location, transport mode,...
# Category:  Internet of Things
# Link:  https://www.programmableweb.com/api/sentiance-graphql
# -----
# Api Name:   e-Sathi API
# Description:   e-Sathi API allows users and developers to retrieve pieces of information from our social networking website via GET request and supports the various parameters. Current API implementation is limited...
# Category:  Social
# Link:  https://www.programmableweb.com/api/e-sathi
# -----
# Api Name:   Instana API
# Description:   The Instana API enables the retrieval of key data points used to monitor and analyze applications in real time. Instana is a REST interface that offers metrics, search fields, snapshots, and events...
# Category:  Monitoring
# Link:  https://www.programmableweb.com/api/instana
# -----
# Api Name:   Salesforce User Interface API
# Description:   This is access to build a Salesforce UI for native mobile applications and custom web apps. Build user interfaces that allow users to get metadata and data about objects and records, to work with...
# Category:  Mobile
# Link:  https://www.programmableweb.com/api/salesforce-user-interface
# -----
# Api Name:   OpenAI Gym API
# Description:   This API is a toolkit for developing and comparing your reinforcement learning agents. It is a local REST API to the gym open-source library. OpenAI is a non-profit AI research company that provides...
# Category:  Artificial Intelligence
# Link:  https://www.programmableweb.com/api/openai-gym
# -----
# Api Name:   Talkdesk Reports API
# Description:   The Talkdesk Reports API displays report type jobs data in JSON format. Developers can include name, status, timespan, from, to, files, and status. Talldesk provides enterprise cloud contact center...
# Category:  Customer Service
# Link:  https://www.programmableweb.com/api/talkdesk-reports
# -----
# Api Name:   Talkdesk Core API
# Description:   The Talkdesk Core API returns JSON data with accounts, apps, contacts, recordings, and users. cURL example available that displays a 200 OK response. Talldesk provides enterprise cloud contact center...
# Category:  Customer Service
# Link:  https://www.programmableweb.com/api/talkdesk-core
# -----
# Api Name:   MeteoGroup Point Observation API
# Description:   The MeteoGroup Point Observation API returns JSON formats with weather data including air temperature, air pressure, humidity, wind speed, cloud cover, precipitation, and wind direction. Developers...
# Category:  Weather
# Link:  https://www.programmableweb.com/api/meteogroup-point-observation
# -----
# Api Name:   ComEd Hour Average API
# Description:   The ComEd Hour Average API returns JSON, text, and RSS formats with the 5-minute average price for ComEd’s Hourly Pricing program. Requests and output examples available. The Commonwealth Edison...
# Category:  Energy
# Link:  https://www.programmableweb.com/api/comed-hour-average
# -----
# Api Name:   Idomoo API
# Description:   The Idomoo API returns JSON data related to video personalization features based on context. Developers require a basic HTTP authentication to access the API. Idomoo is a Personalized Video as a...
# Category:  Video
# Link:  https://www.programmableweb.com/api/idomoo
# -----
# Api Name:   Trusona API
# Description:   Trusona provides password-less two-factor authentication capabilities to unlock approved applications. Trusona uses the security measures already employed in mobile devices such as swipe patterns or...
# Category:  Security
# Link:  https://www.programmableweb.com/api/trusona
# -----
# Api Name:   Smite API
# Description:   The Smite API allows developers to access statistics and data associated with the Smite MOBA game including match details, player details, team information, and ranking. Data is available in JSON and...
# Category:  Games
# Link:  https://www.programmableweb.com/api/smite
# -----
# Api Name:   De Facto Enterprise API
# Description:   The De Facto Enterprise API in REST architecture returns JSON formats with enterprise blockchain data. Developers can use the API to interact with Factom blockchain. Methods are available to get and...
# Category:  Enterprise
# Link:  https://www.programmableweb.com/api/de-facto-enterprise
# -----
# Api Name:   PDFTables API
# Description:   The PDFTables API converts PDF documents to Excel spreadsheets. Developers authenticate with API Key to receive CSV, XML, and XLSX formats.
# Category:  PDF
# Link:  https://www.programmableweb.com/api/pdftables
# -----
# Api Name:   App Store Connect API
# Description:   The App Store Connect API allows developers to automate tasks on the App Store, including uploading, submitting, and managing their apps. Developers can also view sales reports, access app analytics...
# Category:  eCommerce
# Link:  https://www.programmableweb.com/api/app-store-connect
# -----
# Api Name:   Trefle API
# Description:   The Trefle API in REST architecture supports JSON format to return botanical data for plant species. With the API, developers could build farming robots, gardening apps, and search apps with...
# Category:  Nature
# Link:  https://www.programmableweb.com/api/trefle
# -----
# Api Name:   Tangany API
# Description:   Blockchain custody API service. 100% Made in Germany. Wallet as a Service. Unified API (Bitcoin, Ethereum, etc.). Create 'private keys' in a safe HSM-Cloud. Sign transaction without an own node. All...
# Category:  Software-as-a-Service
# Link:  https://www.programmableweb.com/api/tangany
# -----
# Api Name:   PayJoy Finance Partner API
# Description:   The PayJoy API returns JSON data with payments, finance orders, partner contracts, amounts, currency, and client data. API Key is required to authenticate. Visit https://www.payjoy.com/about/ to...
# Category:  Payments
# Link:  https://www.programmableweb.com/api/payjoy-finance-partner
# -----
# Api Name:   Klarna Merchant Card Service API
# Description:   The Klarna Merchant Card Service API is a Rest service that allows you to settle orders with virtual credit cards. The content type supports JSON and includes Create a new settlement, Retrieve An...
# Category:  eCommerce
# Link:  https://www.programmableweb.com/api/klarna-merchant-card-service
# -----
# Api Name:   Klarna Hosted Payment Page API
# Description:   The Klarna Hosted Payment Page API provides a way to integrate Klarna Payments without hosting the webpage that manages the client side. It is a companion service to Klarna Payments, so you need to...
# Category:  eCommerce
# Link:  https://www.programmableweb.com/api/klarna-hosted-payment-page
# -----
# Api Name:   Klarna Transport API
# Description:   This is indirect access to this service, please refer to the corresponding SDK below. Klarna is a global tech bank that provides services for payments and shopping.
# Category:  eCommerce
# Link:  https://www.programmableweb.com/api/klarna-transport
# -----
# Api Name:   Klarna Settlements API
# Description:   The Klarna Settlements API provides access to payouts and transactions, that are basically two types that include; Collections, and Entity. It allows you to return a summary of payouts for each...
# Category:  eCommerce
# Link:  https://www.programmableweb.com/api/klarna-settlements
# -----
# Api Name:   TaxiStartup API
# Description:   With the TaxiStartup API you can request a cab via the Onde platform for your client. You can also connect another dispatch system for handling and distribution of orders. Need a cab? Hack it into...
# Category:  Transportation
# Link:  https://www.programmableweb.com/api/taxistartup
# -----
# Api Name:   Fitbit System API
# Description:   This is indirect access to the Fitbit System API. Please refer to the corresponding SDK below. This Fitbit System service launches an application given a UUID and includes; Variable memory,...
# Category:  Fitness
# Link:  https://www.programmableweb.com/api/fitbit-system
# -----
# Api Name:   Bing Maps Elevations API
# Description:   The Bing Maps Elevations API allows you to get elevation values for a set of locations, a polyline path or area on the Earth. It provides a set of elevations and the associated zoom level is returned...
# Category:  Mapping
# Link:  https://www.programmableweb.com/api/bing-maps-elevations
# -----
# Api Name:   Breachsense API
# Description:   The Breachsense API allows security researchers to quickly search data dumps for breached credentials. This API is in beta release.
# Category:  Security
# Link:  https://www.programmableweb.com/api/breachsense
# -----
# Api Name:   STAPI Star Trek API
# Description:   The STAPI Star Trek API is a public, open source Star Trek API that anyone can contribute to. It uses publicly available data sources, such as Memory Alpha. This data is cleansed, standardized, and...
# Category:  Entertainment
# Link:  https://www.programmableweb.com/api/stapi-star-trek
# -----
# Api Name:   STAPI Star Trek RPC API
# Description:   The STAPI Star Trek RPC API is a public, open source Star Trek API that anyone can contribute to. It uses publicly available data sources, such as Memory Alpha. This data is cleansed, standardized,...
# Category:  Entertainment
# Link:  https://www.programmableweb.com/api/stapi-star-trek-rpc
# -----
# Api Name:   CardConnect Gateway API
# Description:   The CardConnect Gateway API returns JSON data to integrate credit, debit, and alternative payments into applications. REST implementation guide is available along with port connection instructions...
# Category:  Credit Cards
# Link:  https://www.programmableweb.com/api/cardconnect-gateway
# -----
# Api Name:   CardConnect Bolt API
# Description:   The CardConnect Bolt API returns JSON data, aiming to streamline the integration of validated credit card payments. With the API, developers can implement payment acceptance solutions into software...
# Category:  Credit Cards
# Link:  https://www.programmableweb.com/api/cardconnect-bolt
# -----
# Api Name:   CardConnect CoPilot API
# Description:   The CardConnect CoPilot API assists in modifying merchants. Endpoints include create and update merchant, owner card pointe, signature status, and create billing plan. CardConnect is a payment...
# Category:  Credit Cards
# Link:  https://www.programmableweb.com/api/cardconnect-copilot
# -----
# Api Name:   Synoptic Data Mesonet API
# Description:   The Synoptic Data Mesonet API returns JSON and XML data to integrate weather data that includes units with positions, air temperature, elevation, and volts; elevation with sensor variables, longitude...
# Category:  Weather
# Link:  https://www.programmableweb.com/api/synoptic-data-mesonet
# -----
# Api Name:   Olapic Content API
# Description:   The Olapic Content API provides programmatic access to media search. The Content API is a REST API, and its responses are available in JSON format. This API only returns content that has rights-...
# Category:  Content
# Link:  https://www.programmableweb.com/api/olapic-content
# -----
# Api Name:   Olapic Analytics API
# Description:   The Olapic Analytics Tracking API allows you to track users interactions with UGC (User-generated content) through Olapic widgets.
# These interactions can be tracked as events. Media views, video...
# Category:  Analytics
# Link:  https://www.programmableweb.com/api/olapic-analytics
# -----

# %%
# %debug
# Out:
# > <ipython-input-11-af9586013aeb>(5)<module>()
#       3 #while True:
#       4 for tr in apis_table.select('tr'):
# ----> 5     name_tag = td.find("td.a",{"class":"views-field views-field-pw-version-title"})
#       6     name = name_tag.text if name_tag else "N/A"
#       7     description = td.find("td",{"class":"views-field views-field-search-api-excerpt views-field-field-api-description hidden-xs visible-md visible-sm col-md-8"})
#
# ipdb> tr
# <tr class="odd views-row-first"><td class="views-field views-field-pw-version-title"> <a href="/api/google-maps">Google Maps API</a><br/></td><td class="views-field views-field-search-api-excerpt views-field-field-api-description hidden-xs visible-md visible-sm col-md-8"> [This API is no longer available. Google Maps' services have been split into multiple APIs, including the Static Maps API, Street View Image API, Directions APIs, Distance Matrix API, Elevation API,...</td><td class="views-field views-field-field-article-primary-category"> <a href="/category/mapping">Mapping</a></td><td class="views-field views-field-flag-follow-api-count"> 3,850</td><td class="views-field views-field-pw-version-links"> <a href="/api/google-maps-rest-api">REST</a></td></tr>
# ipdb> name_tag
# *** NameError: name 'name_tag' is not defined
# ipdb> q

# %%
npo_apis_df.head()
# Out:
#            Api Name                                        Description  \
# 1   Google Maps API   [This API is no longer available. Google Maps...
# 2       Twitter API   [This API is no longer available. It has been...
#
#    Category  Link
# 1   Mapping  None
# 2    Social  None

# %%
url
# Out:
# 'https://www.programmableweb.com/category/all/apis?page=2'
